# %%
# !pip install q tensorflow==2.1
# !pip install q keras==2.3.1
# !pip install git+https://github.com/qubvel/segmentation_models

# for str decode error ... run it and restart runtime
# !pip uninstall h5py -y
# !pip install h5py==2.10.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: h5py==2.10.0 in /home/tensorflow/.local/lib/python3.8/site-packages (2.10.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from h5py==2.10.0) (1.14.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.8/dist-packages (from h5py==2.10.0) (1.21.3)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
i = !ls Dataset/images/
l = !ls Dataset/masks/
len(i), len(l)
# Out:
# (2975, 2975)

# %%
l[-5:], i[-5:]
# Out:
# (['zurich_000117_000019_gtFine_labelTrainIds.png',
#   'zurich_000118_000019_gtFine_labelTrainIds.png',
#   'zurich_000119_000019_gtFine_labelTrainIds.png',
#   'zurich_000120_000019_gtFine_labelTrainIds.png',
#   'zurich_000121_000019_gtFine_labelTrainIds.png'],
#  ['zurich_000117_000019_leftImg8bit.png',
#   'zurich_000118_000019_leftImg8bit.png',
#   'zurich_000119_000019_leftImg8bit.png',
#   'zurich_000120_000019_leftImg8bit.png',
#   'zurich_000121_000019_leftImg8bit.png'])

# %%
import cv2
from glob import glob
import os
import numpy as np

# 100 = background
# 101 = road
# 102 = obstacle(person, rider, car, truck, bus, train, motorcycle, bicycle)

l = glob('Dataset/masks/*')
m = cv2.imread(l[2970],0)
m.shape
np.unique(m)
# Out:
# array([0, 1, 2], dtype=uint8)

# %%
import os
len(os.listdir('Dataset/images/')), len(os.listdir('Dataset/masks/'))
# Out:
# (2975, 2975)

# %%
import numpy as np
import cv2
import os
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf

def load_dataset(dataset_path):
    images = sorted(glob(os.path.join(dataset_path, "images/*")))
    masks = sorted(glob(os.path.join(dataset_path, "masks/*")))

    train_x, test_x, train_y, test_y = train_test_split(images,masks, test_size=0.168, 
                                                        random_state=168, shuffle=True)
    return train_x, train_y, test_x, test_y

train_x, train_y, val_x, val_y = load_dataset('Dataset')
print(len(train_x), len(train_y), len(val_x), len(val_y))
# Out:
# 2475 2475 500 500

# %%
train_X_y_paths = list(zip(train_x, train_y))
val_X_y_paths = list(zip(val_x, val_y))

# %%
def shuffle(samples):
    index = np.random.permutation(len(samples))
    return np.array(samples)[index]

def read_img(img):
    X_image = cv2.imread(img)[:,:,::-1] # convert bgr to rgb
    X_image = cv2.resize(X_image, (512, 512))    
    X_image = X_image / 255.0
    X_image = X_image.astype(np.float32)
    return X_image

def read_label(label_img):
    Y_image = cv2.imread(label_img, 0)    
    Y_image = cv2.resize(Y_image, (512, 512),fx = 1, fy = 1,interpolation = cv2.INTER_NEAREST)    
    Y_image = tf.one_hot(Y_image, 3)
#     Y_image.set_shape([512, 1024, 3])
    Y_image = np.array(Y_image)
    Y_image = Y_image.astype(np.float32)
    return Y_image

def get_data_generator(samples,batch_size):
    while True:
        for offset in range(0, len(samples), batch_size): 
            samples = shuffle(samples)           
            batch_samples = samples[offset:offset+batch_size]
            X_train = []
            Y_train = []                    
            for batch_sample in batch_samples:
                X_image = read_img(img=batch_sample[0])
                Y_image = read_label(label_img=batch_sample[1])
        
                X_train.append(X_image)
                Y_train.append(Y_image)
            yield np.array(X_train), np.array(Y_train)


BATCH_SIZE = 8
train_generator = get_data_generator(train_X_y_paths,batch_size=BATCH_SIZE)
val_generator = get_data_generator(val_X_y_paths,batch_size=BATCH_SIZE)
 
# x_train, y_train = next(train_generator)
# x_val, y_val  = next(val_generator)
 
# print(x_train.shape,y_train.shape)
# print(x_val.shape, y_val.shape)

# %%
# train_X_y_paths[-5:]
# print(np.unique(y_train[0]), y_train.shape)

# import matplotlib.pyplot as plt
# plt.imshow(np.argmax(y_train[1], axis=-1))#,cmap="gray")
# plt.show()

# %%
# %env SM_FRAMEWORK=tf.keras
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
# -*- coding: utf-8 -*-

""" Deeplabv3+ model for Keras.
This model is based on TF repo:
https://github.com/tensorflow/models/tree/master/research/deeplab
On Pascal VOC, original model gets to 84.56% mIOU
MobileNetv2 backbone is based on this repo:
https://github.com/JonathanCMitchell/mobilenet_v2_keras
# Reference
- [Encoder-Decoder with Atrous Separable Convolution
    for Semantic Image Segmentation](https://arxiv.org/pdf/1802.02611.pdf)
- [Xception: Deep Learning with Depthwise Separable Convolutions]
    (https://arxiv.org/abs/1610.02357)
- [Inverted Residuals and Linear Bottlenecks: Mobile Networks for
    Classification, Detection and Segmentation](https://arxiv.org/abs/1801.04381)
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf

from tensorflow.python.keras.models import Model
from tensorflow.python.keras import layers
from tensorflow.python.keras.layers import Input
from tensorflow.python.keras.layers import Reshape
from tensorflow.python.keras.layers import Activation
from tensorflow.python.keras.layers import Concatenate
from tensorflow.python.keras.layers import Add
from tensorflow.python.keras.layers import Dropout
from tensorflow.python.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Conv2D
from tensorflow.python.keras.layers import DepthwiseConv2D
from tensorflow.python.keras.layers import ZeroPadding2D
from tensorflow.python.keras.layers import GlobalAveragePooling2D
from tensorflow.python.keras.utils.layer_utils import get_source_inputs
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.applications.imagenet_utils import preprocess_input

WEIGHTS_PATH_X = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_MOBILE = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5"

WEIGHTS_PATH_X_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"
WEIGHTS_PATH_MOBILE_CS = "pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"


def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):
    """ SepConv with BN between depthwise & pointwise. Optionally add activation after BN
        Implements right "same" padding for even kernel sizes
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & poinwise convs
            epsilon: epsilon to use in BN layer
    """

    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)

    return x


def _conv2d_same(x, filters, prefix, stride=1, kernel_size=3, rate=1):
    """Implements right 'same' padding for even kernel sizes
        Without this there is a 1 pixel drift when stride = 2
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
    """
    if stride == 1:
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='same', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='valid', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)


def _xception_block(inputs, depth_list, prefix, skip_connection_type, stride,
                    rate=1, depth_activation=False, return_skip=False):
    """ Basic building block of modified Xception network
        Args:
            inputs: input tensor
            depth_list: number of filters in each SepConv layer. len(depth_list) == 3
            prefix: prefix before name
            skip_connection_type: one of {'conv','sum','none'}
            stride: stride at last depthwise conv
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & pointwise convs
            return_skip: flag to return additional tensor after 2 SepConvs for decoder
            """
    residual = inputs
    for i in range(3):
        residual = SepConv_BN(residual,
                              depth_list[i],
                              prefix + '_separable_conv{}'.format(i + 1),
                              stride=stride if i == 2 else 1,
                              rate=rate,
                              depth_activation=depth_activation)
        if i == 1:
            skip = residual
    if skip_connection_type == 'conv':
        shortcut = _conv2d_same(inputs, depth_list[-1], prefix + '_shortcut',
                                kernel_size=1,
                                stride=stride)
        shortcut = BatchNormalization(name=prefix + '_shortcut_BN')(shortcut)
        outputs = layers.add([residual, shortcut])
    elif skip_connection_type == 'sum':
        outputs = layers.add([residual, inputs])
    elif skip_connection_type == 'none':
        outputs = residual
    if return_skip:
        return outputs, skip
    else:
        return outputs


def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id, skip_connection, rate=1):
    in_channels = inputs.shape[-1]#.value  # inputs._keras_shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs
    prefix = 'expanded_conv_{}_'.format(block_id)
    if block_id:
        # Expand

        x = Conv2D(expansion * in_channels, kernel_size=1, padding='same',
                   use_bias=False, activation=None,
                   name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                               name=prefix + 'expand_BN')(x)
        x = Activation(tf.nn.relu6, name=prefix + 'expand_relu')(x)
    else:
        prefix = 'expanded_conv_'
    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None,
                        use_bias=False, padding='same', dilation_rate=(rate, rate),
                        name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'depthwise_BN')(x)

    x = Activation(tf.nn.relu6, name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters,
               kernel_size=1, padding='same', use_bias=False, activation=None,
               name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'project_BN')(x)

    if skip_connection:
        return Add(name=prefix + 'add')([inputs, x])

    # if in_channels == pointwise_filters and stride == 1:
    #    return Add(name='res_connect_' + str(block_id))([inputs, x])

    return x


def Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(512, 512, 3), classes=21, backbone='mobilenetv2',
              OS=16, alpha=1., activation=None):
    """ Instantiates the Deeplabv3+ architecture
    Optionally loads weights pre-trained
    on PASCAL VOC or Cityscapes. This model is available for TensorFlow only.
    # Arguments
        weights: one of 'pascal_voc' (pre-trained on pascal voc),
            'cityscapes' (pre-trained on cityscape) or None (random initialization)
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: shape of input image. format HxWxC
            PASCAL VOC model was trained on (512,512,3) images. None is allowed as shape/width
        classes: number of desired classes. PASCAL VOC has 21 classes, Cityscapes has 19 classes.
            If number of classes not aligned with the weights used, last layer is initialized randomly
        backbone: backbone to use. one of {'xception','mobilenetv2'}
        activation: optional activation to add to the top of the network.
            One of 'softmax', 'sigmoid' or None
        OS: determines input_shape/feature_extractor_output ratio. One of {8,16}.
            Used only for xception backbone.
        alpha: controls the width of the MobileNetV2 network. This is known as the
            width multiplier in the MobileNetV2 paper.
                - If `alpha` < 1.0, proportionally decreases the number
                    of filters in each layer.
                - If `alpha` > 1.0, proportionally increases the number
                    of filters in each layer.
                - If `alpha` = 1, default number of filters from the paper
                    are used at each layer.
            Used only for mobilenetv2 backbone. Pretrained is only available for alpha=1.
    # Returns
        A Keras model instance.
    # Raises
        RuntimeError: If attempting to run this model with a
            backend that does not support separable convolutions.
        ValueError: in case of invalid argument for `weights` or `backbone`
    """

    if not (weights in {'pascal_voc', 'cityscapes', None}):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization), `pascal_voc`, or `cityscapes` '
                         '(pre-trained on PASCAL VOC)')

    if not (backbone in {'xception', 'mobilenetv2'}):
        raise ValueError('The `backbone` argument should be either '
                         '`xception`  or `mobilenetv2` ')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        img_input = input_tensor

    if backbone == 'xception':
        if OS == 8:
            entry_block3_stride = 1
            middle_block_rate = 2  # ! Not mentioned in paper, but required
            exit_block_rates = (2, 4)
            atrous_rates = (12, 24, 36)
        else:
            entry_block3_stride = 2
            middle_block_rate = 1
            exit_block_rates = (1, 2)
            atrous_rates = (6, 12, 18)

        x = Conv2D(32, (3, 3), strides=(2, 2),
                   name='entry_flow_conv1_1', use_bias=False, padding='same')(img_input)
        x = BatchNormalization(name='entry_flow_conv1_1_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _conv2d_same(x, 64, 'entry_flow_conv1_2', kernel_size=3, stride=1)
        x = BatchNormalization(name='entry_flow_conv1_2_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _xception_block(x, [128, 128, 128], 'entry_flow_block1',
                            skip_connection_type='conv', stride=2,
                            depth_activation=False)
        x, skip1 = _xception_block(x, [256, 256, 256], 'entry_flow_block2',
                                   skip_connection_type='conv', stride=2,
                                   depth_activation=False, return_skip=True)

        x = _xception_block(x, [728, 728, 728], 'entry_flow_block3',
                            skip_connection_type='conv', stride=entry_block3_stride,
                            depth_activation=False)
        for i in range(16):
            x = _xception_block(x, [728, 728, 728], 'middle_flow_unit_{}'.format(i + 1),
                                skip_connection_type='sum', stride=1, rate=middle_block_rate,
                                depth_activation=False)

        x = _xception_block(x, [728, 1024, 1024], 'exit_flow_block1',
                            skip_connection_type='conv', stride=1, rate=exit_block_rates[0],
                            depth_activation=False)
        x = _xception_block(x, [1536, 1536, 2048], 'exit_flow_block2',
                            skip_connection_type='none', stride=1, rate=exit_block_rates[1],
                            depth_activation=True)

    else:
        OS = 8
        first_block_filters = _make_divisible(32 * alpha, 8)
        x = Conv2D(first_block_filters,
                   kernel_size=3,
                   strides=(2, 2), padding='same', use_bias=False,
                   name='Conv' if input_shape[2] == 3 else 'Conv_')(img_input)
        x = BatchNormalization(
            epsilon=1e-3, momentum=0.999, name='Conv_BN')(x)
        x = Activation(tf.nn.relu6, name='Conv_Relu6')(x)

        x = _inverted_res_block(x, filters=16, alpha=alpha, stride=1,
                                expansion=1, block_id=0, skip_connection=False)

        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
                                expansion=6, block_id=1, skip_connection=False)
        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=1,
                                expansion=6, block_id=2, skip_connection=True)

        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=2,
                                expansion=6, block_id=3, skip_connection=False)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=4, skip_connection=True)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=5, skip_connection=True)

        # stride in block 6 changed from 2 -> 1, so we need to use rate = 2
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1,  # 1!
                                expansion=6, block_id=6, skip_connection=False)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=7, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=8, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=9, skip_connection=True)

        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=10, skip_connection=False)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=11, skip_connection=True)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=12, skip_connection=True)

        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=2,  # 1!
                                expansion=6, block_id=13, skip_connection=False)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=14, skip_connection=True)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=15, skip_connection=True)

        x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=16, skip_connection=False)

    # end of feature extractor

    # branching for Atrous Spatial Pyramid Pooling

    # Image Feature branch
    shape_before = tf.shape(x)
    b4 = GlobalAveragePooling2D()(x)
    b4_shape = tf.keras.backend.int_shape(b4)
    # from (b_size, channels)->(b_size, 1, 1, channels)
    b4 = Reshape((1, 1, b4_shape[1]))(b4)
    b4 = Conv2D(256, (1, 1), padding='same',
                use_bias=False, name='image_pooling')(b4)
    b4 = BatchNormalization(name='image_pooling_BN', epsilon=1e-5)(b4)
    b4 = Activation(tf.nn.relu)(b4)
    # upsample. have to use compat because of the option align_corners
    size_before = tf.keras.backend.int_shape(x)
    b4 = tf.keras.layers.experimental.preprocessing.Resizing(
            *size_before[1:3], interpolation="bilinear"
        )(b4)
    # simple 1x1
    b0 = Conv2D(256, (1, 1), padding='same', use_bias=False, name='aspp0')(x)
    b0 = BatchNormalization(name='aspp0_BN', epsilon=1e-5)(b0)
    b0 = Activation(tf.nn.relu, name='aspp0_activation')(b0)

    # there are only 2 branches in mobilenetV2. not sure why
    if backbone == 'xception':
        # rate = 6 (12)
        b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
        b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
        b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
        x = Concatenate()([b4, b0, b1, b2, b3])
    else:
        x = Concatenate()([b4, b0])

    x = Conv2D(256, (1, 1), padding='same',
               use_bias=False, name='concat_projection')(x)
    x = BatchNormalization(name='concat_projection_BN', epsilon=1e-5)(x)
    x = Activation(tf.nn.relu)(x)
    x = Dropout(0.1)(x)
    # DeepLab v.3+ decoder

    if backbone == 'xception':
        # Feature projection
        # x4 (x2) block
        skip_size = tf.keras.backend.int_shape(skip1)
        x = tf.keras.layers.experimental.preprocessing.Resizing(
                *skip_size[1:3], interpolation="bilinear"
            )(x)
        dec_skip1 = Conv2D(48, (1, 1), padding='same',
                           use_bias=False, name='feature_projection0')(skip1)
        dec_skip1 = BatchNormalization(
            name='feature_projection0_BN', epsilon=1e-5)(dec_skip1)
        dec_skip1 = Activation(tf.nn.relu)(dec_skip1)
        x = Concatenate()([x, dec_skip1])
        x = SepConv_BN(x, 256, 'decoder_conv0',
                       depth_activation=True, epsilon=1e-5)
        x = SepConv_BN(x, 256, 'decoder_conv1',
                       depth_activation=True, epsilon=1e-5)

    # you can use it with arbitary number of classes
    if (weights == 'pascal_voc' and classes == 21) or (weights == 'cityscapes' and classes == 19):
        last_layer_name = 'logits_semantic'
    else:
        last_layer_name = 'custom_logits_semantic'

    x = Conv2D(classes, (1, 1), padding='same', name=last_layer_name)(x)
    size_before3 = tf.keras.backend.int_shape(img_input)
    x = tf.keras.layers.experimental.preprocessing.Resizing(
            *size_before3[1:3], interpolation="bilinear"
        )(x)
    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    if activation in {'softmax', 'sigmoid'}:
        x = tf.keras.layers.Activation(activation)(x)

    model = Model(inputs, x, name='deeplabv3plus')

    # load weights

    if weights == 'pascal_voc':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_X,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_MOBILE,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    elif weights == 'cityscapes':
        if backbone == 'xception':
#             weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5',
#                                     WEIGHTS_PATH_X_CS,
#                                     cache_subdir='models')
            weights_path = "pretrained_weights/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"    
        else:
#             weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5',
#                                     WEIGHTS_PATH_MOBILE_CS,
#                                     cache_subdir='models')
           weights_path = "pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"
            
        model.load_weights(weights_path, by_name=True)
    return model

def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.
    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].
    # Returns
        Input array scaled to [-1.,1.]
    """
    return preprocess_input(x, mode='tf')

# %%
# !pwd
# Out:
# /home/tensorflow/Documents/Semantic_Segmentation

# %%
# m = tf.keras.applications.MobileNet(
#     input_shape=(512,512,3),
#     alpha=1.0,
#     depth_multiplier=1,
#     dropout=0.001,
#     include_top=False,
#     weights=None,
#     input_tensor=None,
#     pooling=None,
#     classes=3,
#     classifier_activation="softmax",
# )
# m.summary()

# alpha 1.0 : 32,64,128,256,512,1024
# alpha 0.1 : 3,6,12,25,51,102
# alpha 0.3 : 9,18,36,125,153,307

# %% [markdown]
# m = tf.keras.applications.MobileNet(
#     input_shape=(512,512,3),
#     alpha=0.3,
#     depth_multiplier=1,
#     dropout=0.001,
#     include_top=False,
#     weights=None,
#     input_tensor=None,
#     pooling=None,
#     classes=3,
#     classifier_activation="softmax",
# )
# m.summary()

# %%
model = Deeplabv3(weights=None, input_shape=(512,512,3), classes=3, 
                  backbone= 'mobilenetv2', #'xception'
                  OS=16, alpha=0.3, activation='softmax')
# model.load_weights('pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5')

# %%
from segmentation_models.losses import cce_jaccard_loss, dice_loss, JaccardLoss
from segmentation_models.metrics import iou_score, f1_score, precision, recall
ls = dice_loss + cce_jaccard_loss
metrics = [precision, recall, f1_score, iou_score] 

# from tensorflow.keras.models import load_model
# model = load_model('mobilenetV2_bs4/ckpt_path/84.h5',
#                    custom_objects={'dice_loss_plus_categorical_crossentropy_plus_jaccard_loss':ls,
#                                    'precision':precision, 'recall':recall, 'f1-score':f1_score, 'iou_score':iou_score})
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
import os, time, keras
# %env SM_FRAMEWORK=tf.keras

import numpy as np
import tensorflow as tf
from segmentation_models.losses import bce_jaccard_loss, dice_loss, JaccardLoss
from segmentation_models.metrics import iou_score, f1_score, precision, recall
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping

""" Hyperparamaters """
batch_size = 8
epochs = 1000
base_dir = 'mobilenetV2_edge'
if not os.path.exists(base_dir):
    os.mkdir(base_dir)
    os.mkdir(f"{base_dir}/ckpt_path")
    
csv_path = f"{base_dir}/history.csv"

""" callbacks """
root_logdir = os.path.join(os.curdir, f"{base_dir}/logs","fit","")
def get_run_logdir():
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

checkpoint_filepath = f'{base_dir}/'+'ckpt_path/{epoch}.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    # monitor='val_iou_score',
    # mode='max',
    verbose = 1,
    period = 25,
    save_best_only=False
    )

callbacks = [
    model_checkpoint_callback,
#     ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.1, verbose=1),
    CSVLogger(csv_path),
#     EarlyStopping(monitor="val_loss", patience=10),
    tensorboard_cb
]

""" steps per epochs """
train_steps = len(train_X_y_paths)//batch_size
if len(train_X_y_paths) % batch_size != 0:
    train_steps += 1

test_steps = len(val_X_y_paths)//batch_size
if len(val_X_y_paths) % batch_size != 0:
    test_steps += 1

print("train_steps", train_steps, "test_steps",test_steps)

""" Model training """
# for layer in model.layers:
#     if layer.name == "global_average_pooling2d":
#         break
#     else:
#         layer.trainable = False

# for layer in model.layers:
#     print(layer.name,layer.trainable)

model.compile(
    loss=ls,
    optimizer= "adam", #tf.keras.optimizers.Adam(lr),
    metrics=metrics
)
# model.summary()
# Out:
# env: SM_FRAMEWORK=tf.keras
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# train_steps 310 test_steps 63

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=1000,
    initial_epoch = 0,
    steps_per_epoch=train_steps,
    validation_steps=test_steps,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 1/1000
# 310/310 [==============================] - 412s 1s/step - loss: 0.7521 - precision: 0.7583 - recall: 0.7741 - f1-score: 0.7615 - iou_score: 0.6408 - val_loss: 1.8498 - val_precision: 0.3372 - val_recall: 0.3378 - val_f1-score: 0.3179 - val_iou_score: 0.2110
# Epoch 2/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.5139 - precision: 0.8474 - recall: 0.8541 - f1-score: 0.8480 - iou_score: 0.7465 - val_loss: 1.9348 - val_precision: 0.3404 - val_recall: 0.3413 - val_f1-score: 0.3060 - val_iou_score: 0.1988
# Epoch 3/1000
# 310/310 [==============================] - 391s 1s/step - loss: 0.4300 - precision: 0.8744 - recall: 0.8780 - f1-score: 0.8744 - iou_score: 0.7851 - val_loss: 1.8260 - val_precision: 0.3427 - val_recall: 0.3405 - val_f1-score: 0.3197 - val_iou_score: 0.2266
# Epoch 4/1000
# 310/310 [==============================] - 389s 1s/step - loss: 0.4132 - precision: 0.8798 - recall: 0.8830 - f1-score: 0.8795 - iou_score: 0.7934 - val_loss: 1.8351 - val_precision: 0.3483 - val_recall: 0.3505 - val_f1-score: 0.3274 - val_iou_score: 0.2186
# Epoch 5/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.3784 - precision: 0.8906 - recall: 0.8943 - f1-score: 0.8908 - iou_score: 0.8101 - val_loss: 1.8093 - val_precision: 0.3522 - val_recall: 0.3534 - val_f1-score: 0.3377 - val_iou_score: 0.2331
# Epoch 6/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.3556 - precision: 0.8971 - recall: 0.9014 - f1-score: 0.8977 - iou_score: 0.8210 - val_loss: 2.1086 - val_precision: 0.3595 - val_recall: 0.3574 - val_f1-score: 0.2960 - val_iou_score: 0.1905
# Epoch 7/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.3345 - precision: 0.9038 - recall: 0.9072 - f1-score: 0.9045 - iou_score: 0.8312 - val_loss: 1.9097 - val_precision: 0.3589 - val_recall: 0.3585 - val_f1-score: 0.3416 - val_iou_score: 0.2390
# Epoch 8/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.3264 - precision: 0.9060 - recall: 0.9096 - f1-score: 0.9066 - iou_score: 0.8351 - val_loss: 1.8735 - val_precision: 0.3662 - val_recall: 0.3559 - val_f1-score: 0.3334 - val_iou_score: 0.2400
# Epoch 9/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.3288 - precision: 0.9053 - recall: 0.9088 - f1-score: 0.9061 - iou_score: 0.8338 - val_loss: 1.9731 - val_precision: 0.3725 - val_recall: 0.3607 - val_f1-score: 0.3379 - val_iou_score: 0.2428
# Epoch 10/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.3066 - precision: 0.9111 - recall: 0.9151 - f1-score: 0.9122 - iou_score: 0.8438 - val_loss: 2.0050 - val_precision: 0.3815 - val_recall: 0.3519 - val_f1-score: 0.3118 - val_iou_score: 0.2298
# Epoch 11/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.3002 - precision: 0.9142 - recall: 0.9168 - f1-score: 0.9147 - iou_score: 0.8473 - val_loss: 2.2966 - val_precision: 0.4155 - val_recall: 0.3880 - val_f1-score: 0.2941 - val_iou_score: 0.1907
# Epoch 12/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.2990 - precision: 0.9145 - recall: 0.9164 - f1-score: 0.9146 - iou_score: 0.8475 - val_loss: 1.8667 - val_precision: 0.4199 - val_recall: 0.4143 - val_f1-score: 0.3635 - val_iou_score: 0.2502
# Epoch 13/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.2851 - precision: 0.9178 - recall: 0.9207 - f1-score: 0.9186 - iou_score: 0.8539 - val_loss: 1.9386 - val_precision: 0.4295 - val_recall: 0.4298 - val_f1-score: 0.4009 - val_iou_score: 0.2891
# Epoch 14/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.2780 - precision: 0.9205 - recall: 0.9225 - f1-score: 0.9209 - iou_score: 0.8579 - val_loss: 1.7893 - val_precision: 0.5040 - val_recall: 0.4922 - val_f1-score: 0.4565 - val_iou_score: 0.3487
# Epoch 15/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.2686 - precision: 0.9232 - recall: 0.9254 - f1-score: 0.9237 - iou_score: 0.8622 - val_loss: 1.3515 - val_precision: 0.7436 - val_recall: 0.5794 - val_f1-score: 0.5614 - val_iou_score: 0.4849
# Epoch 16/1000
# 310/310 [==============================] - 391s 1s/step - loss: 0.2718 - precision: 0.9223 - recall: 0.9244 - f1-score: 0.9228 - iou_score: 0.8608 - val_loss: 1.0744 - val_precision: 0.8623 - val_recall: 0.6269 - val_f1-score: 0.6468 - val_iou_score: 0.5484
# Epoch 17/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.2657 - precision: 0.9237 - recall: 0.9261 - f1-score: 0.9243 - iou_score: 0.8635 - val_loss: 0.5213 - val_precision: 0.9085 - val_recall: 0.8120 - val_f1-score: 0.8449 - val_iou_score: 0.7511
# Epoch 18/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.2618 - precision: 0.9244 - recall: 0.9280 - f1-score: 0.9254 - iou_score: 0.8654 - val_loss: 0.8911 - val_precision: 0.8980 - val_recall: 0.6893 - val_f1-score: 0.7239 - val_iou_score: 0.6243
# Epoch 19/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.2573 - precision: 0.9264 - recall: 0.9292 - f1-score: 0.9272 - iou_score: 0.8681 - val_loss: 0.3844 - val_precision: 0.8937 - val_recall: 0.9026 - val_f1-score: 0.8973 - val_iou_score: 0.8218
# Epoch 20/1000
# 310/310 [==============================] - 390s 1s/step - loss: 0.2545 - precision: 0.9274 - recall: 0.9295 - f1-score: 0.9280 - iou_score: 0.8695 - val_loss: 0.4446 - val_precision: 0.8840 - val_recall: 0.8775 - val_f1-score: 0.8795 - val_iou_score: 0.7946
# Epoch 21/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.2446 - precision: 0.9299 - recall: 0.9318 - f1-score: 0.9304 - iou_score: 0.8736 - val_loss: 0.4338 - val_precision: 0.8958 - val_recall: 0.8794 - val_f1-score: 0.8856 - val_iou_score: 0.8017
# Epoch 22/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.2395 - precision: 0.9319 - recall: 0.9339 - f1-score: 0.9325 - iou_score: 0.8767 - val_loss: 0.4487 - val_precision: 0.8698 - val_recall: 0.8942 - val_f1-score: 0.8785 - val_iou_score: 0.7911
# Epoch 23/1000
# 310/310 [==============================] - 390s 1s/step - loss: 0.2372 - precision: 0.9317 - recall: 0.9342 - f1-score: 0.9325 - iou_score: 0.8772 - val_loss: 0.3981 - val_precision: 0.8923 - val_recall: 0.8949 - val_f1-score: 0.8924 - val_iou_score: 0.8116
# Epoch 24/1000
# 310/310 [==============================] - 391s 1s/step - loss: 0.2429 - precision: 0.9303 - recall: 0.9324 - f1-score: 0.9310 - iou_score: 0.8745 - val_loss: 0.4193 - val_precision: 0.8722 - val_recall: 0.9121 - val_f1-score: 0.8876 - val_iou_score: 0.8066
# Epoch 25/1000
# 310/310 [==============================] - 389s 1s/step - loss: 0.2460 - precision: 0.9293 - recall: 0.9315 - f1-score: 0.9299 - iou_score: 0.8729 - val_loss: 0.7451 - val_precision: 0.8591 - val_recall: 0.7888 - val_f1-score: 0.8100 - val_iou_score: 0.6887
#
# Epoch 00025: saving model to mobilenetV2_edge/ckpt_path/25.h5
# Epoch 26/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.2302 - precision: 0.9337 - recall: 0.9362 - f1-score: 0.9347 - iou_score: 0.8808 - val_loss: 1.0761 - val_precision: 0.7590 - val_recall: 0.7679 - val_f1-score: 0.7214 - val_iou_score: 0.5752
# Epoch 27/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.2269 - precision: 0.9351 - recall: 0.9369 - f1-score: 0.9357 - iou_score: 0.8824 - val_loss: 0.6303 - val_precision: 0.8862 - val_recall: 0.7953 - val_f1-score: 0.8281 - val_iou_score: 0.7203
# Epoch 28/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.2271 - precision: 0.9347 - recall: 0.9377 - f1-score: 0.9358 - iou_score: 0.8827 - val_loss: 0.5314 - val_precision: 0.8957 - val_recall: 0.8538 - val_f1-score: 0.8699 - val_iou_score: 0.7768
# Epoch 29/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.2149 - precision: 0.9386 - recall: 0.9403 - f1-score: 0.9392 - iou_score: 0.8884 - val_loss: 0.6801 - val_precision: 0.8060 - val_recall: 0.8659 - val_f1-score: 0.8165 - val_iou_score: 0.7012
# Epoch 30/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.2149 - precision: 0.9384 - recall: 0.9405 - f1-score: 0.9392 - iou_score: 0.8883 - val_loss: 0.6229 - val_precision: 0.8824 - val_recall: 0.8102 - val_f1-score: 0.8375 - val_iou_score: 0.7277
# Epoch 31/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.2159 - precision: 0.9381 - recall: 0.9400 - f1-score: 0.9388 - iou_score: 0.8878 - val_loss: 0.3603 - val_precision: 0.9045 - val_recall: 0.9073 - val_f1-score: 0.9049 - val_iou_score: 0.8319
# Epoch 32/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.2174 - precision: 0.9375 - recall: 0.9399 - f1-score: 0.9385 - iou_score: 0.8872 - val_loss: 0.3805 - val_precision: 0.8832 - val_recall: 0.9150 - val_f1-score: 0.8969 - val_iou_score: 0.8186
# Epoch 33/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.2095 - precision: 0.9400 - recall: 0.9420 - f1-score: 0.9408 - iou_score: 0.8910 - val_loss: 0.5276 - val_precision: 0.9089 - val_recall: 0.8336 - val_f1-score: 0.8606 - val_iou_score: 0.7701
# Epoch 34/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.2144 - precision: 0.9390 - recall: 0.9401 - f1-score: 0.9392 - iou_score: 0.8886 - val_loss: 2.7303 - val_precision: 0.8265 - val_recall: 0.5861 - val_f1-score: 0.5278 - val_iou_score: 0.4382
# Epoch 35/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.2020 - precision: 0.9422 - recall: 0.9439 - f1-score: 0.9429 - iou_score: 0.8947 - val_loss: 0.3770 - val_precision: 0.8815 - val_recall: 0.9159 - val_f1-score: 0.8961 - val_iou_score: 0.8190
# Epoch 36/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.2108 - precision: 0.9395 - recall: 0.9419 - f1-score: 0.9404 - iou_score: 0.8905 - val_loss: 0.4782 - val_precision: 0.9049 - val_recall: 0.8551 - val_f1-score: 0.8733 - val_iou_score: 0.7866
# Epoch 37/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.2024 - precision: 0.9419 - recall: 0.9441 - f1-score: 0.9427 - iou_score: 0.8945 - val_loss: 0.3410 - val_precision: 0.9007 - val_recall: 0.9100 - val_f1-score: 0.9041 - val_iou_score: 0.8305
# Epoch 38/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1972 - precision: 0.9437 - recall: 0.9457 - f1-score: 0.9445 - iou_score: 0.8974 - val_loss: 0.3337 - val_precision: 0.8992 - val_recall: 0.9213 - val_f1-score: 0.9087 - val_iou_score: 0.8374
# Epoch 39/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1908 - precision: 0.9454 - recall: 0.9472 - f1-score: 0.9461 - iou_score: 0.9003 - val_loss: 0.5183 - val_precision: 0.8765 - val_recall: 0.8601 - val_f1-score: 0.8609 - val_iou_score: 0.7609
# Epoch 40/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.2018 - precision: 0.9421 - recall: 0.9444 - f1-score: 0.9430 - iou_score: 0.8950 - val_loss: 0.4701 - val_precision: 0.9075 - val_recall: 0.8511 - val_f1-score: 0.8741 - val_iou_score: 0.7877
# Epoch 41/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.2019 - precision: 0.9421 - recall: 0.9443 - f1-score: 0.9429 - iou_score: 0.8949 - val_loss: 0.5054 - val_precision: 0.8375 - val_recall: 0.9042 - val_f1-score: 0.8619 - val_iou_score: 0.7707
# Epoch 42/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.2028 - precision: 0.9422 - recall: 0.9436 - f1-score: 0.9427 - iou_score: 0.8944 - val_loss: 0.3923 - val_precision: 0.8762 - val_recall: 0.9221 - val_f1-score: 0.8958 - val_iou_score: 0.8182
# Epoch 43/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1965 - precision: 0.9435 - recall: 0.9456 - f1-score: 0.9444 - iou_score: 0.8973 - val_loss: 0.3503 - val_precision: 0.9075 - val_recall: 0.9077 - val_f1-score: 0.9063 - val_iou_score: 0.8333
# Epoch 44/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1901 - precision: 0.9453 - recall: 0.9475 - f1-score: 0.9462 - iou_score: 0.9005 - val_loss: 0.3166 - val_precision: 0.9122 - val_recall: 0.9226 - val_f1-score: 0.9165 - val_iou_score: 0.8507
# Epoch 45/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1917 - precision: 0.9450 - recall: 0.9469 - f1-score: 0.9458 - iou_score: 0.8997 - val_loss: 0.8637 - val_precision: 0.8691 - val_recall: 0.7936 - val_f1-score: 0.8075 - val_iou_score: 0.6872
# Epoch 46/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1913 - precision: 0.9450 - recall: 0.9475 - f1-score: 0.9461 - iou_score: 0.9002 - val_loss: 0.6266 - val_precision: 0.8474 - val_recall: 0.8520 - val_f1-score: 0.8396 - val_iou_score: 0.7295
# Epoch 47/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.1958 - precision: 0.9438 - recall: 0.9455 - f1-score: 0.9444 - iou_score: 0.8974 - val_loss: 0.3849 - val_precision: 0.9323 - val_recall: 0.8745 - val_f1-score: 0.8989 - val_iou_score: 0.8233
# Epoch 48/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.1919 - precision: 0.9449 - recall: 0.9469 - f1-score: 0.9457 - iou_score: 0.8995 - val_loss: 1.6256 - val_precision: 0.8234 - val_recall: 0.6023 - val_f1-score: 0.6389 - val_iou_score: 0.4908
# Epoch 49/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1885 - precision: 0.9457 - recall: 0.9484 - f1-score: 0.9468 - iou_score: 0.9016 - val_loss: 0.3648 - val_precision: 0.8849 - val_recall: 0.9263 - val_f1-score: 0.9020 - val_iou_score: 0.8284
# Epoch 50/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1771 - precision: 0.9489 - recall: 0.9511 - f1-score: 0.9499 - iou_score: 0.9070 - val_loss: 0.4544 - val_precision: 0.8589 - val_recall: 0.9112 - val_f1-score: 0.8776 - val_iou_score: 0.7917
#
# Epoch 00050: saving model to mobilenetV2_edge/ckpt_path/50.h5
# Epoch 51/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1736 - precision: 0.9500 - recall: 0.9521 - f1-score: 0.9510 - iou_score: 0.9088 - val_loss: 0.3521 - val_precision: 0.9005 - val_recall: 0.9146 - val_f1-score: 0.9058 - val_iou_score: 0.8336
# Epoch 52/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1813 - precision: 0.9479 - recall: 0.9500 - f1-score: 0.9488 - iou_score: 0.9049 - val_loss: 0.3451 - val_precision: 0.9143 - val_recall: 0.9158 - val_f1-score: 0.9142 - val_iou_score: 0.8461
# Epoch 53/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1824 - precision: 0.9477 - recall: 0.9499 - f1-score: 0.9486 - iou_score: 0.9047 - val_loss: 0.5947 - val_precision: 0.8167 - val_recall: 0.8940 - val_f1-score: 0.8396 - val_iou_score: 0.7445
# Epoch 54/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1830 - precision: 0.9477 - recall: 0.9490 - f1-score: 0.9482 - iou_score: 0.9041 - val_loss: 0.3022 - val_precision: 0.9163 - val_recall: 0.9266 - val_f1-score: 0.9206 - val_iou_score: 0.8573
# Epoch 55/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1802 - precision: 0.9483 - recall: 0.9502 - f1-score: 0.9491 - iou_score: 0.9055 - val_loss: 2.9583 - val_precision: 0.8055 - val_recall: 0.4824 - val_f1-score: 0.4579 - val_iou_score: 0.3511
# Epoch 56/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.1812 - precision: 0.9481 - recall: 0.9503 - f1-score: 0.9490 - iou_score: 0.9054 - val_loss: 0.3768 - val_precision: 0.8950 - val_recall: 0.9060 - val_f1-score: 0.8980 - val_iou_score: 0.8204
# Epoch 57/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.1726 - precision: 0.9501 - recall: 0.9523 - f1-score: 0.9511 - iou_score: 0.9090 - val_loss: 0.2934 - val_precision: 0.9192 - val_recall: 0.9256 - val_f1-score: 0.9217 - val_iou_score: 0.8594
# Epoch 58/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1743 - precision: 0.9497 - recall: 0.9520 - f1-score: 0.9507 - iou_score: 0.9084 - val_loss: 0.3016 - val_precision: 0.9137 - val_recall: 0.9247 - val_f1-score: 0.9181 - val_iou_score: 0.8540
# Epoch 59/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1724 - precision: 0.9507 - recall: 0.9520 - f1-score: 0.9512 - iou_score: 0.9092 - val_loss: 0.6150 - val_precision: 0.8722 - val_recall: 0.8605 - val_f1-score: 0.8556 - val_iou_score: 0.7527
# Epoch 60/1000
# 310/310 [==============================] - 391s 1s/step - loss: 0.1870 - precision: 0.9461 - recall: 0.9490 - f1-score: 0.9473 - iou_score: 0.9025 - val_loss: 0.8962 - val_precision: 0.7663 - val_recall: 0.8507 - val_f1-score: 0.7787 - val_iou_score: 0.6650
# Epoch 61/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1763 - precision: 0.9497 - recall: 0.9513 - f1-score: 0.9504 - iou_score: 0.9076 - val_loss: 0.3292 - val_precision: 0.9086 - val_recall: 0.9134 - val_f1-score: 0.9095 - val_iou_score: 0.8411
# Epoch 62/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1774 - precision: 0.9492 - recall: 0.9509 - f1-score: 0.9499 - iou_score: 0.9069 - val_loss: 0.3345 - val_precision: 0.9195 - val_recall: 0.9067 - val_f1-score: 0.9122 - val_iou_score: 0.8436
# Epoch 63/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1670 - precision: 0.9517 - recall: 0.9537 - f1-score: 0.9526 - iou_score: 0.9117 - val_loss: 0.3262 - val_precision: 0.9182 - val_recall: 0.9121 - val_f1-score: 0.9139 - val_iou_score: 0.8466
# Epoch 64/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1684 - precision: 0.9515 - recall: 0.9535 - f1-score: 0.9524 - iou_score: 0.9113 - val_loss: 0.2959 - val_precision: 0.9190 - val_recall: 0.9231 - val_f1-score: 0.9203 - val_iou_score: 0.8571
# Epoch 65/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1601 - precision: 0.9541 - recall: 0.9558 - f1-score: 0.9549 - iou_score: 0.9156 - val_loss: 0.2924 - val_precision: 0.9212 - val_recall: 0.9288 - val_f1-score: 0.9244 - val_iou_score: 0.8633
# Epoch 66/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1601 - precision: 0.9543 - recall: 0.9556 - f1-score: 0.9549 - iou_score: 0.9156 - val_loss: 0.3639 - val_precision: 0.9230 - val_recall: 0.8922 - val_f1-score: 0.9051 - val_iou_score: 0.8325
# Epoch 67/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1606 - precision: 0.9540 - recall: 0.9557 - f1-score: 0.9547 - iou_score: 0.9153 - val_loss: 0.2899 - val_precision: 0.9333 - val_recall: 0.9192 - val_f1-score: 0.9253 - val_iou_score: 0.8654
# Epoch 68/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1568 - precision: 0.9549 - recall: 0.9567 - f1-score: 0.9557 - iou_score: 0.9171 - val_loss: 0.3131 - val_precision: 0.9204 - val_recall: 0.9224 - val_f1-score: 0.9206 - val_iou_score: 0.8578
# Epoch 69/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1791 - precision: 0.9493 - recall: 0.9506 - f1-score: 0.9497 - iou_score: 0.9066 - val_loss: 0.4922 - val_precision: 0.8509 - val_recall: 0.8955 - val_f1-score: 0.8686 - val_iou_score: 0.7792
# Epoch 70/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1685 - precision: 0.9515 - recall: 0.9530 - f1-score: 0.9521 - iou_score: 0.9109 - val_loss: 0.3361 - val_precision: 0.9037 - val_recall: 0.9288 - val_f1-score: 0.9146 - val_iou_score: 0.8483
# Epoch 71/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1607 - precision: 0.9538 - recall: 0.9555 - f1-score: 0.9546 - iou_score: 0.9151 - val_loss: 0.3203 - val_precision: 0.9048 - val_recall: 0.9280 - val_f1-score: 0.9149 - val_iou_score: 0.8479
# Epoch 72/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1720 - precision: 0.9506 - recall: 0.9524 - f1-score: 0.9514 - iou_score: 0.9095 - val_loss: 0.7000 - val_precision: 0.8923 - val_recall: 0.8191 - val_f1-score: 0.8421 - val_iou_score: 0.7336
# Epoch 73/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1654 - precision: 0.9526 - recall: 0.9545 - f1-score: 0.9534 - iou_score: 0.9130 - val_loss: 0.4003 - val_precision: 0.9113 - val_recall: 0.8795 - val_f1-score: 0.8929 - val_iou_score: 0.8153
# Epoch 74/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.1578 - precision: 0.9548 - recall: 0.9562 - f1-score: 0.9554 - iou_score: 0.9167 - val_loss: 0.2878 - val_precision: 0.9337 - val_recall: 0.9185 - val_f1-score: 0.9254 - val_iou_score: 0.8651
# Epoch 75/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1544 - precision: 0.9556 - recall: 0.9573 - f1-score: 0.9564 - iou_score: 0.9183 - val_loss: 0.2947 - val_precision: 0.9148 - val_recall: 0.9312 - val_f1-score: 0.9221 - val_iou_score: 0.8603
#
# Epoch 00075: saving model to mobilenetV2_edge/ckpt_path/75.h5
# Epoch 76/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1566 - precision: 0.9548 - recall: 0.9567 - f1-score: 0.9557 - iou_score: 0.9171 - val_loss: 0.3724 - val_precision: 0.9086 - val_recall: 0.9096 - val_f1-score: 0.9080 - val_iou_score: 0.8377
# Epoch 77/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.1594 - precision: 0.9542 - recall: 0.9556 - f1-score: 0.9548 - iou_score: 0.9156 - val_loss: 0.2905 - val_precision: 0.9141 - val_recall: 0.9324 - val_f1-score: 0.9223 - val_iou_score: 0.8613
# Epoch 78/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1493 - precision: 0.9573 - recall: 0.9584 - f1-score: 0.9578 - iou_score: 0.9208 - val_loss: 0.2812 - val_precision: 0.9183 - val_recall: 0.9377 - val_f1-score: 0.9272 - val_iou_score: 0.8682
# Epoch 79/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1525 - precision: 0.9561 - recall: 0.9578 - f1-score: 0.9569 - iou_score: 0.9193 - val_loss: 0.2851 - val_precision: 0.9253 - val_recall: 0.9289 - val_f1-score: 0.9265 - val_iou_score: 0.8674
# Epoch 80/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1611 - precision: 0.9534 - recall: 0.9555 - f1-score: 0.9543 - iou_score: 0.9148 - val_loss: 0.2860 - val_precision: 0.9237 - val_recall: 0.9284 - val_f1-score: 0.9255 - val_iou_score: 0.8657
# Epoch 81/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1598 - precision: 0.9543 - recall: 0.9559 - f1-score: 0.9550 - iou_score: 0.9158 - val_loss: 0.3155 - val_precision: 0.9202 - val_recall: 0.9221 - val_f1-score: 0.9203 - val_iou_score: 0.8568
# Epoch 82/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1665 - precision: 0.9526 - recall: 0.9542 - f1-score: 0.9533 - iou_score: 0.9127 - val_loss: 0.3530 - val_precision: 0.8986 - val_recall: 0.9164 - val_f1-score: 0.9058 - val_iou_score: 0.8336
# Epoch 83/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1537 - precision: 0.9557 - recall: 0.9574 - f1-score: 0.9565 - iou_score: 0.9185 - val_loss: 0.2674 - val_precision: 0.9226 - val_recall: 0.9383 - val_f1-score: 0.9298 - val_iou_score: 0.8726
# Epoch 84/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1513 - precision: 0.9563 - recall: 0.9580 - f1-score: 0.9571 - iou_score: 0.9196 - val_loss: 0.3293 - val_precision: 0.9014 - val_recall: 0.9303 - val_f1-score: 0.9137 - val_iou_score: 0.8464
# Epoch 85/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1670 - precision: 0.9523 - recall: 0.9540 - f1-score: 0.9531 - iou_score: 0.9124 - val_loss: 0.3344 - val_precision: 0.9138 - val_recall: 0.9128 - val_f1-score: 0.9124 - val_iou_score: 0.8446
# Epoch 86/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.1498 - precision: 0.9570 - recall: 0.9584 - f1-score: 0.9576 - iou_score: 0.9206 - val_loss: 0.3137 - val_precision: 0.9242 - val_recall: 0.9151 - val_f1-score: 0.9188 - val_iou_score: 0.8541
# Epoch 87/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1496 - precision: 0.9571 - recall: 0.9589 - f1-score: 0.9579 - iou_score: 0.9210 - val_loss: 0.9640 - val_precision: 0.8151 - val_recall: 0.7756 - val_f1-score: 0.7676 - val_iou_score: 0.6339
# Epoch 88/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1609 - precision: 0.9542 - recall: 0.9557 - f1-score: 0.9548 - iou_score: 0.9154 - val_loss: 0.3088 - val_precision: 0.9090 - val_recall: 0.9359 - val_f1-score: 0.9210 - val_iou_score: 0.8582
# Epoch 89/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1490 - precision: 0.9570 - recall: 0.9588 - f1-score: 0.9578 - iou_score: 0.9209 - val_loss: 0.2912 - val_precision: 0.9117 - val_recall: 0.9375 - val_f1-score: 0.9232 - val_iou_score: 0.8623
# Epoch 90/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1482 - precision: 0.9573 - recall: 0.9590 - f1-score: 0.9581 - iou_score: 0.9213 - val_loss: 0.3017 - val_precision: 0.9344 - val_recall: 0.9118 - val_f1-score: 0.9218 - val_iou_score: 0.8594
# Epoch 91/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1744 - precision: 0.9501 - recall: 0.9519 - f1-score: 0.9509 - iou_score: 0.9085 - val_loss: 0.3066 - val_precision: 0.9218 - val_recall: 0.9237 - val_f1-score: 0.9222 - val_iou_score: 0.8590
# Epoch 92/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1480 - precision: 0.9572 - recall: 0.9590 - f1-score: 0.9580 - iou_score: 0.9213 - val_loss: 0.2833 - val_precision: 0.9163 - val_recall: 0.9323 - val_f1-score: 0.9232 - val_iou_score: 0.8631
# Epoch 93/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1411 - precision: 0.9591 - recall: 0.9606 - f1-score: 0.9598 - iou_score: 0.9246 - val_loss: 0.2654 - val_precision: 0.9266 - val_recall: 0.9348 - val_f1-score: 0.9301 - val_iou_score: 0.8737
# Epoch 94/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1538 - precision: 0.9560 - recall: 0.9577 - f1-score: 0.9567 - iou_score: 0.9189 - val_loss: 0.3704 - val_precision: 0.9164 - val_recall: 0.8929 - val_f1-score: 0.9025 - val_iou_score: 0.8305
# Epoch 95/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1460 - precision: 0.9581 - recall: 0.9594 - f1-score: 0.9587 - iou_score: 0.9224 - val_loss: 0.2878 - val_precision: 0.9242 - val_recall: 0.9257 - val_f1-score: 0.9243 - val_iou_score: 0.8644
# Epoch 96/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1429 - precision: 0.9588 - recall: 0.9605 - f1-score: 0.9596 - iou_score: 0.9241 - val_loss: 0.2963 - val_precision: 0.9172 - val_recall: 0.9313 - val_f1-score: 0.9234 - val_iou_score: 0.8623
# Epoch 97/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1401 - precision: 0.9594 - recall: 0.9611 - f1-score: 0.9602 - iou_score: 0.9254 - val_loss: 0.2786 - val_precision: 0.9250 - val_recall: 0.9348 - val_f1-score: 0.9292 - val_iou_score: 0.8722
# Epoch 98/1000
# 310/310 [==============================] - 391s 1s/step - loss: 0.1374 - precision: 0.9605 - recall: 0.9619 - f1-score: 0.9612 - iou_score: 0.9269 - val_loss: 0.3135 - val_precision: 0.9293 - val_recall: 0.9166 - val_f1-score: 0.9218 - val_iou_score: 0.8597
# Epoch 99/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1407 - precision: 0.9595 - recall: 0.9611 - f1-score: 0.9602 - iou_score: 0.9252 - val_loss: 0.3015 - val_precision: 0.9124 - val_recall: 0.9334 - val_f1-score: 0.9216 - val_iou_score: 0.8594
# Epoch 100/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1433 - precision: 0.9590 - recall: 0.9603 - f1-score: 0.9596 - iou_score: 0.9241 - val_loss: 0.3017 - val_precision: 0.9225 - val_recall: 0.9282 - val_f1-score: 0.9247 - val_iou_score: 0.8638
#
# Epoch 00100: saving model to mobilenetV2_edge/ckpt_path/100.h5
# Epoch 101/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1473 - precision: 0.9580 - recall: 0.9592 - f1-score: 0.9586 - iou_score: 0.9221 - val_loss: 0.3258 - val_precision: 0.9234 - val_recall: 0.9168 - val_f1-score: 0.9189 - val_iou_score: 0.8551
# Epoch 102/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1449 - precision: 0.9586 - recall: 0.9600 - f1-score: 0.9592 - iou_score: 0.9233 - val_loss: 0.2960 - val_precision: 0.9169 - val_recall: 0.9388 - val_f1-score: 0.9268 - val_iou_score: 0.8680
# Epoch 103/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1399 - precision: 0.9595 - recall: 0.9613 - f1-score: 0.9603 - iou_score: 0.9254 - val_loss: 0.2887 - val_precision: 0.9133 - val_recall: 0.9391 - val_f1-score: 0.9245 - val_iou_score: 0.8647
# Epoch 104/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1496 - precision: 0.9572 - recall: 0.9589 - f1-score: 0.9579 - iou_score: 0.9210 - val_loss: 0.3224 - val_precision: 0.9270 - val_recall: 0.9111 - val_f1-score: 0.9182 - val_iou_score: 0.8534
# Epoch 105/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1519 - precision: 0.9569 - recall: 0.9584 - f1-score: 0.9576 - iou_score: 0.9202 - val_loss: 0.3182 - val_precision: 0.9143 - val_recall: 0.9245 - val_f1-score: 0.9184 - val_iou_score: 0.8539
# Epoch 106/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1510 - precision: 0.9566 - recall: 0.9586 - f1-score: 0.9575 - iou_score: 0.9203 - val_loss: 0.3139 - val_precision: 0.9227 - val_recall: 0.9141 - val_f1-score: 0.9175 - val_iou_score: 0.8521
# Epoch 107/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1389 - precision: 0.9601 - recall: 0.9613 - f1-score: 0.9606 - iou_score: 0.9260 - val_loss: 0.2969 - val_precision: 0.9218 - val_recall: 0.9294 - val_f1-score: 0.9248 - val_iou_score: 0.8644
# Epoch 108/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1341 - precision: 0.9613 - recall: 0.9629 - f1-score: 0.9621 - iou_score: 0.9285 - val_loss: 0.2573 - val_precision: 0.9337 - val_recall: 0.9322 - val_f1-score: 0.9324 - val_iou_score: 0.8776
# Epoch 109/1000
# 310/310 [==============================] - 392s 1s/step - loss: 0.1336 - precision: 0.9617 - recall: 0.9630 - f1-score: 0.9623 - iou_score: 0.9289 - val_loss: 0.2793 - val_precision: 0.9221 - val_recall: 0.9329 - val_f1-score: 0.9268 - val_iou_score: 0.8682
# Epoch 110/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.1570 - precision: 0.9552 - recall: 0.9565 - f1-score: 0.9558 - iou_score: 0.9173 - val_loss: 0.2919 - val_precision: 0.9208 - val_recall: 0.9312 - val_f1-score: 0.9249 - val_iou_score: 0.8643
# Epoch 111/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.1498 - precision: 0.9571 - recall: 0.9587 - f1-score: 0.9578 - iou_score: 0.9210 - val_loss: 0.5529 - val_precision: 0.8694 - val_recall: 0.8652 - val_f1-score: 0.8638 - val_iou_score: 0.7704
# Epoch 112/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1621 - precision: 0.9538 - recall: 0.9551 - f1-score: 0.9543 - iou_score: 0.9146 - val_loss: 0.2884 - val_precision: 0.9223 - val_recall: 0.9259 - val_f1-score: 0.9234 - val_iou_score: 0.8628
# Epoch 113/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1385 - precision: 0.9597 - recall: 0.9616 - f1-score: 0.9606 - iou_score: 0.9259 - val_loss: 0.2866 - val_precision: 0.9193 - val_recall: 0.9314 - val_f1-score: 0.9246 - val_iou_score: 0.8646
# Epoch 114/1000
# 310/310 [==============================] - 386s 1s/step - loss: 0.1385 - precision: 0.9601 - recall: 0.9618 - f1-score: 0.9609 - iou_score: 0.9263 - val_loss: 0.2668 - val_precision: 0.9298 - val_recall: 0.9347 - val_f1-score: 0.9317 - val_iou_score: 0.8754
# Epoch 115/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1312 - precision: 0.9621 - recall: 0.9637 - f1-score: 0.9629 - iou_score: 0.9300 - val_loss: 0.2830 - val_precision: 0.9332 - val_recall: 0.9256 - val_f1-score: 0.9286 - val_iou_score: 0.8706
# Epoch 116/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1291 - precision: 0.9628 - recall: 0.9642 - f1-score: 0.9635 - iou_score: 0.9310 - val_loss: 0.2616 - val_precision: 0.9329 - val_recall: 0.9361 - val_f1-score: 0.9341 - val_iou_score: 0.8794
# Epoch 117/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.1324 - precision: 0.9618 - recall: 0.9632 - f1-score: 0.9625 - iou_score: 0.9293 - val_loss: 0.2736 - val_precision: 0.9381 - val_recall: 0.9245 - val_f1-score: 0.9305 - val_iou_score: 0.8744
# Epoch 118/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1348 - precision: 0.9609 - recall: 0.9626 - f1-score: 0.9617 - iou_score: 0.9279 - val_loss: 1.9106 - val_precision: 0.8286 - val_recall: 0.5843 - val_f1-score: 0.5958 - val_iou_score: 0.4558
# Epoch 119/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1973 - precision: 0.9445 - recall: 0.9467 - f1-score: 0.9453 - iou_score: 0.8988 - val_loss: 0.3283 - val_precision: 0.8962 - val_recall: 0.9379 - val_f1-score: 0.9139 - val_iou_score: 0.8481
# Epoch 120/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1485 - precision: 0.9575 - recall: 0.9588 - f1-score: 0.9581 - iou_score: 0.9213 - val_loss: 0.2849 - val_precision: 0.9222 - val_recall: 0.9285 - val_f1-score: 0.9248 - val_iou_score: 0.8645
# Epoch 121/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1397 - precision: 0.9595 - recall: 0.9614 - f1-score: 0.9604 - iou_score: 0.9255 - val_loss: 0.2903 - val_precision: 0.9191 - val_recall: 0.9289 - val_f1-score: 0.9233 - val_iou_score: 0.8618
# Epoch 122/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1349 - precision: 0.9609 - recall: 0.9626 - f1-score: 0.9617 - iou_score: 0.9279 - val_loss: 0.2638 - val_precision: 0.9247 - val_recall: 0.9390 - val_f1-score: 0.9310 - val_iou_score: 0.8753
# Epoch 123/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1280 - precision: 0.9631 - recall: 0.9647 - f1-score: 0.9639 - iou_score: 0.9317 - val_loss: 0.2647 - val_precision: 0.9306 - val_recall: 0.9398 - val_f1-score: 0.9346 - val_iou_score: 0.8806
# Epoch 124/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.1397 - precision: 0.9600 - recall: 0.9613 - f1-score: 0.9605 - iou_score: 0.9258 - val_loss: 0.3364 - val_precision: 0.9092 - val_recall: 0.9174 - val_f1-score: 0.9125 - val_iou_score: 0.8443
# Epoch 125/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1535 - precision: 0.9563 - recall: 0.9579 - f1-score: 0.9570 - iou_score: 0.9193 - val_loss: 0.3308 - val_precision: 0.9040 - val_recall: 0.9269 - val_f1-score: 0.9135 - val_iou_score: 0.8458
#
# Epoch 00125: saving model to mobilenetV2_edge/ckpt_path/125.h5
# Epoch 126/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1482 - precision: 0.9574 - recall: 0.9592 - f1-score: 0.9582 - iou_score: 0.9216 - val_loss: 0.2765 - val_precision: 0.9274 - val_recall: 0.9305 - val_f1-score: 0.9284 - val_iou_score: 0.8707
# Epoch 127/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1356 - precision: 0.9609 - recall: 0.9626 - f1-score: 0.9617 - iou_score: 0.9279 - val_loss: 0.2515 - val_precision: 0.9351 - val_recall: 0.9313 - val_f1-score: 0.9327 - val_iou_score: 0.8778
# Epoch 128/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1288 - precision: 0.9631 - recall: 0.9643 - f1-score: 0.9636 - iou_score: 0.9312 - val_loss: 0.2653 - val_precision: 0.9343 - val_recall: 0.9277 - val_f1-score: 0.9305 - val_iou_score: 0.8742
# Epoch 129/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1293 - precision: 0.9627 - recall: 0.9644 - f1-score: 0.9635 - iou_score: 0.9310 - val_loss: 0.2713 - val_precision: 0.9275 - val_recall: 0.9345 - val_f1-score: 0.9305 - val_iou_score: 0.8737
# Epoch 130/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.1388 - precision: 0.9601 - recall: 0.9616 - f1-score: 0.9608 - iou_score: 0.9261 - val_loss: 0.2580 - val_precision: 0.9312 - val_recall: 0.9354 - val_f1-score: 0.9329 - val_iou_score: 0.8777
# Epoch 131/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1287 - precision: 0.9629 - recall: 0.9644 - f1-score: 0.9636 - iou_score: 0.9313 - val_loss: 0.2541 - val_precision: 0.9346 - val_recall: 0.9341 - val_f1-score: 0.9338 - val_iou_score: 0.8793
# Epoch 132/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1251 - precision: 0.9640 - recall: 0.9654 - f1-score: 0.9647 - iou_score: 0.9332 - val_loss: 0.2618 - val_precision: 0.9359 - val_recall: 0.9340 - val_f1-score: 0.9345 - val_iou_score: 0.8807
# Epoch 133/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1347 - precision: 0.9613 - recall: 0.9627 - f1-score: 0.9620 - iou_score: 0.9283 - val_loss: 0.2832 - val_precision: 0.9203 - val_recall: 0.9431 - val_f1-score: 0.9305 - val_iou_score: 0.8741
# Epoch 134/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1270 - precision: 0.9634 - recall: 0.9649 - f1-score: 0.9641 - iou_score: 0.9322 - val_loss: 0.2862 - val_precision: 0.9266 - val_recall: 0.9322 - val_f1-score: 0.9286 - val_iou_score: 0.8710
# Epoch 135/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1277 - precision: 0.9632 - recall: 0.9648 - f1-score: 0.9640 - iou_score: 0.9319 - val_loss: 0.2769 - val_precision: 0.9265 - val_recall: 0.9347 - val_f1-score: 0.9300 - val_iou_score: 0.8732
# Epoch 136/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1496 - precision: 0.9576 - recall: 0.9594 - f1-score: 0.9584 - iou_score: 0.9218 - val_loss: 0.4185 - val_precision: 0.8837 - val_recall: 0.9125 - val_f1-score: 0.8953 - val_iou_score: 0.8175
# Epoch 137/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1466 - precision: 0.9580 - recall: 0.9595 - f1-score: 0.9586 - iou_score: 0.9223 - val_loss: 0.2911 - val_precision: 0.9258 - val_recall: 0.9273 - val_f1-score: 0.9258 - val_iou_score: 0.8666
# Epoch 138/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1284 - precision: 0.9631 - recall: 0.9645 - f1-score: 0.9638 - iou_score: 0.9315 - val_loss: 0.2738 - val_precision: 0.9275 - val_recall: 0.9307 - val_f1-score: 0.9285 - val_iou_score: 0.8710
# Epoch 139/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1278 - precision: 0.9631 - recall: 0.9649 - f1-score: 0.9639 - iou_score: 0.9318 - val_loss: 0.2665 - val_precision: 0.9332 - val_recall: 0.9307 - val_f1-score: 0.9314 - val_iou_score: 0.8758
# Epoch 140/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1280 - precision: 0.9630 - recall: 0.9645 - f1-score: 0.9637 - iou_score: 0.9314 - val_loss: 0.2639 - val_precision: 0.9316 - val_recall: 0.9370 - val_f1-score: 0.9339 - val_iou_score: 0.8793
# Epoch 141/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1266 - precision: 0.9636 - recall: 0.9652 - f1-score: 0.9643 - iou_score: 0.9325 - val_loss: 0.2792 - val_precision: 0.9255 - val_recall: 0.9371 - val_f1-score: 0.9306 - val_iou_score: 0.8740
# Epoch 142/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.1250 - precision: 0.9639 - recall: 0.9656 - f1-score: 0.9647 - iou_score: 0.9332 - val_loss: 0.2700 - val_precision: 0.9367 - val_recall: 0.9281 - val_f1-score: 0.9317 - val_iou_score: 0.8762
# Epoch 143/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1230 - precision: 0.9644 - recall: 0.9661 - f1-score: 0.9652 - iou_score: 0.9342 - val_loss: 0.2814 - val_precision: 0.9357 - val_recall: 0.9248 - val_f1-score: 0.9296 - val_iou_score: 0.8734
# Epoch 144/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1366 - precision: 0.9612 - recall: 0.9629 - f1-score: 0.9620 - iou_score: 0.9283 - val_loss: 0.4403 - val_precision: 0.9066 - val_recall: 0.8796 - val_f1-score: 0.8902 - val_iou_score: 0.8123
# Epoch 145/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1540 - precision: 0.9558 - recall: 0.9576 - f1-score: 0.9566 - iou_score: 0.9187 - val_loss: 0.3262 - val_precision: 0.9121 - val_recall: 0.9281 - val_f1-score: 0.9191 - val_iou_score: 0.8554
# Epoch 146/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.1349 - precision: 0.9612 - recall: 0.9626 - f1-score: 0.9619 - iou_score: 0.9281 - val_loss: 0.2699 - val_precision: 0.9221 - val_recall: 0.9417 - val_f1-score: 0.9310 - val_iou_score: 0.8747
# Epoch 147/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1338 - precision: 0.9614 - recall: 0.9633 - f1-score: 0.9623 - iou_score: 0.9288 - val_loss: 0.2623 - val_precision: 0.9285 - val_recall: 0.9336 - val_f1-score: 0.9306 - val_iou_score: 0.8745
# Epoch 148/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1247 - precision: 0.9640 - recall: 0.9657 - f1-score: 0.9648 - iou_score: 0.9334 - val_loss: 0.2870 - val_precision: 0.9293 - val_recall: 0.9292 - val_f1-score: 0.9285 - val_iou_score: 0.8703
# Epoch 149/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1297 - precision: 0.9626 - recall: 0.9642 - f1-score: 0.9634 - iou_score: 0.9308 - val_loss: 0.2784 - val_precision: 0.9320 - val_recall: 0.9300 - val_f1-score: 0.9304 - val_iou_score: 0.8737
# Epoch 150/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.1256 - precision: 0.9636 - recall: 0.9654 - f1-score: 0.9645 - iou_score: 0.9328 - val_loss: 0.2610 - val_precision: 0.9335 - val_recall: 0.9389 - val_f1-score: 0.9357 - val_iou_score: 0.8823
# Epoch 00150: saving model to mobilenetV2_edge/ckpt_path/150.h5
# Epoch 151/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1258 - precision: 0.9637 - recall: 0.9652 - f1-score: 0.9644 - iou_score: 0.9328 - val_loss: 0.2859 - val_precision: 0.9278 - val_recall: 0.9305 - val_f1-score: 0.9285 - val_iou_score: 0.8704
# Epoch 152/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1228 - precision: 0.9646 - recall: 0.9662 - f1-score: 0.9654 - iou_score: 0.9344 - val_loss: 0.2748 - val_precision: 0.9273 - val_recall: 0.9342 - val_f1-score: 0.9299 - val_iou_score: 0.8735
# Epoch 153/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.1225 - precision: 0.9646 - recall: 0.9664 - f1-score: 0.9655 - iou_score: 0.9346 - val_loss: 0.2410 - val_precision: 0.9334 - val_recall: 0.9438 - val_f1-score: 0.9380 - val_iou_score: 0.8870
# Epoch 154/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1246 - precision: 0.9644 - recall: 0.9659 - f1-score: 0.9651 - iou_score: 0.9339 - val_loss: 0.3303 - val_precision: 0.9257 - val_recall: 0.9122 - val_f1-score: 0.9179 - val_iou_score: 0.8525
# Epoch 155/1000
# 310/310 [==============================] - 403s 1s/step - loss: 0.1481 - precision: 0.9582 - recall: 0.9596 - f1-score: 0.9588 - iou_score: 0.9225 - val_loss: 0.3671 - val_precision: 0.9063 - val_recall: 0.9197 - val_f1-score: 0.9116 - val_iou_score: 0.8428
# Epoch 156/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1550 - precision: 0.9555 - recall: 0.9575 - f1-score: 0.9564 - iou_score: 0.9182 - val_loss: 0.3109 - val_precision: 0.9216 - val_recall: 0.9216 - val_f1-score: 0.9208 - val_iou_score: 0.8576
# Epoch 157/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.1325 - precision: 0.9619 - recall: 0.9636 - f1-score: 0.9627 - iou_score: 0.9295 - val_loss: 0.2739 - val_precision: 0.9287 - val_recall: 0.9335 - val_f1-score: 0.9306 - val_iou_score: 0.8739
# Epoch 158/1000
# 310/310 [==============================] - 403s 1s/step - loss: 0.1271 - precision: 0.9634 - recall: 0.9649 - f1-score: 0.9641 - iou_score: 0.9322 - val_loss: 0.3018 - val_precision: 0.9141 - val_recall: 0.9273 - val_f1-score: 0.9195 - val_iou_score: 0.8548
# Epoch 159/1000
# 310/310 [==============================] - 404s 1s/step - loss: 0.1260 - precision: 0.9636 - recall: 0.9649 - f1-score: 0.9642 - iou_score: 0.9324 - val_loss: 0.2550 - val_precision: 0.9321 - val_recall: 0.9401 - val_f1-score: 0.9356 - val_iou_score: 0.8826
# Epoch 160/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.1240 - precision: 0.9643 - recall: 0.9658 - f1-score: 0.9650 - iou_score: 0.9338 - val_loss: 0.2687 - val_precision: 0.9299 - val_recall: 0.9385 - val_f1-score: 0.9335 - val_iou_score: 0.8790
# Epoch 161/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1231 - precision: 0.9645 - recall: 0.9662 - f1-score: 0.9653 - iou_score: 0.9343 - val_loss: 0.2572 - val_precision: 0.9311 - val_recall: 0.9409 - val_f1-score: 0.9354 - val_iou_score: 0.8823
# Epoch 162/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.1213 - precision: 0.9650 - recall: 0.9666 - f1-score: 0.9658 - iou_score: 0.9351 - val_loss: 0.2816 - val_precision: 0.9286 - val_recall: 0.9282 - val_f1-score: 0.9277 - val_iou_score: 0.8696
# Epoch 163/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.1209 - precision: 0.9651 - recall: 0.9666 - f1-score: 0.9658 - iou_score: 0.9353 - val_loss: 0.2579 - val_precision: 0.9285 - val_recall: 0.9432 - val_f1-score: 0.9351 - val_iou_score: 0.8820
# Epoch 164/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.1208 - precision: 0.9651 - recall: 0.9669 - f1-score: 0.9660 - iou_score: 0.9355 - val_loss: 0.3001 - val_precision: 0.9139 - val_recall: 0.9382 - val_f1-score: 0.9244 - val_iou_score: 0.8645
# Epoch 165/1000
# 310/310 [==============================] - 402s 1s/step - loss: 0.1194 - precision: 0.9655 - recall: 0.9673 - f1-score: 0.9664 - iou_score: 0.9362 - val_loss: 0.2581 - val_precision: 0.9317 - val_recall: 0.9378 - val_f1-score: 0.9342 - val_iou_score: 0.8804
# Epoch 166/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1183 - precision: 0.9659 - recall: 0.9676 - f1-score: 0.9667 - iou_score: 0.9368 - val_loss: 0.2991 - val_precision: 0.9333 - val_recall: 0.9196 - val_f1-score: 0.9255 - val_iou_score: 0.8648
# Epoch 167/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1226 - precision: 0.9646 - recall: 0.9662 - f1-score: 0.9654 - iou_score: 0.9344 - val_loss: 0.2406 - val_precision: 0.9345 - val_recall: 0.9406 - val_f1-score: 0.9370 - val_iou_score: 0.8856
# Epoch 168/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1214 - precision: 0.9649 - recall: 0.9664 - f1-score: 0.9656 - iou_score: 0.9349 - val_loss: 0.2927 - val_precision: 0.9204 - val_recall: 0.9410 - val_f1-score: 0.9295 - val_iou_score: 0.8723
# Epoch 169/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.1207 - precision: 0.9653 - recall: 0.9669 - f1-score: 0.9661 - iou_score: 0.9356 - val_loss: 0.2639 - val_precision: 0.9315 - val_recall: 0.9369 - val_f1-score: 0.9337 - val_iou_score: 0.8795
# Epoch 170/1000
# 310/310 [==============================] - 404s 1s/step - loss: 0.1226 - precision: 0.9649 - recall: 0.9663 - f1-score: 0.9656 - iou_score: 0.9347 - val_loss: 0.3113 - val_precision: 0.9241 - val_recall: 0.9229 - val_f1-score: 0.9227 - val_iou_score: 0.8606
# Epoch 171/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.1308 - precision: 0.9627 - recall: 0.9640 - f1-score: 0.9633 - iou_score: 0.9305 - val_loss: 0.3154 - val_precision: 0.9245 - val_recall: 0.9236 - val_f1-score: 0.9231 - val_iou_score: 0.8623
# Epoch 172/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1280 - precision: 0.9630 - recall: 0.9647 - f1-score: 0.9638 - iou_score: 0.9316 - val_loss: 0.2911 - val_precision: 0.9308 - val_recall: 0.9262 - val_f1-score: 0.9280 - val_iou_score: 0.8697
# Epoch 173/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.1199 - precision: 0.9652 - recall: 0.9670 - f1-score: 0.9661 - iou_score: 0.9357 - val_loss: 0.2697 - val_precision: 0.9348 - val_recall: 0.9348 - val_f1-score: 0.9343 - val_iou_score: 0.8801
# Epoch 174/1000
# ...
# Epoch 435/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.1006 - precision: 0.9708 - recall: 0.9727 - f1-score: 0.9717 - iou_score: 0.9459 - val_loss: 0.3028 - val_precision: 0.9280 - val_recall: 0.9327 - val_f1-score: 0.9295 - val_iou_score: 0.8722
# Epoch 436/1000
# 310/310 [==============================] - 394s 1s/step - loss: 0.0958 - precision: 0.9723 - recall: 0.9740 - f1-score: 0.9731 - iou_score: 0.9484 - val_loss: 0.2729 - val_precision: 0.9330 - val_recall: 0.9346 - val_f1-score: 0.9332 - val_iou_score: 0.8793
# Epoch 437/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.0945 - precision: 0.9724 - recall: 0.9744 - f1-score: 0.9734 - iou_score: 0.9490 - val_loss: 0.2543 - val_precision: 0.9349 - val_recall: 0.9423 - val_f1-score: 0.9381 - val_iou_score: 0.8871
# Epoch 438/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.0959 - precision: 0.9721 - recall: 0.9740 - f1-score: 0.9730 - iou_score: 0.9484 - val_loss: 0.2749 - val_precision: 0.9341 - val_recall: 0.9379 - val_f1-score: 0.9353 - val_iou_score: 0.8820
# Epoch 439/1000
# 310/310 [==============================] - 393s 1s/step - loss: 0.1006 - precision: 0.9708 - recall: 0.9727 - f1-score: 0.9717 - iou_score: 0.9460 - val_loss: 0.2855 - val_precision: 0.9402 - val_recall: 0.9294 - val_f1-score: 0.9341 - val_iou_score: 0.8799
# Epoch 440/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.0966 - precision: 0.9719 - recall: 0.9737 - f1-score: 0.9728 - iou_score: 0.9479 - val_loss: 0.2430 - val_precision: 0.9427 - val_recall: 0.9399 - val_f1-score: 0.9410 - val_iou_score: 0.8919
# Epoch 441/1000
# 310/310 [==============================] - 403s 1s/step - loss: 0.1053 - precision: 0.9699 - recall: 0.9715 - f1-score: 0.9707 - iou_score: 0.9440 - val_loss: 0.2875 - val_precision: 0.9346 - val_recall: 0.9314 - val_f1-score: 0.9323 - val_iou_score: 0.8775
# Epoch 442/1000
# 310/310 [==============================] - 404s 1s/step - loss: 0.1084 - precision: 0.9691 - recall: 0.9709 - f1-score: 0.9700 - iou_score: 0.9426 - val_loss: 0.2907 - val_precision: 0.9350 - val_recall: 0.9296 - val_f1-score: 0.9317 - val_iou_score: 0.8762
# Epoch 443/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.0975 - precision: 0.9717 - recall: 0.9735 - f1-score: 0.9726 - iou_score: 0.9475 - val_loss: 0.2800 - val_precision: 0.9318 - val_recall: 0.9378 - val_f1-score: 0.9341 - val_iou_score: 0.8810
# Epoch 444/1000
# 310/310 [==============================] - 404s 1s/step - loss: 0.0954 - precision: 0.9724 - recall: 0.9740 - f1-score: 0.9732 - iou_score: 0.9486 - val_loss: 0.2494 - val_precision: 0.9383 - val_recall: 0.9414 - val_f1-score: 0.9394 - val_iou_score: 0.8895
# Epoch 445/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.0950 - precision: 0.9725 - recall: 0.9742 - f1-score: 0.9733 - iou_score: 0.9489 - val_loss: 0.2832 - val_precision: 0.9354 - val_recall: 0.9327 - val_f1-score: 0.9332 - val_iou_score: 0.8792
# Epoch 446/1000
# 310/310 [==============================] - 406s 1s/step - loss: 0.1016 - precision: 0.9707 - recall: 0.9724 - f1-score: 0.9715 - iou_score: 0.9456 - val_loss: 0.3439 - val_precision: 0.9279 - val_recall: 0.9247 - val_f1-score: 0.9253 - val_iou_score: 0.8651
# Epoch 447/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1032 - precision: 0.9703 - recall: 0.9720 - f1-score: 0.9711 - iou_score: 0.9448 - val_loss: 0.2687 - val_precision: 0.9338 - val_recall: 0.9399 - val_f1-score: 0.9362 - val_iou_score: 0.8840
# Epoch 448/1000
# 310/310 [==============================] - 402s 1s/step - loss: 0.0951 - precision: 0.9724 - recall: 0.9742 - f1-score: 0.9733 - iou_score: 0.9488 - val_loss: 0.2674 - val_precision: 0.9333 - val_recall: 0.9406 - val_f1-score: 0.9365 - val_iou_score: 0.8843
# Epoch 449/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.0939 - precision: 0.9727 - recall: 0.9746 - f1-score: 0.9736 - iou_score: 0.9495 - val_loss: 0.2736 - val_precision: 0.9359 - val_recall: 0.9373 - val_f1-score: 0.9360 - val_iou_score: 0.8833
# Epoch 450/1000
# 310/310 [==============================] - 403s 1s/step - loss: 0.0943 - precision: 0.9726 - recall: 0.9744 - f1-score: 0.9734 - iou_score: 0.9491 - val_loss: 0.2802 - val_precision: 0.9294 - val_recall: 0.9395 - val_f1-score: 0.9336 - val_iou_score: 0.8796
#
# Epoch 00450: saving model to mobilenetV2_edge/ckpt_path/450.h5
# Epoch 451/1000
# 310/310 [==============================] - 402s 1s/step - loss: 0.0934 - precision: 0.9729 - recall: 0.9746 - f1-score: 0.9738 - iou_score: 0.9497 - val_loss: 0.2758 - val_precision: 0.9335 - val_recall: 0.9402 - val_f1-score: 0.9365 - val_iou_score: 0.8843
# Epoch 452/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.0955 - precision: 0.9721 - recall: 0.9742 - f1-score: 0.9731 - iou_score: 0.9485 - val_loss: 0.2933 - val_precision: 0.9401 - val_recall: 0.9262 - val_f1-score: 0.9322 - val_iou_score: 0.8771
# Epoch 453/1000
# 310/310 [==============================] - 403s 1s/step - loss: 0.0968 - precision: 0.9717 - recall: 0.9736 - f1-score: 0.9727 - iou_score: 0.9477 - val_loss: 0.2672 - val_precision: 0.9387 - val_recall: 0.9409 - val_f1-score: 0.9394 - val_iou_score: 0.8887
# Epoch 454/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.0958 - precision: 0.9721 - recall: 0.9740 - f1-score: 0.9730 - iou_score: 0.9484 - val_loss: 0.2820 - val_precision: 0.9379 - val_recall: 0.9367 - val_f1-score: 0.9366 - val_iou_score: 0.8846
# Epoch 455/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.0948 - precision: 0.9725 - recall: 0.9742 - f1-score: 0.9734 - iou_score: 0.9490 - val_loss: 0.2746 - val_precision: 0.9332 - val_recall: 0.9389 - val_f1-score: 0.9355 - val_iou_score: 0.8826
# Epoch 456/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.0986 - precision: 0.9712 - recall: 0.9732 - f1-score: 0.9722 - iou_score: 0.9468 - val_loss: 0.3024 - val_precision: 0.9307 - val_recall: 0.9345 - val_f1-score: 0.9320 - val_iou_score: 0.8765
# Epoch 457/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.0959 - precision: 0.9722 - recall: 0.9739 - f1-score: 0.9731 - iou_score: 0.9484 - val_loss: 0.2719 - val_precision: 0.9409 - val_recall: 0.9325 - val_f1-score: 0.9361 - val_iou_score: 0.8838
# Epoch 458/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.0935 - precision: 0.9728 - recall: 0.9747 - f1-score: 0.9737 - iou_score: 0.9496 - val_loss: 0.2712 - val_precision: 0.9422 - val_recall: 0.9307 - val_f1-score: 0.9359 - val_iou_score: 0.8834
# Epoch 459/1000
# 310/310 [==============================] - 395s 1s/step - loss: 0.0961 - precision: 0.9723 - recall: 0.9738 - f1-score: 0.9730 - iou_score: 0.9483 - val_loss: 0.2570 - val_precision: 0.9406 - val_recall: 0.9401 - val_f1-score: 0.9399 - val_iou_score: 0.8899
# Epoch 460/1000
# 310/310 [==============================] - 396s 1s/step - loss: 0.0986 - precision: 0.9716 - recall: 0.9735 - f1-score: 0.9725 - iou_score: 0.9473 - val_loss: 0.2931 - val_precision: 0.9343 - val_recall: 0.9278 - val_f1-score: 0.9304 - val_iou_score: 0.8743
# Epoch 461/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.1016 - precision: 0.9707 - recall: 0.9725 - f1-score: 0.9716 - iou_score: 0.9456 - val_loss: 0.2833 - val_precision: 0.9347 - val_recall: 0.9366 - val_f1-score: 0.9352 - val_iou_score: 0.8813
# Epoch 462/1000
# 310/310 [==============================] - 402s 1s/step - loss: 0.0936 - precision: 0.9728 - recall: 0.9747 - f1-score: 0.9737 - iou_score: 0.9496 - val_loss: 0.2811 - val_precision: 0.9322 - val_recall: 0.9361 - val_f1-score: 0.9336 - val_iou_score: 0.8795
# Epoch 463/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.0944 - precision: 0.9726 - recall: 0.9743 - f1-score: 0.9734 - iou_score: 0.9491 - val_loss: 0.2828 - val_precision: 0.9351 - val_recall: 0.9335 - val_f1-score: 0.9338 - val_iou_score: 0.8797
# Epoch 464/1000
# 310/310 [==============================] - 407s 1s/step - loss: 0.0959 - precision: 0.9721 - recall: 0.9740 - f1-score: 0.9730 - iou_score: 0.9483 - val_loss: 0.2908 - val_precision: 0.9346 - val_recall: 0.9317 - val_f1-score: 0.9326 - val_iou_score: 0.8776
# Epoch 465/1000
# 310/310 [==============================] - 402s 1s/step - loss: 0.0959 - precision: 0.9721 - recall: 0.9740 - f1-score: 0.9730 - iou_score: 0.9484 - val_loss: 0.2942 - val_precision: 0.9290 - val_recall: 0.9339 - val_f1-score: 0.9309 - val_iou_score: 0.8747
# Epoch 466/1000
# 310/310 [==============================] - 404s 1s/step - loss: 0.0984 - precision: 0.9716 - recall: 0.9734 - f1-score: 0.9725 - iou_score: 0.9473 - val_loss: 0.2735 - val_precision: 0.9350 - val_recall: 0.9351 - val_f1-score: 0.9346 - val_iou_score: 0.8813
# Epoch 467/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.0992 - precision: 0.9711 - recall: 0.9731 - f1-score: 0.9721 - iou_score: 0.9466 - val_loss: 0.2999 - val_precision: 0.9269 - val_recall: 0.9346 - val_f1-score: 0.9295 - val_iou_score: 0.8735
# Epoch 468/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.0924 - precision: 0.9732 - recall: 0.9749 - f1-score: 0.9740 - iou_score: 0.9502 - val_loss: 0.2578 - val_precision: 0.9428 - val_recall: 0.9360 - val_f1-score: 0.9388 - val_iou_score: 0.8887
# Epoch 469/1000
# 310/310 [==============================] - 402s 1s/step - loss: 0.0939 - precision: 0.9728 - recall: 0.9744 - f1-score: 0.9736 - iou_score: 0.9494 - val_loss: 0.2804 - val_precision: 0.9361 - val_recall: 0.9333 - val_f1-score: 0.9341 - val_iou_score: 0.8809
# Epoch 470/1000
# 310/310 [==============================] - 401s 1s/step - loss: 0.1204 - precision: 0.9661 - recall: 0.9678 - f1-score: 0.9668 - iou_score: 0.9371 - val_loss: 0.3660 - val_precision: 0.9306 - val_recall: 0.8989 - val_f1-score: 0.9127 - val_iou_score: 0.8449
# Epoch 471/1000
# 310/310 [==============================] - 402s 1s/step - loss: 0.1225 - precision: 0.9646 - recall: 0.9665 - f1-score: 0.9655 - iou_score: 0.9347 - val_loss: 0.2931 - val_precision: 0.9343 - val_recall: 0.9303 - val_f1-score: 0.9317 - val_iou_score: 0.8760
# Epoch 472/1000
# 310/310 [==============================] - 403s 1s/step - loss: 0.0989 - precision: 0.9714 - recall: 0.9730 - f1-score: 0.9722 - iou_score: 0.9468 - val_loss: 0.2610 - val_precision: 0.9363 - val_recall: 0.9379 - val_f1-score: 0.9367 - val_iou_score: 0.8845
# Epoch 473/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.0944 - precision: 0.9727 - recall: 0.9743 - f1-score: 0.9735 - iou_score: 0.9491 - val_loss: 0.2497 - val_precision: 0.9402 - val_recall: 0.9405 - val_f1-score: 0.9400 - val_iou_score: 0.8898
# Epoch 474/1000
# 310/310 [==============================] - 404s 1s/step - loss: 0.0933 - precision: 0.9729 - recall: 0.9747 - f1-score: 0.9737 - iou_score: 0.9497 - val_loss: 0.2701 - val_precision: 0.9381 - val_recall: 0.9363 - val_f1-score: 0.9368 - val_iou_score: 0.8846
# Epoch 475/1000
# 310/310 [==============================] - 405s 1s/step - loss: 0.0929 - precision: 0.9729 - recall: 0.9748 - f1-score: 0.9738 - iou_score: 0.9498 - val_loss: 0.2833 - val_precision: 0.9328 - val_recall: 0.9364 - val_f1-score: 0.9339 - val_iou_score: 0.8802
#
# Epoch 00475: saving model to mobilenetV2_edge/ckpt_path/475.h5
# Epoch 476/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.0932 - precision: 0.9730 - recall: 0.9748 - f1-score: 0.9738 - iou_score: 0.9498 - val_loss: 0.2929 - val_precision: 0.9325 - val_recall: 0.9364 - val_f1-score: 0.9336 - val_iou_score: 0.8792
# Epoch 477/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.0919 - precision: 0.9733 - recall: 0.9751 - f1-score: 0.9742 - iou_score: 0.9505 - val_loss: 0.2437 - val_precision: 0.9397 - val_recall: 0.9423 - val_f1-score: 0.9407 - val_iou_score: 0.8914
# Epoch 478/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.0912 - precision: 0.9735 - recall: 0.9753 - f1-score: 0.9744 - iou_score: 0.9508 - val_loss: 0.2949 - val_precision: 0.9304 - val_recall: 0.9361 - val_f1-score: 0.9324 - val_iou_score: 0.8774
# Epoch 479/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.0942 - precision: 0.9726 - recall: 0.9744 - f1-score: 0.9735 - iou_score: 0.9492 - val_loss: 0.2758 - val_precision: 0.9395 - val_recall: 0.9361 - val_f1-score: 0.9367 - val_iou_score: 0.8856
# Epoch 480/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.0923 - precision: 0.9732 - recall: 0.9749 - f1-score: 0.9740 - iou_score: 0.9502 - val_loss: 0.2641 - val_precision: 0.9429 - val_recall: 0.9366 - val_f1-score: 0.9391 - val_iou_score: 0.8885
# Epoch 481/1000
# 310/310 [==============================] - 403s 1s/step - loss: 0.0935 - precision: 0.9729 - recall: 0.9746 - f1-score: 0.9738 - iou_score: 0.9497 - val_loss: 0.2817 - val_precision: 0.9349 - val_recall: 0.9355 - val_f1-score: 0.9345 - val_iou_score: 0.8811
# Epoch 482/1000
# 310/310 [==============================] - 399s 1s/step - loss: 0.0933 - precision: 0.9730 - recall: 0.9747 - f1-score: 0.9738 - iou_score: 0.9497 - val_loss: 0.2848 - val_precision: 0.9333 - val_recall: 0.9339 - val_f1-score: 0.9329 - val_iou_score: 0.8790
# Epoch 483/1000
# 310/310 [==============================] - 404s 1s/step - loss: 0.0951 - precision: 0.9723 - recall: 0.9742 - f1-score: 0.9732 - iou_score: 0.9488 - val_loss: 0.2690 - val_precision: 0.9399 - val_recall: 0.9347 - val_f1-score: 0.9366 - val_iou_score: 0.8847
# Epoch 484/1000
# 310/310 [==============================] - 398s 1s/step - loss: 0.0940 - precision: 0.9728 - recall: 0.9746 - f1-score: 0.9736 - iou_score: 0.9495 - val_loss: 0.2839 - val_precision: 0.9364 - val_recall: 0.9300 - val_f1-score: 0.9326 - val_iou_score: 0.8784
# Epoch 485/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.0939 - precision: 0.9728 - recall: 0.9745 - f1-score: 0.9736 - iou_score: 0.9494 - val_loss: 0.2798 - val_precision: 0.9373 - val_recall: 0.9325 - val_f1-score: 0.9343 - val_iou_score: 0.8805
# Epoch 486/1000
# 310/310 [==============================] - 397s 1s/step - loss: 0.1050 - precision: 0.9699 - recall: 0.9717 - f1-score: 0.9707 - iou_score: 0.9440 - val_loss: 0.2758 - val_precision: 0.9369 - val_recall: 0.9321 - val_f1-score: 0.9339 - val_iou_score: 0.8792
# Epoch 487/1000
# 310/310 [==============================] - 400s 1s/step - loss: 0.0931 - precision: 0.9730 - recall: 0.9748 - f1-score: 0.9739 - iou_score: 0.9499 - val_loss: 0.2711 - val_precision: 0.9349 - val_recall: 0.9361 - val_f1-score: 0.9349 - val_iou_score: 0.8820
# Epoch 488/1000
# 310/310 [==============================] - 402s 1s/step - loss: 0.0947 - precision: 0.9724 - recall: 0.9743 - f1-score: 0.9733 - iou_score: 0.9489 - val_loss: 0.2573 - val_precision: 0.9389 - val_recall: 0.9402 - val_f1-score: 0.9392 - val_iou_score: 0.8888
# Epoch 489/1000
# 310/310 [==============================] - 432s 1s/step - loss: 0.0925 - precision: 0.9732 - recall: 0.9749 - f1-score: 0.9740 - iou_score: 0.9502 - val_loss: 0.2753 - val_precision: 0.9356 - val_recall: 0.9328 - val_f1-score: 0.9337 - val_iou_score: 0.8802
# Epoch 490/1000
# 310/310 [==============================] - 446s 1s/step - loss: 0.1011 - precision: 0.9709 - recall: 0.9727 - f1-score: 0.9718 - iou_score: 0.9460 - val_loss: 0.2766 - val_precision: 0.9389 - val_recall: 0.9326 - val_f1-score: 0.9352 - val_iou_score: 0.8820
# Epoch 491/1000
# 310/310 [==============================] - 425s 1s/step - loss: 0.0991 - precision: 0.9713 - recall: 0.9731 - f1-score: 0.9722 - iou_score: 0.9468 - val_loss: 0.2593 - val_precision: 0.9388 - val_recall: 0.9406 - val_f1-score: 0.9392 - val_iou_score: 0.8890
# Epoch 492/1000
# 237/310 [=====================>........] - ETA: 1:23 - loss: 0.0926 - precision: 0.9731 - recall: 0.9750 - f1-score: 0.9740 - iou_score: 0.9501

# %%
# model.save('/content/drive/MyDrive/LaneSeg/Deeplabv3p_xception_fullsize_Lane_Seg_0036+16.h5')

# %%
# from segmentation_models.losses import cce_jaccard_loss, dice_loss, JaccardLoss
# from segmentation_models.metrics import iou_score, f1_score, precision, recall
# ls = dice_loss + cce_jaccard_loss
# metrics = [precision, recall, f1_score, iou_score] 

# from tensorflow.keras.models import load_model
# model = load_model('mobilenetv2_bs4/ckpt_path/Deeplabv3p_mobilenetv2_200.h5',
#                    custom_objects={'dice_loss_plus_categorical_crossentropy_plus_jaccard_loss':ls,
#                                    'precision':precision, 'recall':recall, 'f1-score':f1_score, 'iou_score':iou_score})

# %%
# !tensorboard --logdir logs --host 0.0.0.0
