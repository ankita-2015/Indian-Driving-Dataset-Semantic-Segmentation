# %%
# !pip install q tensorflow==2.1
# !pip install q keras==2.3.1
# !pip install git+https://github.com/qubvel/segmentation_models

# for str decode error ... run it and restart runtime
# !pip uninstall h5py -y
# !pip install h5py==2.10.0
# Out:
# Found existing installation: h5py 3.5.0
# Uninstalling h5py-3.5.0:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/shutil.py", line 791, in move
#     os.rename(src, real_dst)
# PermissionError: [Errno 13] Permission denied: '/usr/local/lib/python3.8/dist-packages/h5py-3.5.0.dist-info/' -> '/tmp/pip-uninstall-m46lb6rp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 228, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/commands/uninstall.py", line 89, in run
#     uninstall_pathset = req.uninstall(
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/req/req_install.py", line 686, in uninstall
#     uninstalled_pathset.remove(auto_confirm, verbose)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/req/req_uninstall.py", line 394, in remove
#     moved.stash(path)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/req/req_uninstall.py", line 283, in stash
#     renames(path, new_path)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/misc.py", line 352, in renames
#     shutil.move(old, new)
#   File "/usr/lib/python3.8/shutil.py", line 809, in move
#     rmtree(src)
#   File "/usr/lib/python3.8/shutil.py", line 718, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/usr/lib/python3.8/shutil.py", line 675, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/usr/lib/python3.8/shutil.py", line 673, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# PermissionError: [Errno 13] Permission denied: 'METADATA'
# Defaulting to user installation because normal site-packages is not writeable
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 5.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.8/dist-packages (from h5py==2.10.0) (1.21.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from h5py==2.10.0) (1.14.0)
# Installing collected packages: h5py
# Successfully installed h5py-2.10.0
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
i = !ls Dataset/images/
l = !ls Dataset/masks/
len(i), len(l)
# Out:
# (2975, 2975)

# %%
l[-5:], i[-5:]
# Out:
# (['zurich_000117_000019_gtFine_labelTrainIds.png',
#   'zurich_000118_000019_gtFine_labelTrainIds.png',
#   'zurich_000119_000019_gtFine_labelTrainIds.png',
#   'zurich_000120_000019_gtFine_labelTrainIds.png',
#   'zurich_000121_000019_gtFine_labelTrainIds.png'],
#  ['zurich_000117_000019_leftImg8bit.png',
#   'zurich_000118_000019_leftImg8bit.png',
#   'zurich_000119_000019_leftImg8bit.png',
#   'zurich_000120_000019_leftImg8bit.png',
#   'zurich_000121_000019_leftImg8bit.png'])

# %%
import cv2
from glob import glob
import os
import numpy as np

# 100 = background
# 101 = sidewalk(1)
# 102 = obstacle(person(11), rider, car, truck, bus, train, motorcycle, bicycle(18))
# 103 = traffic (5,6,7)
# 104 = road(0)

l = glob('Dataset/masks/*')
m = cv2.imread(l[2970],0)
m.shape
np.unique(m)
# Out:
# array([0, 1, 2, 3, 4], dtype=uint8)

# %%
import os
len(os.listdir('Dataset/images/')), len(os.listdir('Dataset/masks/'))
# Out:
# (2975, 2975)

# %%
import numpy as np
import cv2
import os
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf

def load_dataset(dataset_path):
    images = sorted(glob(os.path.join(dataset_path, "images/*")))
    masks = sorted(glob(os.path.join(dataset_path, "masks/*")))

    train_x, test_x, train_y, test_y = train_test_split(images,masks, test_size=0.168, 
                                                        random_state=168, shuffle=True)
    return train_x, train_y, test_x, test_y

train_x, train_y, val_x, val_y = load_dataset('Dataset')
print(len(train_x), len(train_y), len(val_x), len(val_y))
# Out:
# 2475 2475 500 500

# %%
train_X_y_paths = list(zip(train_x, train_y))
val_X_y_paths = list(zip(val_x, val_y))

# %%
def shuffle(samples):
    index = np.random.permutation(len(samples))
    return np.array(samples)[index]

def read_img(img):
    X_image = cv2.imread(img)[:,:,::-1] # convert bgr to rgb
    X_image = cv2.resize(X_image, (512, 512))    
    X_image = X_image / 255.0
    X_image = X_image.astype(np.float32)
    return X_image

def read_label(label_img):
    Y_image = cv2.imread(label_img, 0)    
    Y_image = cv2.resize(Y_image, (512, 512),fx = 1, fy = 1,interpolation = cv2.INTER_NEAREST)    
    Y_image = tf.one_hot(Y_image, 5)
#     Y_image.set_shape([512, 1024, 3])
    Y_image = np.array(Y_image)
    Y_image = Y_image.astype(np.float32)
    return Y_image

def get_data_generator(samples,batch_size):
    while True:
        for offset in range(0, len(samples), batch_size): 
            samples = shuffle(samples)           
            batch_samples = samples[offset:offset+batch_size]
            X_train = []
            Y_train = []                    
            for batch_sample in batch_samples:
                X_image = read_img(img=batch_sample[0])
                Y_image = read_label(label_img=batch_sample[1])
        
                X_train.append(X_image)
                Y_train.append(Y_image)
            yield np.array(X_train), np.array(Y_train)


BATCH_SIZE = 4
train_generator = get_data_generator(train_X_y_paths,batch_size=BATCH_SIZE)
val_generator = get_data_generator(val_X_y_paths,batch_size=BATCH_SIZE)
 
# x_train, y_train = next(train_generator)
# x_val, y_val  = next(val_generator)
 
# print(x_train.shape,y_train.shape)
# print(x_val.shape, y_val.shape)

# %%
# train_X_y_paths[-5:]
# np.unique(y_train[0]), y_train.shape

# %%
# %env SM_FRAMEWORK=tf.keras
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
# -*- coding: utf-8 -*-

""" Deeplabv3+ model for Keras.
This model is based on TF repo:
https://github.com/tensorflow/models/tree/master/research/deeplab
On Pascal VOC, original model gets to 84.56% mIOU
MobileNetv2 backbone is based on this repo:
https://github.com/JonathanCMitchell/mobilenet_v2_keras
# Reference
- [Encoder-Decoder with Atrous Separable Convolution
    for Semantic Image Segmentation](https://arxiv.org/pdf/1802.02611.pdf)
- [Xception: Deep Learning with Depthwise Separable Convolutions]
    (https://arxiv.org/abs/1610.02357)
- [Inverted Residuals and Linear Bottlenecks: Mobile Networks for
    Classification, Detection and Segmentation](https://arxiv.org/abs/1801.04381)
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf

from tensorflow.python.keras.models import Model
from tensorflow.python.keras import layers
from tensorflow.python.keras.layers import Input
from tensorflow.python.keras.layers import Reshape
from tensorflow.python.keras.layers import Activation
from tensorflow.python.keras.layers import Concatenate
from tensorflow.python.keras.layers import Add
from tensorflow.python.keras.layers import Dropout
from tensorflow.python.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Conv2D
from tensorflow.python.keras.layers import DepthwiseConv2D
from tensorflow.python.keras.layers import ZeroPadding2D
from tensorflow.python.keras.layers import GlobalAveragePooling2D
from tensorflow.python.keras.utils.layer_utils import get_source_inputs
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.applications.imagenet_utils import preprocess_input

WEIGHTS_PATH_X = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_MOBILE = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5"

WEIGHTS_PATH_X_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"
WEIGHTS_PATH_MOBILE_CS = "pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"


def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):
    """ SepConv with BN between depthwise & pointwise. Optionally add activation after BN
        Implements right "same" padding for even kernel sizes
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & poinwise convs
            epsilon: epsilon to use in BN layer
    """

    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)

    return x


def _conv2d_same(x, filters, prefix, stride=1, kernel_size=3, rate=1):
    """Implements right 'same' padding for even kernel sizes
        Without this there is a 1 pixel drift when stride = 2
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
    """
    if stride == 1:
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='same', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='valid', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)


def _xception_block(inputs, depth_list, prefix, skip_connection_type, stride,
                    rate=1, depth_activation=False, return_skip=False):
    """ Basic building block of modified Xception network
        Args:
            inputs: input tensor
            depth_list: number of filters in each SepConv layer. len(depth_list) == 3
            prefix: prefix before name
            skip_connection_type: one of {'conv','sum','none'}
            stride: stride at last depthwise conv
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & pointwise convs
            return_skip: flag to return additional tensor after 2 SepConvs for decoder
            """
    residual = inputs
    for i in range(3):
        residual = SepConv_BN(residual,
                              depth_list[i],
                              prefix + '_separable_conv{}'.format(i + 1),
                              stride=stride if i == 2 else 1,
                              rate=rate,
                              depth_activation=depth_activation)
        if i == 1:
            skip = residual
    if skip_connection_type == 'conv':
        shortcut = _conv2d_same(inputs, depth_list[-1], prefix + '_shortcut',
                                kernel_size=1,
                                stride=stride)
        shortcut = BatchNormalization(name=prefix + '_shortcut_BN')(shortcut)
        outputs = layers.add([residual, shortcut])
    elif skip_connection_type == 'sum':
        outputs = layers.add([residual, inputs])
    elif skip_connection_type == 'none':
        outputs = residual
    if return_skip:
        return outputs, skip
    else:
        return outputs


def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id, skip_connection, rate=1):
    in_channels = inputs.shape[-1]#.value  # inputs._keras_shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs
    prefix = 'expanded_conv_{}_'.format(block_id)
    if block_id:
        # Expand

        x = Conv2D(expansion * in_channels, kernel_size=1, padding='same',
                   use_bias=False, activation=None,
                   name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                               name=prefix + 'expand_BN')(x)
        x = Activation(tf.nn.relu6, name=prefix + 'expand_relu')(x)
    else:
        prefix = 'expanded_conv_'
    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None,
                        use_bias=False, padding='same', dilation_rate=(rate, rate),
                        name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'depthwise_BN')(x)

    x = Activation(tf.nn.relu6, name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters,
               kernel_size=1, padding='same', use_bias=False, activation=None,
               name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'project_BN')(x)

    if skip_connection:
        return Add(name=prefix + 'add')([inputs, x])

    # if in_channels == pointwise_filters and stride == 1:
    #    return Add(name='res_connect_' + str(block_id))([inputs, x])

    return x


def Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(512, 512, 3), classes=21, backbone='mobilenetv2',
              OS=16, alpha=1., activation=None):
    """ Instantiates the Deeplabv3+ architecture
    Optionally loads weights pre-trained
    on PASCAL VOC or Cityscapes. This model is available for TensorFlow only.
    # Arguments
        weights: one of 'pascal_voc' (pre-trained on pascal voc),
            'cityscapes' (pre-trained on cityscape) or None (random initialization)
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: shape of input image. format HxWxC
            PASCAL VOC model was trained on (512,512,3) images. None is allowed as shape/width
        classes: number of desired classes. PASCAL VOC has 21 classes, Cityscapes has 19 classes.
            If number of classes not aligned with the weights used, last layer is initialized randomly
        backbone: backbone to use. one of {'xception','mobilenetv2'}
        activation: optional activation to add to the top of the network.
            One of 'softmax', 'sigmoid' or None
        OS: determines input_shape/feature_extractor_output ratio. One of {8,16}.
            Used only for xception backbone.
        alpha: controls the width of the MobileNetV2 network. This is known as the
            width multiplier in the MobileNetV2 paper.
                - If `alpha` < 1.0, proportionally decreases the number
                    of filters in each layer.
                - If `alpha` > 1.0, proportionally increases the number
                    of filters in each layer.
                - If `alpha` = 1, default number of filters from the paper
                    are used at each layer.
            Used only for mobilenetv2 backbone. Pretrained is only available for alpha=1.
    # Returns
        A Keras model instance.
    # Raises
        RuntimeError: If attempting to run this model with a
            backend that does not support separable convolutions.
        ValueError: in case of invalid argument for `weights` or `backbone`
    """

    if not (weights in {'pascal_voc', 'cityscapes', None}):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization), `pascal_voc`, or `cityscapes` '
                         '(pre-trained on PASCAL VOC)')

    if not (backbone in {'xception', 'mobilenetv2'}):
        raise ValueError('The `backbone` argument should be either '
                         '`xception`  or `mobilenetv2` ')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        img_input = input_tensor

    if backbone == 'xception':
        if OS == 8:
            entry_block3_stride = 1
            middle_block_rate = 2  # ! Not mentioned in paper, but required
            exit_block_rates = (2, 4)
            atrous_rates = (12, 24, 36)
        else:
            entry_block3_stride = 2
            middle_block_rate = 1
            exit_block_rates = (1, 2)
            atrous_rates = (6, 12, 18)

        x = Conv2D(32, (3, 3), strides=(2, 2),
                   name='entry_flow_conv1_1', use_bias=False, padding='same')(img_input)
        x = BatchNormalization(name='entry_flow_conv1_1_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _conv2d_same(x, 64, 'entry_flow_conv1_2', kernel_size=3, stride=1)
        x = BatchNormalization(name='entry_flow_conv1_2_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _xception_block(x, [128, 128, 128], 'entry_flow_block1',
                            skip_connection_type='conv', stride=2,
                            depth_activation=False)
        x, skip1 = _xception_block(x, [256, 256, 256], 'entry_flow_block2',
                                   skip_connection_type='conv', stride=2,
                                   depth_activation=False, return_skip=True)

        x = _xception_block(x, [728, 728, 728], 'entry_flow_block3',
                            skip_connection_type='conv', stride=entry_block3_stride,
                            depth_activation=False)
        for i in range(16):
            x = _xception_block(x, [728, 728, 728], 'middle_flow_unit_{}'.format(i + 1),
                                skip_connection_type='sum', stride=1, rate=middle_block_rate,
                                depth_activation=False)

        x = _xception_block(x, [728, 1024, 1024], 'exit_flow_block1',
                            skip_connection_type='conv', stride=1, rate=exit_block_rates[0],
                            depth_activation=False)
        x = _xception_block(x, [1536, 1536, 2048], 'exit_flow_block2',
                            skip_connection_type='none', stride=1, rate=exit_block_rates[1],
                            depth_activation=True)

    else:
        OS = 8
        first_block_filters = _make_divisible(32 * alpha, 8)
        x = Conv2D(first_block_filters,
                   kernel_size=3,
                   strides=(2, 2), padding='same', use_bias=False,
                   name='Conv' if input_shape[2] == 3 else 'Conv_')(img_input)
        x = BatchNormalization(
            epsilon=1e-3, momentum=0.999, name='Conv_BN')(x)
        x = Activation(tf.nn.relu6, name='Conv_Relu6')(x)

        x = _inverted_res_block(x, filters=16, alpha=alpha, stride=1,
                                expansion=1, block_id=0, skip_connection=False)

        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
                                expansion=6, block_id=1, skip_connection=False)
        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=1,
                                expansion=6, block_id=2, skip_connection=True)

        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=2,
                                expansion=6, block_id=3, skip_connection=False)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=4, skip_connection=True)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=5, skip_connection=True)

        # stride in block 6 changed from 2 -> 1, so we need to use rate = 2
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1,  # 1!
                                expansion=6, block_id=6, skip_connection=False)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=7, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=8, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=9, skip_connection=True)

        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=10, skip_connection=False)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=11, skip_connection=True)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=12, skip_connection=True)

        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=2,  # 1!
                                expansion=6, block_id=13, skip_connection=False)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=14, skip_connection=True)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=15, skip_connection=True)

        x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=16, skip_connection=False)

    # end of feature extractor

    # branching for Atrous Spatial Pyramid Pooling

    # Image Feature branch
    shape_before = tf.shape(x)
    b4 = GlobalAveragePooling2D()(x)
    b4_shape = tf.keras.backend.int_shape(b4)
    # from (b_size, channels)->(b_size, 1, 1, channels)
    b4 = Reshape((1, 1, b4_shape[1]))(b4)
    b4 = Conv2D(256, (1, 1), padding='same',
                use_bias=False, name='image_pooling')(b4)
    b4 = BatchNormalization(name='image_pooling_BN', epsilon=1e-5)(b4)
    b4 = Activation(tf.nn.relu)(b4)
    # upsample. have to use compat because of the option align_corners
    size_before = tf.keras.backend.int_shape(x)
    b4 = tf.keras.layers.experimental.preprocessing.Resizing(
            *size_before[1:3], interpolation="bilinear"
        )(b4)
    # simple 1x1
    b0 = Conv2D(256, (1, 1), padding='same', use_bias=False, name='aspp0')(x)
    b0 = BatchNormalization(name='aspp0_BN', epsilon=1e-5)(b0)
    b0 = Activation(tf.nn.relu, name='aspp0_activation')(b0)

    # there are only 2 branches in mobilenetV2. not sure why
    if backbone == 'xception':
        # rate = 6 (12)
        b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
        b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
        b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
        x = Concatenate()([b4, b0, b1, b2, b3])
    else:
        x = Concatenate()([b4, b0])

    x = Conv2D(256, (1, 1), padding='same',
               use_bias=False, name='concat_projection')(x)
    x = BatchNormalization(name='concat_projection_BN', epsilon=1e-5)(x)
    x = Activation(tf.nn.relu)(x)
    x = Dropout(0.1)(x)
    # DeepLab v.3+ decoder

    if backbone == 'xception':
        # Feature projection
        # x4 (x2) block
        skip_size = tf.keras.backend.int_shape(skip1)
        x = tf.keras.layers.experimental.preprocessing.Resizing(
                *skip_size[1:3], interpolation="bilinear"
            )(x)
        dec_skip1 = Conv2D(48, (1, 1), padding='same',
                           use_bias=False, name='feature_projection0')(skip1)
        dec_skip1 = BatchNormalization(
            name='feature_projection0_BN', epsilon=1e-5)(dec_skip1)
        dec_skip1 = Activation(tf.nn.relu)(dec_skip1)
        x = Concatenate()([x, dec_skip1])
        x = SepConv_BN(x, 256, 'decoder_conv0',
                       depth_activation=True, epsilon=1e-5)
        x = SepConv_BN(x, 256, 'decoder_conv1',
                       depth_activation=True, epsilon=1e-5)

    # you can use it with arbitary number of classes
    if (weights == 'pascal_voc' and classes == 21) or (weights == 'cityscapes' and classes == 19):
        last_layer_name = 'logits_semantic'
    else:
        last_layer_name = 'custom_logits_semantic'

    x = Conv2D(classes, (1, 1), padding='same', name=last_layer_name)(x)
    size_before3 = tf.keras.backend.int_shape(img_input)
    x = tf.keras.layers.experimental.preprocessing.Resizing(
            *size_before3[1:3], interpolation="bilinear"
        )(x)
    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    if activation in {'softmax', 'sigmoid'}:
        x = tf.keras.layers.Activation(activation)(x)

    model = Model(inputs, x, name='deeplabv3plus')

    # load weights

    if weights == 'pascal_voc':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_X,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_MOBILE,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    elif weights == 'cityscapes':
        if backbone == 'xception':
#             weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5',
#                                     WEIGHTS_PATH_X_CS,
#                                     cache_subdir='models')
            weights_path = "pretrained_weights/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"    
        else:
#             weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5',
#                                     WEIGHTS_PATH_MOBILE_CS,
#                                     cache_subdir='models')
           weights_path = "pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"
            
        model.load_weights(weights_path, by_name=True)
    return model

def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.
    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].
    # Returns
        Input array scaled to [-1.,1.]
    """
    return preprocess_input(x, mode='tf')

# %%
# !pwd
# Out:
# /home/tensorflow/Documents/Semantic_Segmentation

# %%
model = Deeplabv3(weights='cityscapes', input_shape=(512,512,3), classes=5, 
                  backbone= 'mobilenetv2', #'xception'
                  OS=16, alpha=1, activation='softmax')
# model.load_weights('pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5')

# %%
from segmentation_models.losses import cce_jaccard_loss, dice_loss, JaccardLoss
from segmentation_models.metrics import iou_score, f1_score, precision, recall
ls = dice_loss + cce_jaccard_loss
metrics = [precision, recall, f1_score, iou_score] 

from tensorflow.keras.models import load_model
model = load_model('mobilenetV2_bs4/ckpt_path/84.h5',
                   custom_objects={'dice_loss_plus_categorical_crossentropy_plus_jaccard_loss':ls,
                                   'precision':precision, 'recall':recall, 'f1-score':f1_score, 'iou_score':iou_score})
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
import os, time, keras
# %env SM_FRAMEWORK=tf.keras

import numpy as np
import tensorflow as tf
from segmentation_models.losses import bce_jaccard_loss, dice_loss, JaccardLoss
from segmentation_models.metrics import iou_score, f1_score, precision, recall
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping

""" Hyperparamaters """
batch_size = 4
epochs = 1000
base_dir = 'mobilenetV2_bs4'
if not os.path.exists(base_dir):
    os.mkdir(base_dir)
    os.mkdir(f"{base_dir}/ckpt_path")
    
csv_path = f"{base_dir}/history.csv"

""" callbacks """
root_logdir = os.path.join(os.curdir, f"{base_dir}/logs","fit","")
def get_run_logdir():
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

checkpoint_filepath = f'{base_dir}/'+'ckpt_path/{epoch}.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    # monitor='val_iou_score',
    # mode='max',
    verbose = 1,
    period = 25,
    save_best_only=False
    )

callbacks = [
    model_checkpoint_callback,
#     ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.1, verbose=1),
    CSVLogger(csv_path),
#     EarlyStopping(monitor="val_loss", patience=10),
    tensorboard_cb
]

""" steps per epochs """
train_steps = len(train_X_y_paths)//batch_size
if len(train_X_y_paths) % batch_size != 0:
    train_steps += 1

test_steps = len(val_X_y_paths)//batch_size
if len(val_X_y_paths) % batch_size != 0:
    test_steps += 1

print("train_steps", train_steps, "test_steps",test_steps)

""" Model training """
# for layer in model.layers:
#     if layer.name == "global_average_pooling2d":
#         break
#     else:
#         layer.trainable = False

# for layer in model.layers:
#     print(layer.name,layer.trainable)

model.compile(
    loss=ls,
    optimizer= "adam",
    metrics=metrics
)
# model.summary()
# Out:
# env: SM_FRAMEWORK=tf.keras
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# train_steps 619 test_steps 125

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=1000,
    initial_epoch = 84,
    steps_per_epoch=train_steps,
    validation_steps=test_steps,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 85/1000
# 619/619 [==============================] - 482s 761ms/step - loss: 0.2546 - precision: 0.9223 - recall: 0.9112 - f1-score: 0.9160 - iou_score: 0.8575 - val_loss: 0.5176 - val_precision: 0.8474 - val_recall: 0.8279 - val_f1-score: 0.8329 - val_iou_score: 0.7443
# Epoch 86/1000
# 619/619 [==============================] - 463s 749ms/step - loss: 0.2510 - precision: 0.9233 - recall: 0.9122 - f1-score: 0.9171 - iou_score: 0.8593 - val_loss: 0.4926 - val_precision: 0.8701 - val_recall: 0.8222 - val_f1-score: 0.8387 - val_iou_score: 0.7554
# Epoch 87/1000
# 619/619 [==============================] - 463s 748ms/step - loss: 0.2540 - precision: 0.9230 - recall: 0.9113 - f1-score: 0.9165 - iou_score: 0.8579 - val_loss: 0.4793 - val_precision: 0.8538 - val_recall: 0.8462 - val_f1-score: 0.8464 - val_iou_score: 0.7621
# Epoch 88/1000
# 619/619 [==============================] - 463s 749ms/step - loss: 0.2439 - precision: 0.9262 - recall: 0.9148 - f1-score: 0.9199 - iou_score: 0.8632 - val_loss: 0.4778 - val_precision: 0.8535 - val_recall: 0.8479 - val_f1-score: 0.8468 - val_iou_score: 0.7622
# Epoch 89/1000
# 619/619 [==============================] - 462s 747ms/step - loss: 0.2413 - precision: 0.9270 - recall: 0.9149 - f1-score: 0.9203 - iou_score: 0.8643 - val_loss: 0.4989 - val_precision: 0.8790 - val_recall: 0.8149 - val_f1-score: 0.8368 - val_iou_score: 0.7531
# Epoch 90/1000
# 619/619 [==============================] - 467s 755ms/step - loss: 0.2426 - precision: 0.9266 - recall: 0.9152 - f1-score: 0.9202 - iou_score: 0.8640 - val_loss: 0.5536 - val_precision: 0.8463 - val_recall: 0.8103 - val_f1-score: 0.8226 - val_iou_score: 0.7301
# Epoch 91/1000
# 619/619 [==============================] - 470s 760ms/step - loss: 0.2632 - precision: 0.9193 - recall: 0.9085 - f1-score: 0.9131 - iou_score: 0.8531 - val_loss: 0.4958 - val_precision: 0.8430 - val_recall: 0.8455 - val_f1-score: 0.8407 - val_iou_score: 0.7533
# Epoch 92/1000
# 619/619 [==============================] - 466s 753ms/step - loss: 0.2385 - precision: 0.9279 - recall: 0.9166 - f1-score: 0.9217 - iou_score: 0.8661 - val_loss: 0.5268 - val_precision: 0.8597 - val_recall: 0.8212 - val_f1-score: 0.8338 - val_iou_score: 0.7446
# Epoch 93/1000
# 619/619 [==============================] - 467s 755ms/step - loss: 0.2381 - precision: 0.9284 - recall: 0.9162 - f1-score: 0.9217 - iou_score: 0.8663 - val_loss: 0.4983 - val_precision: 0.8713 - val_recall: 0.8206 - val_f1-score: 0.8386 - val_iou_score: 0.7535
# Epoch 94/1000
# 619/619 [==============================] - 465s 752ms/step - loss: 0.2403 - precision: 0.9271 - recall: 0.9163 - f1-score: 0.9211 - iou_score: 0.8653 - val_loss: 0.5543 - val_precision: 0.8559 - val_recall: 0.8150 - val_f1-score: 0.8272 - val_iou_score: 0.7357
# Epoch 95/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.2522 - precision: 0.9230 - recall: 0.9123 - f1-score: 0.9169 - iou_score: 0.8590 - val_loss: 0.5196 - val_precision: 0.8489 - val_recall: 0.8284 - val_f1-score: 0.8338 - val_iou_score: 0.7459
# Epoch 96/1000
# 619/619 [==============================] - 470s 760ms/step - loss: 0.2402 - precision: 0.9273 - recall: 0.9159 - f1-score: 0.9210 - iou_score: 0.8651 - val_loss: 0.4751 - val_precision: 0.8615 - val_recall: 0.8428 - val_f1-score: 0.8477 - val_iou_score: 0.7651
# Epoch 97/1000
# 619/619 [==============================] - 471s 762ms/step - loss: 0.2503 - precision: 0.9243 - recall: 0.9131 - f1-score: 0.9179 - iou_score: 0.8603 - val_loss: 0.5516 - val_precision: 0.8572 - val_recall: 0.7989 - val_f1-score: 0.8209 - val_iou_score: 0.7279
# Epoch 98/1000
# 619/619 [==============================] - 470s 760ms/step - loss: 0.2533 - precision: 0.9226 - recall: 0.9120 - f1-score: 0.9166 - iou_score: 0.8581 - val_loss: 0.4756 - val_precision: 0.8584 - val_recall: 0.8419 - val_f1-score: 0.8463 - val_iou_score: 0.7647
# Epoch 99/1000
# 619/619 [==============================] - 467s 756ms/step - loss: 0.2381 - precision: 0.9282 - recall: 0.9168 - f1-score: 0.9219 - iou_score: 0.8663 - val_loss: 0.4856 - val_precision: 0.8641 - val_recall: 0.8318 - val_f1-score: 0.8430 - val_iou_score: 0.7588
# Epoch 100/1000
# 619/619 [==============================] - 460s 743ms/step - loss: 0.2376 - precision: 0.9284 - recall: 0.9167 - f1-score: 0.9219 - iou_score: 0.8666 - val_loss: 0.5008 - val_precision: 0.8531 - val_recall: 0.8334 - val_f1-score: 0.8396 - val_iou_score: 0.7540
# Epoch 101/1000
# 619/619 [==============================] - 462s 747ms/step - loss: 0.2330 - precision: 0.9300 - recall: 0.9186 - f1-score: 0.9237 - iou_score: 0.8692 - val_loss: 0.4907 - val_precision: 0.8639 - val_recall: 0.8320 - val_f1-score: 0.8427 - val_iou_score: 0.7602
# Epoch 102/1000
# 619/619 [==============================] - 465s 751ms/step - loss: 0.2383 - precision: 0.9282 - recall: 0.9163 - f1-score: 0.9216 - iou_score: 0.8663 - val_loss: 0.4701 - val_precision: 0.8457 - val_recall: 0.8520 - val_f1-score: 0.8455 - val_iou_score: 0.7639
# Epoch 103/1000
# 619/619 [==============================] - 464s 751ms/step - loss: 0.2596 - precision: 0.9213 - recall: 0.9103 - f1-score: 0.9150 - iou_score: 0.8553 - val_loss: 0.5111 - val_precision: 0.8500 - val_recall: 0.8322 - val_f1-score: 0.8371 - val_iou_score: 0.7493
# Epoch 104/1000
# 619/619 [==============================] - 460s 743ms/step - loss: 0.2365 - precision: 0.9290 - recall: 0.9171 - f1-score: 0.9224 - iou_score: 0.8672 - val_loss: 0.4872 - val_precision: 0.8452 - val_recall: 0.8497 - val_f1-score: 0.8436 - val_iou_score: 0.7590
# Epoch 105/1000
# 619/619 [==============================] - 460s 744ms/step - loss: 0.2359 - precision: 0.9290 - recall: 0.9172 - f1-score: 0.9224 - iou_score: 0.8674 - val_loss: 0.5029 - val_precision: 0.8590 - val_recall: 0.8347 - val_f1-score: 0.8417 - val_iou_score: 0.7565
# Epoch 106/1000
# 619/619 [==============================] - 461s 745ms/step - loss: 0.2323 - precision: 0.9305 - recall: 0.9184 - f1-score: 0.9238 - iou_score: 0.8695 - val_loss: 0.5019 - val_precision: 0.8674 - val_recall: 0.8322 - val_f1-score: 0.8421 - val_iou_score: 0.7570
# Epoch 107/1000
# 619/619 [==============================] - 460s 744ms/step - loss: 0.2299 - precision: 0.9308 - recall: 0.9196 - f1-score: 0.9246 - iou_score: 0.8707 - val_loss: 0.4679 - val_precision: 0.8714 - val_recall: 0.8352 - val_f1-score: 0.8480 - val_iou_score: 0.7658
# Epoch 108/1000
# 619/619 [==============================] - 460s 744ms/step - loss: 0.2317 - precision: 0.9302 - recall: 0.9191 - f1-score: 0.9240 - iou_score: 0.8698 - val_loss: 0.4672 - val_precision: 0.8631 - val_recall: 0.8367 - val_f1-score: 0.8460 - val_iou_score: 0.7655
# Epoch 109/1000
# 619/619 [==============================] - ETA: 0s - loss: 0.2320 - precision: 0.9305 - recall: 0.9187 - f1-score: 0.9240 - iou_score: 0.8697
# Epoch 00109: saving model to mobilenetV2_bs4/ckpt_path/109.h5
# 619/619 [==============================] - 463s 749ms/step - loss: 0.2320 - precision: 0.9305 - recall: 0.9187 - f1-score: 0.9240 - iou_score: 0.8697 - val_loss: 0.4803 - val_precision: 0.8793 - val_recall: 0.8313 - val_f1-score: 0.8487 - val_iou_score: 0.7661
# Epoch 110/1000
# 619/619 [==============================] - 458s 741ms/step - loss: 0.2301 - precision: 0.9313 - recall: 0.9196 - f1-score: 0.9248 - iou_score: 0.8709 - val_loss: 0.4987 - val_precision: 0.8712 - val_recall: 0.8229 - val_f1-score: 0.8374 - val_iou_score: 0.7538
# Epoch 111/1000
# 619/619 [==============================] - 464s 750ms/step - loss: 0.2559 - precision: 0.9226 - recall: 0.9116 - f1-score: 0.9163 - iou_score: 0.8572 - val_loss: 0.5181 - val_precision: 0.8446 - val_recall: 0.8277 - val_f1-score: 0.8328 - val_iou_score: 0.7432
# Epoch 112/1000
# 619/619 [==============================] - 461s 746ms/step - loss: 0.2376 - precision: 0.9283 - recall: 0.9171 - f1-score: 0.9221 - iou_score: 0.8666 - val_loss: 0.5076 - val_precision: 0.8619 - val_recall: 0.8230 - val_f1-score: 0.8357 - val_iou_score: 0.7509
# Epoch 113/1000
# 619/619 [==============================] - 462s 747ms/step - loss: 0.2313 - precision: 0.9307 - recall: 0.9193 - f1-score: 0.9244 - iou_score: 0.8701 - val_loss: 0.5179 - val_precision: 0.8697 - val_recall: 0.8188 - val_f1-score: 0.8364 - val_iou_score: 0.7494
# Epoch 114/1000
# 619/619 [==============================] - 462s 746ms/step - loss: 0.2320 - precision: 0.9304 - recall: 0.9190 - f1-score: 0.9241 - iou_score: 0.8697 - val_loss: 0.4860 - val_precision: 0.8678 - val_recall: 0.8365 - val_f1-score: 0.8468 - val_iou_score: 0.7631
# Epoch 115/1000
# 619/619 [==============================] - 461s 745ms/step - loss: 0.2255 - precision: 0.9325 - recall: 0.9214 - f1-score: 0.9264 - iou_score: 0.8733 - val_loss: 0.5081 - val_precision: 0.8723 - val_recall: 0.8207 - val_f1-score: 0.8383 - val_iou_score: 0.7533
# Epoch 116/1000
# 619/619 [==============================] - 463s 749ms/step - loss: 0.2218 - precision: 0.9344 - recall: 0.9223 - f1-score: 0.9278 - iou_score: 0.8752 - val_loss: 0.4610 - val_precision: 0.8635 - val_recall: 0.8464 - val_f1-score: 0.8521 - val_iou_score: 0.7715
# Epoch 117/1000
# 619/619 [==============================] - 459s 743ms/step - loss: 0.2480 - precision: 0.9253 - recall: 0.9147 - f1-score: 0.9193 - iou_score: 0.8619 - val_loss: 0.5719 - val_precision: 0.8513 - val_recall: 0.7999 - val_f1-score: 0.8174 - val_iou_score: 0.7216
# Epoch 118/1000
# 619/619 [==============================] - 459s 742ms/step - loss: 0.2377 - precision: 0.9284 - recall: 0.9171 - f1-score: 0.9221 - iou_score: 0.8665 - val_loss: 0.5027 - val_precision: 0.8500 - val_recall: 0.8402 - val_f1-score: 0.8398 - val_iou_score: 0.7553
# Epoch 119/1000
# 619/619 [==============================] - 462s 747ms/step - loss: 0.2332 - precision: 0.9301 - recall: 0.9187 - f1-score: 0.9238 - iou_score: 0.8693 - val_loss: 0.4857 - val_precision: 0.8578 - val_recall: 0.8354 - val_f1-score: 0.8417 - val_iou_score: 0.7587
# Epoch 120/1000
# 619/619 [==============================] - 461s 746ms/step - loss: 0.2285 - precision: 0.9314 - recall: 0.9199 - f1-score: 0.9251 - iou_score: 0.8716 - val_loss: 0.4765 - val_precision: 0.8585 - val_recall: 0.8440 - val_f1-score: 0.8467 - val_iou_score: 0.7634
# Epoch 121/1000
# 619/619 [==============================] - 460s 744ms/step - loss: 0.2199 - precision: 0.9344 - recall: 0.9234 - f1-score: 0.9283 - iou_score: 0.8762 - val_loss: 0.4603 - val_precision: 0.8649 - val_recall: 0.8479 - val_f1-score: 0.8529 - val_iou_score: 0.7707
# Epoch 122/1000
# 619/619 [==============================] - 463s 749ms/step - loss: 0.2229 - precision: 0.9336 - recall: 0.9223 - f1-score: 0.9274 - iou_score: 0.8747 - val_loss: 0.5131 - val_precision: 0.8709 - val_recall: 0.8252 - val_f1-score: 0.8421 - val_iou_score: 0.7550
# Epoch 123/1000
# 619/619 [==============================] - 460s 744ms/step - loss: 0.2277 - precision: 0.9318 - recall: 0.9205 - f1-score: 0.9256 - iou_score: 0.8720 - val_loss: 0.4928 - val_precision: 0.8693 - val_recall: 0.8288 - val_f1-score: 0.8413 - val_iou_score: 0.7578
# Epoch 124/1000
# 619/619 [==============================] - 461s 745ms/step - loss: 0.2402 - precision: 0.9278 - recall: 0.9163 - f1-score: 0.9213 - iou_score: 0.8655 - val_loss: 0.5091 - val_precision: 0.8643 - val_recall: 0.8317 - val_f1-score: 0.8418 - val_iou_score: 0.7571
# Epoch 125/1000
# 619/619 [==============================] - 464s 750ms/step - loss: 0.2267 - precision: 0.9320 - recall: 0.9208 - f1-score: 0.9259 - iou_score: 0.8725 - val_loss: 0.4858 - val_precision: 0.8733 - val_recall: 0.8312 - val_f1-score: 0.8452 - val_iou_score: 0.7636
# Epoch 126/1000
# 619/619 [==============================] - 462s 746ms/step - loss: 0.2232 - precision: 0.9335 - recall: 0.9226 - f1-score: 0.9275 - iou_score: 0.8747 - val_loss: 0.4563 - val_precision: 0.8639 - val_recall: 0.8520 - val_f1-score: 0.8546 - val_iou_score: 0.7751
# Epoch 127/1000
# 619/619 [==============================] - 463s 749ms/step - loss: 0.2238 - precision: 0.9335 - recall: 0.9217 - f1-score: 0.9268 - iou_score: 0.8742 - val_loss: 0.4895 - val_precision: 0.8568 - val_recall: 0.8426 - val_f1-score: 0.8453 - val_iou_score: 0.7612
# Epoch 128/1000
# 619/619 [==============================] - 462s 748ms/step - loss: 0.2218 - precision: 0.9336 - recall: 0.9233 - f1-score: 0.9279 - iou_score: 0.8754 - val_loss: 0.4612 - val_precision: 0.8561 - val_recall: 0.8483 - val_f1-score: 0.8485 - val_iou_score: 0.7678
# Epoch 129/1000
# 619/619 [==============================] - 464s 750ms/step - loss: 0.2285 - precision: 0.9320 - recall: 0.9201 - f1-score: 0.9254 - iou_score: 0.8719 - val_loss: 0.5491 - val_precision: 0.8588 - val_recall: 0.8042 - val_f1-score: 0.8213 - val_iou_score: 0.7280
# Epoch 130/1000
# 619/619 [==============================] - 462s 746ms/step - loss: 0.2540 - precision: 0.9231 - recall: 0.9123 - f1-score: 0.9168 - iou_score: 0.8583 - val_loss: 0.5796 - val_precision: 0.8566 - val_recall: 0.7923 - val_f1-score: 0.8110 - val_iou_score: 0.7170
# Epoch 131/1000
# 619/619 [==============================] - 461s 745ms/step - loss: 0.2303 - precision: 0.9309 - recall: 0.9203 - f1-score: 0.9249 - iou_score: 0.8708 - val_loss: 0.4863 - val_precision: 0.8720 - val_recall: 0.8278 - val_f1-score: 0.8427 - val_iou_score: 0.7595
# Epoch 132/1000
# 619/619 [==============================] - 460s 745ms/step - loss: 0.2191 - precision: 0.9342 - recall: 0.9242 - f1-score: 0.9287 - iou_score: 0.8768 - val_loss: 0.4579 - val_precision: 0.8683 - val_recall: 0.8480 - val_f1-score: 0.8541 - val_iou_score: 0.7730
# Epoch 133/1000
# 619/619 [==============================] - 463s 749ms/step - loss: 0.2186 - precision: 0.9351 - recall: 0.9239 - f1-score: 0.9289 - iou_score: 0.8771 - val_loss: 0.4682 - val_precision: 0.8658 - val_recall: 0.8423 - val_f1-score: 0.8491 - val_iou_score: 0.7673
# Epoch 134/1000
# 619/619 [==============================] - ETA: 0s - loss: 0.2209 - precision: 0.9343 - recall: 0.9228 - f1-score: 0.9280 - iou_score: 0.8759
# Epoch 00134: saving model to mobilenetV2_bs4/ckpt_path/134.h5
# 619/619 [==============================] - 461s 746ms/step - loss: 0.2209 - precision: 0.9343 - recall: 0.9228 - f1-score: 0.9280 - iou_score: 0.8759 - val_loss: 0.5148 - val_precision: 0.8541 - val_recall: 0.8234 - val_f1-score: 0.8333 - val_iou_score: 0.7497
# Epoch 135/1000
# 619/619 [==============================] - 460s 744ms/step - loss: 0.2214 - precision: 0.9337 - recall: 0.9229 - f1-score: 0.9278 - iou_score: 0.8756 - val_loss: 0.5000 - val_precision: 0.8680 - val_recall: 0.8236 - val_f1-score: 0.8402 - val_iou_score: 0.7546
# Epoch 136/1000
# 619/619 [==============================] - 462s 747ms/step - loss: 0.2227 - precision: 0.9340 - recall: 0.9229 - f1-score: 0.9278 - iou_score: 0.8755 - val_loss: 0.5880 - val_precision: 0.8285 - val_recall: 0.8138 - val_f1-score: 0.8158 - val_iou_score: 0.7198
# Epoch 137/1000
# 619/619 [==============================] - 461s 746ms/step - loss: 0.2405 - precision: 0.9271 - recall: 0.9173 - f1-score: 0.9216 - iou_score: 0.8654 - val_loss: 0.5019 - val_precision: 0.8425 - val_recall: 0.8468 - val_f1-score: 0.8405 - val_iou_score: 0.7527
# Epoch 138/1000
# 619/619 [==============================] - 458s 741ms/step - loss: 0.2179 - precision: 0.9353 - recall: 0.9240 - f1-score: 0.9291 - iou_score: 0.8775 - val_loss: 0.4995 - val_precision: 0.8697 - val_recall: 0.8288 - val_f1-score: 0.8425 - val_iou_score: 0.7588
# Epoch 139/1000
# 619/619 [==============================] - 460s 744ms/step - loss: 0.2162 - precision: 0.9356 - recall: 0.9249 - f1-score: 0.9297 - iou_score: 0.8784 - val_loss: 0.4700 - val_precision: 0.8753 - val_recall: 0.8364 - val_f1-score: 0.8492 - val_iou_score: 0.7679
# Epoch 140/1000
# 619/619 [==============================] - 460s 744ms/step - loss: 0.2156 - precision: 0.9360 - recall: 0.9251 - f1-score: 0.9301 - iou_score: 0.8790 - val_loss: 0.5185 - val_precision: 0.8789 - val_recall: 0.8110 - val_f1-score: 0.8347 - val_iou_score: 0.7504
# Epoch 141/1000
# 619/619 [==============================] - 461s 746ms/step - loss: 0.2172 - precision: 0.9356 - recall: 0.9244 - f1-score: 0.9294 - iou_score: 0.8780 - val_loss: 0.4861 - val_precision: 0.8559 - val_recall: 0.8405 - val_f1-score: 0.8438 - val_iou_score: 0.7606
# Epoch 142/1000
# 619/619 [==============================] - 464s 751ms/step - loss: 0.2152 - precision: 0.9361 - recall: 0.9248 - f1-score: 0.9299 - iou_score: 0.8789 - val_loss: 0.4717 - val_precision: 0.8649 - val_recall: 0.8432 - val_f1-score: 0.8493 - val_iou_score: 0.7682
# Epoch 143/1000
# 619/619 [==============================] - 468s 756ms/step - loss: 0.2169 - precision: 0.9357 - recall: 0.9246 - f1-score: 0.9296 - iou_score: 0.8782 - val_loss: 0.4666 - val_precision: 0.8716 - val_recall: 0.8433 - val_f1-score: 0.8504 - val_iou_score: 0.7696
# Epoch 144/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.2155 - precision: 0.9360 - recall: 0.9251 - f1-score: 0.9300 - iou_score: 0.8789 - val_loss: 0.4830 - val_precision: 0.8737 - val_recall: 0.8374 - val_f1-score: 0.8496 - val_iou_score: 0.7678
# Epoch 145/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.2204 - precision: 0.9346 - recall: 0.9230 - f1-score: 0.9282 - iou_score: 0.8762 - val_loss: 0.5197 - val_precision: 0.8662 - val_recall: 0.8234 - val_f1-score: 0.8378 - val_iou_score: 0.7526
# Epoch 146/1000
# 619/619 [==============================] - 467s 756ms/step - loss: 0.2155 - precision: 0.9358 - recall: 0.9256 - f1-score: 0.9303 - iou_score: 0.8790 - val_loss: 0.5241 - val_precision: 0.8714 - val_recall: 0.8131 - val_f1-score: 0.8325 - val_iou_score: 0.7455
# Epoch 147/1000
# 619/619 [==============================] - 465s 752ms/step - loss: 0.2149 - precision: 0.9361 - recall: 0.9254 - f1-score: 0.9302 - iou_score: 0.8792 - val_loss: 0.5147 - val_precision: 0.8635 - val_recall: 0.8278 - val_f1-score: 0.8396 - val_iou_score: 0.7525
# Epoch 148/1000
# 619/619 [==============================] - 465s 752ms/step - loss: 0.2144 - precision: 0.9367 - recall: 0.9254 - f1-score: 0.9305 - iou_score: 0.8796 - val_loss: 0.5084 - val_precision: 0.8604 - val_recall: 0.8302 - val_f1-score: 0.8398 - val_iou_score: 0.7550
# Epoch 149/1000
# 619/619 [==============================] - 467s 755ms/step - loss: 0.2324 - precision: 0.9305 - recall: 0.9205 - f1-score: 0.9249 - iou_score: 0.8705 - val_loss: 0.4900 - val_precision: 0.8399 - val_recall: 0.8580 - val_f1-score: 0.8448 - val_iou_score: 0.7614
# Epoch 150/1000
# 619/619 [==============================] - 468s 756ms/step - loss: 0.2220 - precision: 0.9336 - recall: 0.9234 - f1-score: 0.9280 - iou_score: 0.8754 - val_loss: 0.4682 - val_precision: 0.8555 - val_recall: 0.8486 - val_f1-score: 0.8478 - val_iou_score: 0.7652
# Epoch 151/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.2120 - precision: 0.9372 - recall: 0.9266 - f1-score: 0.9314 - iou_score: 0.8808 - val_loss: 0.4906 - val_precision: 0.8549 - val_recall: 0.8414 - val_f1-score: 0.8434 - val_iou_score: 0.7602
# Epoch 152/1000
# 619/619 [==============================] - 465s 752ms/step - loss: 0.2113 - precision: 0.9375 - recall: 0.9266 - f1-score: 0.9315 - iou_score: 0.8812 - val_loss: 0.4894 - val_precision: 0.8698 - val_recall: 0.8376 - val_f1-score: 0.8472 - val_iou_score: 0.7642
# Epoch 153/1000
# 619/619 [==============================] - 466s 754ms/step - loss: 0.2124 - precision: 0.9373 - recall: 0.9259 - f1-score: 0.9311 - iou_score: 0.8806 - val_loss: 0.4880 - val_precision: 0.8656 - val_recall: 0.8440 - val_f1-score: 0.8498 - val_iou_score: 0.7676
# Epoch 154/1000
# 619/619 [==============================] - 466s 753ms/step - loss: 0.2127 - precision: 0.9372 - recall: 0.9258 - f1-score: 0.9310 - iou_score: 0.8804 - val_loss: 0.4877 - val_precision: 0.8562 - val_recall: 0.8434 - val_f1-score: 0.8461 - val_iou_score: 0.7634
# Epoch 155/1000
# 619/619 [==============================] - 465s 752ms/step - loss: 0.2230 - precision: 0.9338 - recall: 0.9227 - f1-score: 0.9276 - iou_score: 0.8750 - val_loss: 0.4924 - val_precision: 0.8695 - val_recall: 0.8237 - val_f1-score: 0.8397 - val_iou_score: 0.7551
# Epoch 156/1000
# 619/619 [==============================] - 465s 752ms/step - loss: 0.2157 - precision: 0.9359 - recall: 0.9255 - f1-score: 0.9302 - iou_score: 0.8789 - val_loss: 0.4937 - val_precision: 0.8640 - val_recall: 0.8372 - val_f1-score: 0.8456 - val_iou_score: 0.7611
# Epoch 157/1000
# 619/619 [==============================] - 467s 754ms/step - loss: 0.2117 - precision: 0.9374 - recall: 0.9266 - f1-score: 0.9314 - iou_score: 0.8811 - val_loss: 0.4826 - val_precision: 0.8683 - val_recall: 0.8376 - val_f1-score: 0.8486 - val_iou_score: 0.7666
# Epoch 158/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.2098 - precision: 0.9381 - recall: 0.9271 - f1-score: 0.9321 - iou_score: 0.8821 - val_loss: 0.4786 - val_precision: 0.8652 - val_recall: 0.8415 - val_f1-score: 0.8487 - val_iou_score: 0.7676
# Epoch 159/1000
# 619/619 [==============================] - ETA: 0s - loss: 0.2118 - precision: 0.9375 - recall: 0.9264 - f1-score: 0.9315 - iou_score: 0.8810
# Epoch 00159: saving model to mobilenetV2_bs4/ckpt_path/159.h5
# 619/619 [==============================] - 469s 759ms/step - loss: 0.2118 - precision: 0.9375 - recall: 0.9264 - f1-score: 0.9315 - iou_score: 0.8810 - val_loss: 0.4843 - val_precision: 0.8646 - val_recall: 0.8405 - val_f1-score: 0.8479 - val_iou_score: 0.7648
# Epoch 160/1000
# 619/619 [==============================] - 467s 756ms/step - loss: 0.2182 - precision: 0.9350 - recall: 0.9245 - f1-score: 0.9292 - iou_score: 0.8774 - val_loss: 0.4885 - val_precision: 0.8543 - val_recall: 0.8441 - val_f1-score: 0.8457 - val_iou_score: 0.7623
# Epoch 161/1000
# 619/619 [==============================] - 467s 756ms/step - loss: 0.2137 - precision: 0.9367 - recall: 0.9257 - f1-score: 0.9307 - iou_score: 0.8799 - val_loss: 0.4730 - val_precision: 0.8696 - val_recall: 0.8422 - val_f1-score: 0.8515 - val_iou_score: 0.7697
# Epoch 162/1000
# 619/619 [==============================] - 468s 756ms/step - loss: 0.2087 - precision: 0.9382 - recall: 0.9280 - f1-score: 0.9326 - iou_score: 0.8828 - val_loss: 0.4663 - val_precision: 0.8662 - val_recall: 0.8462 - val_f1-score: 0.8523 - val_iou_score: 0.7719
# Epoch 163/1000
# 619/619 [==============================] - 468s 756ms/step - loss: 0.2098 - precision: 0.9379 - recall: 0.9276 - f1-score: 0.9322 - iou_score: 0.8822 - val_loss: 0.4869 - val_precision: 0.8595 - val_recall: 0.8399 - val_f1-score: 0.8444 - val_iou_score: 0.7624
# Epoch 164/1000
# 619/619 [==============================] - 467s 755ms/step - loss: 0.2112 - precision: 0.9370 - recall: 0.9269 - f1-score: 0.9314 - iou_score: 0.8813 - val_loss: 0.4855 - val_precision: 0.8550 - val_recall: 0.8419 - val_f1-score: 0.8446 - val_iou_score: 0.7622
# Epoch 165/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.2164 - precision: 0.9356 - recall: 0.9253 - f1-score: 0.9299 - iou_score: 0.8786 - val_loss: 0.5251 - val_precision: 0.8564 - val_recall: 0.8239 - val_f1-score: 0.8345 - val_iou_score: 0.7474
# Epoch 166/1000
# 619/619 [==============================] - 470s 759ms/step - loss: 0.2111 - precision: 0.9376 - recall: 0.9264 - f1-score: 0.9315 - iou_score: 0.8814 - val_loss: 0.4796 - val_precision: 0.8673 - val_recall: 0.8397 - val_f1-score: 0.8486 - val_iou_score: 0.7660
# Epoch 167/1000
# 619/619 [==============================] - 467s 756ms/step - loss: 0.2064 - precision: 0.9390 - recall: 0.9288 - f1-score: 0.9334 - iou_score: 0.8840 - val_loss: 0.4729 - val_precision: 0.8689 - val_recall: 0.8379 - val_f1-score: 0.8488 - val_iou_score: 0.7680
# Epoch 168/1000
# 619/619 [==============================] - 468s 756ms/step - loss: 0.2076 - precision: 0.9389 - recall: 0.9281 - f1-score: 0.9329 - iou_score: 0.8834 - val_loss: 0.4831 - val_precision: 0.8581 - val_recall: 0.8467 - val_f1-score: 0.8489 - val_iou_score: 0.7645
# Epoch 169/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.2059 - precision: 0.9391 - recall: 0.9292 - f1-score: 0.9337 - iou_score: 0.8843 - val_loss: 0.4813 - val_precision: 0.8642 - val_recall: 0.8400 - val_f1-score: 0.8476 - val_iou_score: 0.7668
# Epoch 170/1000
# 619/619 [==============================] - 470s 760ms/step - loss: 0.2064 - precision: 0.9394 - recall: 0.9284 - f1-score: 0.9333 - iou_score: 0.8841 - val_loss: 0.4928 - val_precision: 0.8693 - val_recall: 0.8347 - val_f1-score: 0.8454 - val_iou_score: 0.7628
# Epoch 171/1000
# 619/619 [==============================] - 467s 755ms/step - loss: 0.2090 - precision: 0.9382 - recall: 0.9276 - f1-score: 0.9323 - iou_score: 0.8826 - val_loss: 0.5215 - val_precision: 0.8628 - val_recall: 0.8235 - val_f1-score: 0.8361 - val_iou_score: 0.7504
# Epoch 172/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.2088 - precision: 0.9380 - recall: 0.9276 - f1-score: 0.9323 - iou_score: 0.8826 - val_loss: 0.4882 - val_precision: 0.8670 - val_recall: 0.8348 - val_f1-score: 0.8451 - val_iou_score: 0.7627
# Epoch 173/1000
# 619/619 [==============================] - 467s 756ms/step - loss: 0.2191 - precision: 0.9351 - recall: 0.9241 - f1-score: 0.9290 - iou_score: 0.8771 - val_loss: 0.4886 - val_precision: 0.8787 - val_recall: 0.8232 - val_f1-score: 0.8414 - val_iou_score: 0.7588
# Epoch 174/1000
# 619/619 [==============================] - 471s 762ms/step - loss: 0.2116 - precision: 0.9376 - recall: 0.9269 - f1-score: 0.9318 - iou_score: 0.8811 - val_loss: 0.4796 - val_precision: 0.8724 - val_recall: 0.8365 - val_f1-score: 0.8485 - val_iou_score: 0.7661
# Epoch 175/1000
# 619/619 [==============================] - 469s 759ms/step - loss: 0.2084 - precision: 0.9388 - recall: 0.9274 - f1-score: 0.9325 - iou_score: 0.8828 - val_loss: 0.4824 - val_precision: 0.8691 - val_recall: 0.8389 - val_f1-score: 0.8484 - val_iou_score: 0.7683
# Epoch 176/1000
# 619/619 [==============================] - 470s 761ms/step - loss: 0.2060 - precision: 0.9395 - recall: 0.9284 - f1-score: 0.9334 - iou_score: 0.8843 - val_loss: 0.4795 - val_precision: 0.8698 - val_recall: 0.8419 - val_f1-score: 0.8511 - val_iou_score: 0.7696
# Epoch 177/1000
# 619/619 [==============================] - 471s 762ms/step - loss: 0.2036 - precision: 0.9401 - recall: 0.9294 - f1-score: 0.9343 - iou_score: 0.8856 - val_loss: 0.4690 - val_precision: 0.8674 - val_recall: 0.8451 - val_f1-score: 0.8520 - val_iou_score: 0.7711
# Epoch 178/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.2110 - precision: 0.9375 - recall: 0.9276 - f1-score: 0.9320 - iou_score: 0.8817 - val_loss: 0.4726 - val_precision: 0.8731 - val_recall: 0.8397 - val_f1-score: 0.8512 - val_iou_score: 0.7687
# Epoch 179/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.2033 - precision: 0.9401 - recall: 0.9297 - f1-score: 0.9344 - iou_score: 0.8857 - val_loss: 0.4962 - val_precision: 0.8606 - val_recall: 0.8332 - val_f1-score: 0.8420 - val_iou_score: 0.7589
# Epoch 180/1000
# 619/619 [==============================] - 467s 756ms/step - loss: 0.2059 - precision: 0.9394 - recall: 0.9290 - f1-score: 0.9337 - iou_score: 0.8844 - val_loss: 0.5091 - val_precision: 0.8566 - val_recall: 0.8347 - val_f1-score: 0.8408 - val_iou_score: 0.7572
# Epoch 181/1000
# 619/619 [==============================] - 466s 754ms/step - loss: 0.2046 - precision: 0.9397 - recall: 0.9292 - f1-score: 0.9339 - iou_score: 0.8850 - val_loss: 0.4853 - val_precision: 0.8659 - val_recall: 0.8382 - val_f1-score: 0.8463 - val_iou_score: 0.7649
# Epoch 182/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.2040 - precision: 0.9399 - recall: 0.9295 - f1-score: 0.9342 - iou_score: 0.8853 - val_loss: 0.4828 - val_precision: 0.8650 - val_recall: 0.8406 - val_f1-score: 0.8484 - val_iou_score: 0.7662
# Epoch 183/1000
# 619/619 [==============================] - 471s 761ms/step - loss: 0.2034 - precision: 0.9401 - recall: 0.9297 - f1-score: 0.9344 - iou_score: 0.8857 - val_loss: 0.4815 - val_precision: 0.8747 - val_recall: 0.8314 - val_f1-score: 0.8474 - val_iou_score: 0.7640
# Epoch 184/1000
# 619/619 [==============================] - ETA: 0s - loss: 0.2092 - precision: 0.9383 - recall: 0.9274 - f1-score: 0.9323 - iou_score: 0.8826
# Epoch 00184: saving model to mobilenetV2_bs4/ckpt_path/184.h5
# 619/619 [==============================] - 470s 759ms/step - loss: 0.2092 - precision: 0.9383 - recall: 0.9274 - f1-score: 0.9323 - iou_score: 0.8826 - val_loss: 0.4827 - val_precision: 0.8761 - val_recall: 0.8331 - val_f1-score: 0.8486 - val_iou_score: 0.7659
# Epoch 185/1000
# 619/619 [==============================] - 470s 759ms/step - loss: 0.2010 - precision: 0.9409 - recall: 0.9305 - f1-score: 0.9353 - iou_score: 0.8870 - val_loss: 0.4919 - val_precision: 0.8743 - val_recall: 0.8308 - val_f1-score: 0.8442 - val_iou_score: 0.7642
# Epoch 186/1000
# 619/619 [==============================] - 470s 759ms/step - loss: 0.2016 - precision: 0.9409 - recall: 0.9305 - f1-score: 0.9352 - iou_score: 0.8868 - val_loss: 0.5016 - val_precision: 0.8773 - val_recall: 0.8241 - val_f1-score: 0.8413 - val_iou_score: 0.7590
# Epoch 187/1000
# 619/619 [==============================] - 468s 756ms/step - loss: 0.2025 - precision: 0.9407 - recall: 0.9302 - f1-score: 0.9350 - iou_score: 0.8863 - val_loss: 0.4781 - val_precision: 0.8730 - val_recall: 0.8323 - val_f1-score: 0.8457 - val_iou_score: 0.7649
# Epoch 188/1000
# 619/619 [==============================] - 468s 756ms/step - loss: 0.2044 - precision: 0.9397 - recall: 0.9293 - f1-score: 0.9340 - iou_score: 0.8851 - val_loss: 0.5243 - val_precision: 0.8610 - val_recall: 0.8296 - val_f1-score: 0.8394 - val_iou_score: 0.7520
# Epoch 189/1000
# 619/619 [==============================] - 466s 753ms/step - loss: 0.2034 - precision: 0.9402 - recall: 0.9295 - f1-score: 0.9343 - iou_score: 0.8856 - val_loss: 0.4771 - val_precision: 0.8683 - val_recall: 0.8381 - val_f1-score: 0.8482 - val_iou_score: 0.7667
# Epoch 190/1000
# 619/619 [==============================] - 463s 748ms/step - loss: 0.2274 - precision: 0.9331 - recall: 0.9222 - f1-score: 0.9268 - iou_score: 0.8736 - val_loss: 0.5409 - val_precision: 0.8431 - val_recall: 0.8307 - val_f1-score: 0.8291 - val_iou_score: 0.7407
# Epoch 191/1000
# 619/619 [==============================] - 465s 753ms/step - loss: 0.2129 - precision: 0.9374 - recall: 0.9272 - f1-score: 0.9318 - iou_score: 0.8812 - val_loss: 0.6017 - val_precision: 0.8151 - val_recall: 0.8223 - val_f1-score: 0.8137 - val_iou_score: 0.7144
# Epoch 192/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.2154 - precision: 0.9364 - recall: 0.9264 - f1-score: 0.9308 - iou_score: 0.8795 - val_loss: 0.4984 - val_precision: 0.8691 - val_recall: 0.8332 - val_f1-score: 0.8429 - val_iou_score: 0.7605
# Epoch 193/1000
# 619/619 [==============================] - 465s 752ms/step - loss: 0.2017 - precision: 0.9411 - recall: 0.9298 - f1-score: 0.9349 - iou_score: 0.8866 - val_loss: 0.4893 - val_precision: 0.8732 - val_recall: 0.8330 - val_f1-score: 0.8469 - val_iou_score: 0.7645
# Epoch 194/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.1986 - precision: 0.9422 - recall: 0.9312 - f1-score: 0.9363 - iou_score: 0.8884 - val_loss: 0.4801 - val_precision: 0.8712 - val_recall: 0.8320 - val_f1-score: 0.8452 - val_iou_score: 0.7635
# Epoch 195/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.1996 - precision: 0.9416 - recall: 0.9311 - f1-score: 0.9359 - iou_score: 0.8879 - val_loss: 0.4742 - val_precision: 0.8718 - val_recall: 0.8387 - val_f1-score: 0.8500 - val_iou_score: 0.7691
# Epoch 196/1000
# 619/619 [==============================] - 469s 759ms/step - loss: 0.2007 - precision: 0.9413 - recall: 0.9307 - f1-score: 0.9355 - iou_score: 0.8874 - val_loss: 0.4836 - val_precision: 0.8605 - val_recall: 0.8447 - val_f1-score: 0.8472 - val_iou_score: 0.7653
# Epoch 197/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.1986 - precision: 0.9419 - recall: 0.9310 - f1-score: 0.9359 - iou_score: 0.8883 - val_loss: 0.4783 - val_precision: 0.8671 - val_recall: 0.8435 - val_f1-score: 0.8512 - val_iou_score: 0.7699
# Epoch 198/1000
# 619/619 [==============================] - 467s 756ms/step - loss: 0.2003 - precision: 0.9412 - recall: 0.9310 - f1-score: 0.9357 - iou_score: 0.8876 - val_loss: 0.4902 - val_precision: 0.8680 - val_recall: 0.8371 - val_f1-score: 0.8482 - val_iou_score: 0.7649
# Epoch 199/1000
# 619/619 [==============================] - 470s 760ms/step - loss: 0.2013 - precision: 0.9409 - recall: 0.9303 - f1-score: 0.9352 - iou_score: 0.8869 - val_loss: 0.4629 - val_precision: 0.8728 - val_recall: 0.8461 - val_f1-score: 0.8549 - val_iou_score: 0.7749
# Epoch 200/1000
# 619/619 [==============================] - 470s 760ms/step - loss: 0.2010 - precision: 0.9409 - recall: 0.9307 - f1-score: 0.9353 - iou_score: 0.8871 - val_loss: 0.4846 - val_precision: 0.8578 - val_recall: 0.8476 - val_f1-score: 0.8481 - val_iou_score: 0.7651
# Epoch 201/1000
# 619/619 [==============================] - 469s 759ms/step - loss: 0.2025 - precision: 0.9405 - recall: 0.9298 - f1-score: 0.9346 - iou_score: 0.8863 - val_loss: 0.4811 - val_precision: 0.8794 - val_recall: 0.8357 - val_f1-score: 0.8515 - val_iou_score: 0.7703
# Epoch 202/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.2003 - precision: 0.9411 - recall: 0.9310 - f1-score: 0.9356 - iou_score: 0.8874 - val_loss: 0.4918 - val_precision: 0.8649 - val_recall: 0.8363 - val_f1-score: 0.8458 - val_iou_score: 0.7632
# Epoch 203/1000
# 619/619 [==============================] - 465s 752ms/step - loss: 0.2003 - precision: 0.9411 - recall: 0.9307 - f1-score: 0.9354 - iou_score: 0.8875 - val_loss: 0.5090 - val_precision: 0.8627 - val_recall: 0.8287 - val_f1-score: 0.8398 - val_iou_score: 0.7554
# Epoch 204/1000
# 619/619 [==============================] - 471s 761ms/step - loss: 0.2162 - precision: 0.9362 - recall: 0.9259 - f1-score: 0.9305 - iou_score: 0.8791 - val_loss: 0.5099 - val_precision: 0.8580 - val_recall: 0.8283 - val_f1-score: 0.8386 - val_iou_score: 0.7524
# Epoch 205/1000
# 619/619 [==============================] - 468s 756ms/step - loss: 0.2081 - precision: 0.9385 - recall: 0.9284 - f1-score: 0.9330 - iou_score: 0.8831 - val_loss: 0.4790 - val_precision: 0.8631 - val_recall: 0.8450 - val_f1-score: 0.8503 - val_iou_score: 0.7693
# Epoch 206/1000
# 619/619 [==============================] - 470s 760ms/step - loss: 0.1976 - precision: 0.9424 - recall: 0.9320 - f1-score: 0.9367 - iou_score: 0.8891 - val_loss: 0.4954 - val_precision: 0.8635 - val_recall: 0.8414 - val_f1-score: 0.8480 - val_iou_score: 0.7650
# Epoch 207/1000
# 619/619 [==============================] - 471s 762ms/step - loss: 0.1958 - precision: 0.9429 - recall: 0.9321 - f1-score: 0.9371 - iou_score: 0.8899 - val_loss: 0.4800 - val_precision: 0.8671 - val_recall: 0.8443 - val_f1-score: 0.8514 - val_iou_score: 0.7694
# Epoch 208/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.1955 - precision: 0.9427 - recall: 0.9327 - f1-score: 0.9373 - iou_score: 0.8901 - val_loss: 0.4761 - val_precision: 0.8652 - val_recall: 0.8440 - val_f1-score: 0.8496 - val_iou_score: 0.7692
# Epoch 209/1000
# 619/619 [==============================] - ETA: 0s - loss: 0.1962 - precision: 0.9427 - recall: 0.9322 - f1-score: 0.9370 - iou_score: 0.8897
# Epoch 00209: saving model to mobilenetV2_bs4/ckpt_path/209.h5
# 619/619 [==============================] - 471s 761ms/step - loss: 0.1962 - precision: 0.9427 - recall: 0.9322 - f1-score: 0.9370 - iou_score: 0.8897 - val_loss: 0.4965 - val_precision: 0.8621 - val_recall: 0.8421 - val_f1-score: 0.8468 - val_iou_score: 0.7633
# Epoch 210/1000
# 619/619 [==============================] - 470s 760ms/step - loss: 0.1966 - precision: 0.9426 - recall: 0.9322 - f1-score: 0.9369 - iou_score: 0.8897 - val_loss: 0.4856 - val_precision: 0.8674 - val_recall: 0.8425 - val_f1-score: 0.8506 - val_iou_score: 0.7673
# Epoch 211/1000
# 619/619 [==============================] - 470s 761ms/step - loss: 0.1961 - precision: 0.9425 - recall: 0.9325 - f1-score: 0.9371 - iou_score: 0.8899 - val_loss: 0.4727 - val_precision: 0.8707 - val_recall: 0.8429 - val_f1-score: 0.8518 - val_iou_score: 0.7706
# Epoch 212/1000
# 619/619 [==============================] - 471s 762ms/step - loss: 0.1984 - precision: 0.9417 - recall: 0.9315 - f1-score: 0.9362 - iou_score: 0.8886 - val_loss: 0.4749 - val_precision: 0.8781 - val_recall: 0.8345 - val_f1-score: 0.8499 - val_iou_score: 0.7693
# Epoch 213/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.1993 - precision: 0.9416 - recall: 0.9309 - f1-score: 0.9358 - iou_score: 0.8881 - val_loss: 0.4790 - val_precision: 0.8640 - val_recall: 0.8461 - val_f1-score: 0.8514 - val_iou_score: 0.7711
# Epoch 214/1000
# 619/619 [==============================] - 470s 761ms/step - loss: 0.1985 - precision: 0.9417 - recall: 0.9313 - f1-score: 0.9360 - iou_score: 0.8884 - val_loss: 0.4828 - val_precision: 0.8703 - val_recall: 0.8350 - val_f1-score: 0.8466 - val_iou_score: 0.7654
# Epoch 215/1000
# 619/619 [==============================] - 469s 759ms/step - loss: 0.1966 - precision: 0.9425 - recall: 0.9323 - f1-score: 0.9369 - iou_score: 0.8895 - val_loss: 0.4813 - val_precision: 0.8693 - val_recall: 0.8388 - val_f1-score: 0.8498 - val_iou_score: 0.7670
# Epoch 216/1000
# 619/619 [==============================] - 471s 762ms/step - loss: 0.1959 - precision: 0.9427 - recall: 0.9323 - f1-score: 0.9370 - iou_score: 0.8899 - val_loss: 0.4838 - val_precision: 0.8636 - val_recall: 0.8449 - val_f1-score: 0.8502 - val_iou_score: 0.7688
# Epoch 217/1000
# 619/619 [==============================] - 469s 758ms/step - loss: 0.1951 - precision: 0.9428 - recall: 0.9331 - f1-score: 0.9375 - iou_score: 0.8904 - val_loss: 0.4796 - val_precision: 0.8591 - val_recall: 0.8520 - val_f1-score: 0.8519 - val_iou_score: 0.7717
# Epoch 218/1000
# 619/619 [==============================] - 468s 757ms/step - loss: 0.1943 - precision: 0.9434 - recall: 0.9330 - f1-score: 0.9377 - iou_score: 0.8908 - val_loss: 0.4921 - val_precision: 0.8555 - val_recall: 0.8448 - val_f1-score: 0.8462 - val_iou_score: 0.7629
# Epoch 219/1000
# 619/619 [==============================] - 482s 780ms/step - loss: 0.1969 - precision: 0.9426 - recall: 0.9317 - f1-score: 0.9366 - iou_score: 0.8894 - val_loss: 0.4889 - val_precision: 0.8674 - val_recall: 0.8373 - val_f1-score: 0.8478 - val_iou_score: 0.7649
# Epoch 220/1000
# 619/619 [==============================] - 510s 825ms/step - loss: 0.1963 - precision: 0.9424 - recall: 0.9325 - f1-score: 0.9370 - iou_score: 0.8898 - val_loss: 0.4830 - val_precision: 0.8688 - val_recall: 0.8361 - val_f1-score: 0.8478 - val_iou_score: 0.7660
# Epoch 221/1000
# 619/619 [==============================] - 471s 761ms/step - loss: 0.1954 - precision: 0.9430 - recall: 0.9324 - f1-score: 0.9372 - iou_score: 0.8902 - val_loss: 0.5043 - val_precision: 0.8723 - val_recall: 0.8253 - val_f1-score: 0.8422 - val_iou_score: 0.7584
# Epoch 222/1000
#  63/619 [==>...........................] - ETA: 6:04 - loss: 0.1917 - precision: 0.9439 - recall: 0.9344 - f1-score: 0.9386 - iou_score: 0.8926
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-fe9f64786916> in <module>
# ----> 1 history = model.fit(
#       2     train_generator,
#       3     validation_data=val_generator,
#       4     epochs=1000,
#       5     initial_epoch = 84,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
# model.save('/content/drive/MyDrive/mobilenetv2.h5')

# %%
# from segmentation_models.losses import cce_jaccard_loss, dice_loss, JaccardLoss
# from segmentation_models.metrics import iou_score, f1_score, precision, recall
# ls = dice_loss + cce_jaccard_loss
# metrics = [precision, recall, f1_score, iou_score] 

# from tensorflow.keras.models import load_model
# model = load_model('mobilenetv2_bs4/ckpt_path/Deeplabv3p_mobilenetv2_200.h5',
#                    custom_objects={'dice_loss_plus_categorical_crossentropy_plus_jaccard_loss':ls,
#                                    'precision':precision, 'recall':recall, 'f1-score':f1_score, 'iou_score':iou_score})

# %%
# !tensorboard --logdir logs --host 0.0.0.0
