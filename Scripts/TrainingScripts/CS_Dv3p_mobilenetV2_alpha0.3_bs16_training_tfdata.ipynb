# %%
# !pip install q tensorflow==2.1
# !pip install q keras==2.3.1
# !pip install git+https://github.com/qubvel/segmentation_models

# for str decode error ... run it and restart runtime
# !pip uninstall h5py -y
# !pip install h5py==2.10.0

# %%
i = !ls Dataset/images/
l = !ls Dataset/masks/
len(i), len(l)
# Out:
# (2975, 2975)

# %%
l[-5:], i[-5:]
# Out:
# (['zurich_000117_000019_gtFine_labelTrainIds.png',
#   'zurich_000118_000019_gtFine_labelTrainIds.png',
#   'zurich_000119_000019_gtFine_labelTrainIds.png',
#   'zurich_000120_000019_gtFine_labelTrainIds.png',
#   'zurich_000121_000019_gtFine_labelTrainIds.png'],
#  ['zurich_000117_000019_leftImg8bit.png',
#   'zurich_000118_000019_leftImg8bit.png',
#   'zurich_000119_000019_leftImg8bit.png',
#   'zurich_000120_000019_leftImg8bit.png',
#   'zurich_000121_000019_leftImg8bit.png'])

# %%
import cv2
from glob import glob
import os
import numpy as np

# 100 = background
# 101 = road
# 102 = obstacle(person, rider, car, truck, bus, train, motorcycle, bicycle)

l = glob('Dataset/masks/*')
m = cv2.imread(l[2970],0)
m.shape
np.unique(m)
# Out:
# array([0, 1, 2], dtype=uint8)

# %%
import os
len(os.listdir('Dataset/images/')), len(os.listdir('Dataset/masks/'))
# Out:
# (2975, 2975)

# %%
import numpy as np
import cv2
import os
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf

def load_dataset(dataset_path):
    images = sorted(glob(os.path.join(dataset_path, "images/*")))
    masks = sorted(glob(os.path.join(dataset_path, "masks/*")))

    train_x, test_x, train_y, test_y = train_test_split(images,masks, test_size=0.168, 
                                                        random_state=168, shuffle=True)
    return train_x, train_y, test_x, test_y

train_x, train_y, val_x, val_y = load_dataset('Dataset')
print(len(train_x), len(train_y), len(val_x), len(val_y))
# Out:
# 2475 2475 500 500

# %% [markdown]
# ### TF data API

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
SEED = 42

gpus = tf.config.experimental.list_physical_devices('GPU')
logical_gpus = tf.config.experimental.list_logical_devices('GPU')
# cpus = tf.config.experimental.list_physical_devices('CPU')
# print(gpus,logical_gpus)

# Image size that we are going to use
IMG_SIZE = 512
# Our images are RGB (3 channels)
N_CHANNELS = 3
# Scene Parsing has 150 classes + `not labeled`
N_CLASSES = 3

# len(train_x), len(train_y), len(val_x), len(val_y)
def parse_x_y(img_path,mask_path):
    image = tf.io.read_file(img_path)
    image = tf.image.decode_png(image, channels=3)
    image = tf.image.convert_image_dtype(image, tf.uint8)
    
    mask = tf.io.read_file(mask_path)    
    mask = tf.image.decode_png(mask, channels=1)  
    return {'image': image, 'segmentation_mask': mask}

@tf.function
def normalize(input_image: tf.Tensor, input_mask: tf.Tensor) -> tuple:
    input_image = tf.cast(input_image, tf.float32) / 255.0
    return input_image, input_mask

@tf.function
def load_image_train(datapoint: dict) -> tuple:
    input_image = tf.image.resize(datapoint['image'], (IMG_SIZE, IMG_SIZE))
    input_mask = tf.image.resize(datapoint['segmentation_mask'], (IMG_SIZE, IMG_SIZE),method='nearest')    
#     if tf.random.uniform(()) > 0.5:
#         input_image = tf.image.flip_left_right(input_image)
#         input_mask = tf.image.flip_left_right(input_mask)

    input_image, input_mask = normalize(input_image, input_mask)
    input_mask = tf.one_hot(input_mask, 3)
    input_mask = tf.reshape(input_mask, (512, 512, 3))
    return input_image, input_mask

BATCH_SIZE = 16
BUFFER_SIZE = 32

train_dataset = tf.data.Dataset.from_tensor_slices((train_x,train_y))
train_dataset = train_dataset.map(parse_x_y)

val_dataset = tf.data.Dataset.from_tensor_slices((val_x,val_y))
val_dataset =val_dataset.map(parse_x_y)

dataset = {"train": train_dataset, "val": val_dataset}

dataset['train'] = dataset['train'].map(load_image_train, num_parallel_calls=tf.data.experimental.AUTOTUNE).shuffle(buffer_size=BUFFER_SIZE, seed=SEED).batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
dataset['val'] = dataset['val'].map(load_image_train, num_parallel_calls=tf.data.experimental.AUTOTUNE).shuffle(buffer_size=BUFFER_SIZE, seed=SEED).batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

# %%
for image,label in dataset['train'].take(1):
    print("image: ",image.shape)
    print("label: ",label.shape,"\n\tunique values", np.unique(label[0]))
    
for image,label in dataset['val'].take(1):
    print("image: ",image.shape)
    print("label: ",label.shape,"\n\tunique values", np.unique(label[0]))
# Out:
# image:  (16, 512, 512, 3)
# label:  (16, 512, 512, 3)
# 	unique values [0. 1.]
# image:  (16, 512, 512, 3)
# label:  (16, 512, 512, 3)
# 	unique values [0. 1.]

# %%
import matplotlib.pyplot as plt

def display_sample(display_list):
    """Show side-by-side an input image,
    the ground truth and the prediction.
    """
    plt.figure(figsize=(7, 7))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

# %%
i=0
for image, mask in dataset['train'].take(5):
    i=i+1
#     print(i)
    sample_image, sample_mask = image, mask
    t = np.argmax(sample_mask[0],axis=-1)
    t = tf.expand_dims(t,axis=-1)
    display_sample([sample_image[0],t])

# %% [markdown]
# ## custom data generator

# %%
train_X_y_paths = list(zip(train_x, train_y))
val_X_y_paths = list(zip(val_x, val_y))

# %%
def shuffle(samples):
    index = np.random.permutation(len(samples))
    return np.array(samples)[index]

def read_img(img):
    X_image = cv2.imread(img)[:,:,::-1] # convert bgr to rgb
    X_image = cv2.resize(X_image, (512, 512))    
    X_image = X_image / 255.0
    X_image = X_image.astype(np.float32)
    return X_image

def read_label(label_img):
    Y_image = cv2.imread(label_img, 0)    
    Y_image = cv2.resize(Y_image, (512, 512),fx = 1, fy = 1,interpolation = cv2.INTER_NEAREST)    
    Y_image = tf.one_hot(Y_image, 3)
#     Y_image.set_shape([512, 1024, 3])
    Y_image = np.array(Y_image)
    Y_image = Y_image.astype(np.float32)
    return Y_image

def get_data_generator(samples,batch_size):
    while True:
        for offset in range(0, len(samples), batch_size): 
            samples = shuffle(samples)           
            batch_samples = samples[offset:offset+batch_size]
            X_train = []
            Y_train = []                    
            for batch_sample in batch_samples:
                X_image = read_img(img=batch_sample[0])
                Y_image = read_label(label_img=batch_sample[1])
        
                X_train.append(X_image)
                Y_train.append(Y_image)
            yield np.array(X_train), np.array(Y_train)


BATCH_SIZE = 32
train_generator = get_data_generator(train_X_y_paths,batch_size=BATCH_SIZE)
val_generator = get_data_generator(val_X_y_paths,batch_size=BATCH_SIZE)
 
# x_train, y_train = next(train_generator)
# x_val, y_val  = next(val_generator)
 
# print(x_train.shape,y_train.shape)
# print(x_val.shape, y_val.shape)

# %%
# train_X_y_paths[-5:]
# print(np.unique(y_train[0]), y_train.shape)

# import matplotlib.pyplot as plt
# plt.imshow(np.argmax(y_train[1], axis=-1))#,cmap="gray")
# plt.show()

# %%
# %env SM_FRAMEWORK=tf.keras

# %%
# -*- coding: utf-8 -*-

""" Deeplabv3+ model for Keras.
This model is based on TF repo:
https://github.com/tensorflow/models/tree/master/research/deeplab
On Pascal VOC, original model gets to 84.56% mIOU
MobileNetv2 backbone is based on this repo:
https://github.com/JonathanCMitchell/mobilenet_v2_keras
# Reference
- [Encoder-Decoder with Atrous Separable Convolution
    for Semantic Image Segmentation](https://arxiv.org/pdf/1802.02611.pdf)
- [Xception: Deep Learning with Depthwise Separable Convolutions]
    (https://arxiv.org/abs/1610.02357)
- [Inverted Residuals and Linear Bottlenecks: Mobile Networks for
    Classification, Detection and Segmentation](https://arxiv.org/abs/1801.04381)
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf

from tensorflow.python.keras.models import Model
from tensorflow.python.keras import layers
from tensorflow.python.keras.layers import Input
from tensorflow.python.keras.layers import Reshape
from tensorflow.python.keras.layers import Activation
from tensorflow.python.keras.layers import Concatenate
from tensorflow.python.keras.layers import Add
from tensorflow.python.keras.layers import Dropout
from tensorflow.python.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Conv2D
from tensorflow.python.keras.layers import DepthwiseConv2D
from tensorflow.python.keras.layers import ZeroPadding2D
from tensorflow.python.keras.layers import GlobalAveragePooling2D
from tensorflow.python.keras.utils.layer_utils import get_source_inputs
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.applications.imagenet_utils import preprocess_input

WEIGHTS_PATH_X = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_MOBILE = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5"

WEIGHTS_PATH_X_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"
WEIGHTS_PATH_MOBILE_CS = "pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"


def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):
    """ SepConv with BN between depthwise & pointwise. Optionally add activation after BN
        Implements right "same" padding for even kernel sizes
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & poinwise convs
            epsilon: epsilon to use in BN layer
    """

    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)

    return x


def _conv2d_same(x, filters, prefix, stride=1, kernel_size=3, rate=1):
    """Implements right 'same' padding for even kernel sizes
        Without this there is a 1 pixel drift when stride = 2
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
    """
    if stride == 1:
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='same', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='valid', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)


def _xception_block(inputs, depth_list, prefix, skip_connection_type, stride,
                    rate=1, depth_activation=False, return_skip=False):
    """ Basic building block of modified Xception network
        Args:
            inputs: input tensor
            depth_list: number of filters in each SepConv layer. len(depth_list) == 3
            prefix: prefix before name
            skip_connection_type: one of {'conv','sum','none'}
            stride: stride at last depthwise conv
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & pointwise convs
            return_skip: flag to return additional tensor after 2 SepConvs for decoder
            """
    residual = inputs
    for i in range(3):
        residual = SepConv_BN(residual,
                              depth_list[i],
                              prefix + '_separable_conv{}'.format(i + 1),
                              stride=stride if i == 2 else 1,
                              rate=rate,
                              depth_activation=depth_activation)
        if i == 1:
            skip = residual
    if skip_connection_type == 'conv':
        shortcut = _conv2d_same(inputs, depth_list[-1], prefix + '_shortcut',
                                kernel_size=1,
                                stride=stride)
        shortcut = BatchNormalization(name=prefix + '_shortcut_BN')(shortcut)
        outputs = layers.add([residual, shortcut])
    elif skip_connection_type == 'sum':
        outputs = layers.add([residual, inputs])
    elif skip_connection_type == 'none':
        outputs = residual
    if return_skip:
        return outputs, skip
    else:
        return outputs


def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id, skip_connection, rate=1):
    in_channels = inputs.shape[-1]#.value  # inputs._keras_shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs
    prefix = 'expanded_conv_{}_'.format(block_id)
    if block_id:
        # Expand

        x = Conv2D(expansion * in_channels, kernel_size=1, padding='same',
                   use_bias=False, activation=None,
                   name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                               name=prefix + 'expand_BN')(x)
        x = Activation(tf.nn.relu6, name=prefix + 'expand_relu')(x)
    else:
        prefix = 'expanded_conv_'
    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None,
                        use_bias=False, padding='same', dilation_rate=(rate, rate),
                        name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'depthwise_BN')(x)

    x = Activation(tf.nn.relu6, name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters,
               kernel_size=1, padding='same', use_bias=False, activation=None,
               name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'project_BN')(x)

    if skip_connection:
        return Add(name=prefix + 'add')([inputs, x])

    # if in_channels == pointwise_filters and stride == 1:
    #    return Add(name='res_connect_' + str(block_id))([inputs, x])

    return x


def Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(512, 512, 3), classes=21, backbone='mobilenetv2',
              OS=16, alpha=1., activation=None):
    """ Instantiates the Deeplabv3+ architecture
    Optionally loads weights pre-trained
    on PASCAL VOC or Cityscapes. This model is available for TensorFlow only.
    # Arguments
        weights: one of 'pascal_voc' (pre-trained on pascal voc),
            'cityscapes' (pre-trained on cityscape) or None (random initialization)
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: shape of input image. format HxWxC
            PASCAL VOC model was trained on (512,512,3) images. None is allowed as shape/width
        classes: number of desired classes. PASCAL VOC has 21 classes, Cityscapes has 19 classes.
            If number of classes not aligned with the weights used, last layer is initialized randomly
        backbone: backbone to use. one of {'xception','mobilenetv2'}
        activation: optional activation to add to the top of the network.
            One of 'softmax', 'sigmoid' or None
        OS: determines input_shape/feature_extractor_output ratio. One of {8,16}.
            Used only for xception backbone.
        alpha: controls the width of the MobileNetV2 network. This is known as the
            width multiplier in the MobileNetV2 paper.
                - If `alpha` < 1.0, proportionally decreases the number
                    of filters in each layer.
                - If `alpha` > 1.0, proportionally increases the number
                    of filters in each layer.
                - If `alpha` = 1, default number of filters from the paper
                    are used at each layer.
            Used only for mobilenetv2 backbone. Pretrained is only available for alpha=1.
    # Returns
        A Keras model instance.
    # Raises
        RuntimeError: If attempting to run this model with a
            backend that does not support separable convolutions.
        ValueError: in case of invalid argument for `weights` or `backbone`
    """

    if not (weights in {'pascal_voc', 'cityscapes', None}):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization), `pascal_voc`, or `cityscapes` '
                         '(pre-trained on PASCAL VOC)')

    if not (backbone in {'xception', 'mobilenetv2'}):
        raise ValueError('The `backbone` argument should be either '
                         '`xception`  or `mobilenetv2` ')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        img_input = input_tensor

    if backbone == 'xception':
        if OS == 8:
            entry_block3_stride = 1
            middle_block_rate = 2  # ! Not mentioned in paper, but required
            exit_block_rates = (2, 4)
            atrous_rates = (12, 24, 36)
        else:
            entry_block3_stride = 2
            middle_block_rate = 1
            exit_block_rates = (1, 2)
            atrous_rates = (6, 12, 18)

        x = Conv2D(32, (3, 3), strides=(2, 2),
                   name='entry_flow_conv1_1', use_bias=False, padding='same')(img_input)
        x = BatchNormalization(name='entry_flow_conv1_1_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _conv2d_same(x, 64, 'entry_flow_conv1_2', kernel_size=3, stride=1)
        x = BatchNormalization(name='entry_flow_conv1_2_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _xception_block(x, [128, 128, 128], 'entry_flow_block1',
                            skip_connection_type='conv', stride=2,
                            depth_activation=False)
        x, skip1 = _xception_block(x, [256, 256, 256], 'entry_flow_block2',
                                   skip_connection_type='conv', stride=2,
                                   depth_activation=False, return_skip=True)

        x = _xception_block(x, [728, 728, 728], 'entry_flow_block3',
                            skip_connection_type='conv', stride=entry_block3_stride,
                            depth_activation=False)
        for i in range(16):
            x = _xception_block(x, [728, 728, 728], 'middle_flow_unit_{}'.format(i + 1),
                                skip_connection_type='sum', stride=1, rate=middle_block_rate,
                                depth_activation=False)

        x = _xception_block(x, [728, 1024, 1024], 'exit_flow_block1',
                            skip_connection_type='conv', stride=1, rate=exit_block_rates[0],
                            depth_activation=False)
        x = _xception_block(x, [1536, 1536, 2048], 'exit_flow_block2',
                            skip_connection_type='none', stride=1, rate=exit_block_rates[1],
                            depth_activation=True)

    else:
        OS = 8
        first_block_filters = _make_divisible(32 * alpha, 8)
        x = Conv2D(first_block_filters,
                   kernel_size=3,
                   strides=(2, 2), padding='same', use_bias=False,
                   name='Conv' if input_shape[2] == 3 else 'Conv_')(img_input)
        x = BatchNormalization(
            epsilon=1e-3, momentum=0.999, name='Conv_BN')(x)
        x = Activation(tf.nn.relu6, name='Conv_Relu6')(x)

        x = _inverted_res_block(x, filters=16, alpha=alpha, stride=1,
                                expansion=1, block_id=0, skip_connection=False)

        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
                                expansion=6, block_id=1, skip_connection=False)
        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=1,
                                expansion=6, block_id=2, skip_connection=True)

        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=2,
                                expansion=6, block_id=3, skip_connection=False)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=4, skip_connection=True)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=5, skip_connection=True)

        # stride in block 6 changed from 2 -> 1, so we need to use rate = 2
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1,  # 1!
                                expansion=6, block_id=6, skip_connection=False)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=7, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=8, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=9, skip_connection=True)

        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=10, skip_connection=False)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=11, skip_connection=True)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=12, skip_connection=True)

        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=2,  # 1!
                                expansion=6, block_id=13, skip_connection=False)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=14, skip_connection=True)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=15, skip_connection=True)

        x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=16, skip_connection=False)

    # end of feature extractor

    # branching for Atrous Spatial Pyramid Pooling

    # Image Feature branch
    shape_before = tf.shape(x)
    b4 = GlobalAveragePooling2D()(x)
    b4_shape = tf.keras.backend.int_shape(b4)
    # from (b_size, channels)->(b_size, 1, 1, channels)
    b4 = Reshape((1, 1, b4_shape[1]))(b4)
    b4 = Conv2D(256, (1, 1), padding='same',
                use_bias=False, name='image_pooling')(b4)
    b4 = BatchNormalization(name='image_pooling_BN', epsilon=1e-5)(b4)
    b4 = Activation(tf.nn.relu)(b4)
    # upsample. have to use compat because of the option align_corners
    size_before = tf.keras.backend.int_shape(x)
    b4 = tf.keras.layers.experimental.preprocessing.Resizing(
            *size_before[1:3], interpolation="bilinear"
        )(b4)
    # simple 1x1
    b0 = Conv2D(256, (1, 1), padding='same', use_bias=False, name='aspp0')(x)
    b0 = BatchNormalization(name='aspp0_BN', epsilon=1e-5)(b0)
    b0 = Activation(tf.nn.relu, name='aspp0_activation')(b0)

    # there are only 2 branches in mobilenetV2. not sure why
    if backbone == 'xception':
        # rate = 6 (12)
        b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
        b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
        b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
        x = Concatenate()([b4, b0, b1, b2, b3])
    else:
        x = Concatenate()([b4, b0])

    x = Conv2D(256, (1, 1), padding='same',
               use_bias=False, name='concat_projection')(x)
    x = BatchNormalization(name='concat_projection_BN', epsilon=1e-5)(x)
    x = Activation(tf.nn.relu)(x)
    x = Dropout(0.1)(x)
    # DeepLab v.3+ decoder

    if backbone == 'xception':
        # Feature projection
        # x4 (x2) block
        skip_size = tf.keras.backend.int_shape(skip1)
        x = tf.keras.layers.experimental.preprocessing.Resizing(
                *skip_size[1:3], interpolation="bilinear"
            )(x)
        dec_skip1 = Conv2D(48, (1, 1), padding='same',
                           use_bias=False, name='feature_projection0')(skip1)
        dec_skip1 = BatchNormalization(
            name='feature_projection0_BN', epsilon=1e-5)(dec_skip1)
        dec_skip1 = Activation(tf.nn.relu)(dec_skip1)
        x = Concatenate()([x, dec_skip1])
        x = SepConv_BN(x, 256, 'decoder_conv0',
                       depth_activation=True, epsilon=1e-5)
        x = SepConv_BN(x, 256, 'decoder_conv1',
                       depth_activation=True, epsilon=1e-5)

    # you can use it with arbitary number of classes
    if (weights == 'pascal_voc' and classes == 21) or (weights == 'cityscapes' and classes == 19):
        last_layer_name = 'logits_semantic'
    else:
        last_layer_name = 'custom_logits_semantic'

    x = Conv2D(classes, (1, 1), padding='same', name=last_layer_name)(x)
    size_before3 = tf.keras.backend.int_shape(img_input)
    x = tf.keras.layers.experimental.preprocessing.Resizing(
            *size_before3[1:3], interpolation="bilinear"
        )(x)
    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    if activation in {'softmax', 'sigmoid'}:
        x = tf.keras.layers.Activation(activation)(x)

    model = Model(inputs, x, name='deeplabv3plus')

    # load weights

    if weights == 'pascal_voc':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_X,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_MOBILE,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    elif weights == 'cityscapes':
        if backbone == 'xception':
#             weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5',
#                                     WEIGHTS_PATH_X_CS,
#                                     cache_subdir='models')
            weights_path = "pretrained_weights/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"    
        else:
#             weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5',
#                                     WEIGHTS_PATH_MOBILE_CS,
#                                     cache_subdir='models')
           weights_path = "pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"
            
        model.load_weights(weights_path, by_name=True)
    return model

def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.
    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].
    # Returns
        Input array scaled to [-1.,1.]
    """
    return preprocess_input(x, mode='tf')

# %%
# !pwd
# Out:
# /home/tensorflow/Documents/Semantic_Segmentation

# %%
# m = tf.keras.applications.MobileNet(
#     input_shape=(512,512,3),
#     alpha=1.0,
#     depth_multiplier=1,
#     dropout=0.001,
#     include_top=False,
#     weights=None,
#     input_tensor=None,
#     pooling=None,
#     classes=3,
#     classifier_activation="softmax",
# )
# m.summary()

# alpha 1.0 : 32,64,128,256,512,1024
# alpha 0.1 : 3,6,12,25,51,102
# alpha 0.3 : 9,18,36,125,153,307

# %% [markdown]
# m = tf.keras.applications.MobileNet(
#     input_shape=(512,512,3),
#     alpha=0.3,
#     depth_multiplier=1,
#     dropout=0.001,
#     include_top=False,
#     weights=None,
#     input_tensor=None,
#     pooling=None,
#     classes=3,
#     classifier_activation="softmax",
# )
# m.summary()

# %%
model = Deeplabv3(weights=None, input_shape=(512,512,3), classes=3, 
                  backbone= 'mobilenetv2', #'xception'
                  OS=16, alpha=0.3, activation='softmax')
# model.load_weights('pretrained_weights/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5')

# %%
from segmentation_models.losses import cce_jaccard_loss, dice_loss, JaccardLoss
from segmentation_models.metrics import iou_score, f1_score, precision, recall
ls = dice_loss + cce_jaccard_loss
metrics = [precision, recall, f1_score, iou_score] 

from tensorflow.keras.models import load_model
model = load_model('mobilenetV2_edge/ckpt_path/475.h5',
                   custom_objects={'dice_loss_plus_categorical_crossentropy_plus_jaccard_loss':ls,
                                   'precision':precision, 'recall':recall, 'f1-score':f1_score, 'iou_score':iou_score})
# Out:
# Segmentation Models: using `keras` framework.

# %%
import os, time, keras
# %env SM_FRAMEWORK=tf.keras

import numpy as np
import tensorflow as tf
# from model import build_unet
# from data import load_dataset, tf_dataset
from segmentation_models.losses import bce_jaccard_loss, dice_loss, JaccardLoss
from segmentation_models.metrics import iou_score, f1_score, precision, recall
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping

""" Hyperparamaters """
batch_size = 16
epochs = 1000
base_dir = 'mobilenetV2_edge'
if not os.path.exists(base_dir):
    os.mkdir(base_dir)
    os.mkdir(f"{base_dir}/ckpt_path")
    
csv_path = f"{base_dir}/history.csv"

""" callbacks """
root_logdir = os.path.join(os.curdir, f"{base_dir}/logs","fit","")
def get_run_logdir():
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

checkpoint_filepath = f'{base_dir}/'+'ckpt_path/{epoch}.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    # monitor='val_iou_score',
    # mode='max',
    verbose = 1,
    period = 25,
    save_best_only=False
    )

callbacks = [
    model_checkpoint_callback,
#     ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.1, verbose=1),
    CSVLogger(csv_path),
#     EarlyStopping(monitor="val_loss", patience=10),
    tensorboard_cb
]

""" steps per epochs """
train_steps = len(train_X_y_paths)//batch_size
if len(train_X_y_paths) % batch_size != 0:
    train_steps += 1

test_steps = len(val_X_y_paths)//batch_size
if len(val_X_y_paths) % batch_size != 0:
    test_steps += 1

print("train_steps", train_steps, "test_steps",test_steps)

""" Model training """
# for layer in model.layers:
#     if layer.name == "global_average_pooling2d":
#         break
#     else:
#         layer.trainable = False

# for layer in model.layers:
#     print(layer.name,layer.trainable)

model.compile(
    loss=ls,
    optimizer= "adam",
    metrics=metrics
)
# model.summary()
# Out:
# env: SM_FRAMEWORK=tf.keras
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# train_steps 155 test_steps 32

# %%
history = model.fit(
    dataset["train"],
    validation_data=dataset["val"],
    epochs=1000,
    initial_epoch = 475,
    steps_per_epoch=train_steps,
    validation_steps=test_steps,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 476/1000
# 155/155 [==============================] - 107s 620ms/step - loss: 0.0900 - precision: 0.9741 - recall: 0.9759 - f1-score: 0.9750 - iou_score: 0.9519 - val_loss: 0.2763 - val_precision: 0.9345 - val_recall: 0.9396 - val_f1-score: 0.9367 - val_iou_score: 0.8842
# Epoch 477/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0882 - precision: 0.9745 - recall: 0.9764 - f1-score: 0.9755 - iou_score: 0.9528 - val_loss: 0.2710 - val_precision: 0.9378 - val_recall: 0.9366 - val_f1-score: 0.9368 - val_iou_score: 0.8843
# Epoch 478/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0876 - precision: 0.9747 - recall: 0.9766 - f1-score: 0.9757 - iou_score: 0.9532 - val_loss: 0.2686 - val_precision: 0.9363 - val_recall: 0.9398 - val_f1-score: 0.9377 - val_iou_score: 0.8858
# Epoch 479/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0868 - precision: 0.9750 - recall: 0.9769 - f1-score: 0.9759 - iou_score: 0.9537 - val_loss: 0.2712 - val_precision: 0.9360 - val_recall: 0.9393 - val_f1-score: 0.9373 - val_iou_score: 0.8849
# Epoch 480/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0869 - precision: 0.9749 - recall: 0.9768 - f1-score: 0.9759 - iou_score: 0.9535 - val_loss: 0.2769 - val_precision: 0.9343 - val_recall: 0.9380 - val_f1-score: 0.9357 - val_iou_score: 0.8826
# Epoch 481/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0865 - precision: 0.9751 - recall: 0.9770 - f1-score: 0.9760 - iou_score: 0.9538 - val_loss: 0.2815 - val_precision: 0.9325 - val_recall: 0.9405 - val_f1-score: 0.9361 - val_iou_score: 0.8833
# Epoch 482/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0860 - precision: 0.9752 - recall: 0.9771 - f1-score: 0.9761 - iou_score: 0.9540 - val_loss: 0.2790 - val_precision: 0.9351 - val_recall: 0.9384 - val_f1-score: 0.9364 - val_iou_score: 0.8836
# Epoch 483/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0864 - precision: 0.9751 - recall: 0.9770 - f1-score: 0.9760 - iou_score: 0.9538 - val_loss: 0.2791 - val_precision: 0.9378 - val_recall: 0.9362 - val_f1-score: 0.9367 - val_iou_score: 0.8841
# Epoch 484/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0858 - precision: 0.9753 - recall: 0.9772 - f1-score: 0.9762 - iou_score: 0.9542 - val_loss: 0.2746 - val_precision: 0.9353 - val_recall: 0.9388 - val_f1-score: 0.9367 - val_iou_score: 0.8844
# Epoch 485/1000
# 155/155 [==============================] - 95s 607ms/step - loss: 0.0855 - precision: 0.9753 - recall: 0.9772 - f1-score: 0.9763 - iou_score: 0.9543 - val_loss: 0.2804 - val_precision: 0.9371 - val_recall: 0.9362 - val_f1-score: 0.9363 - val_iou_score: 0.8836
# Epoch 486/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0857 - precision: 0.9752 - recall: 0.9772 - f1-score: 0.9762 - iou_score: 0.9542 - val_loss: 0.2822 - val_precision: 0.9340 - val_recall: 0.9371 - val_f1-score: 0.9351 - val_iou_score: 0.8815
# Epoch 487/1000
# 155/155 [==============================] - 94s 607ms/step - loss: 0.0855 - precision: 0.9754 - recall: 0.9772 - f1-score: 0.9763 - iou_score: 0.9543 - val_loss: 0.2818 - val_precision: 0.9356 - val_recall: 0.9390 - val_f1-score: 0.9370 - val_iou_score: 0.8846
# Epoch 488/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0856 - precision: 0.9753 - recall: 0.9772 - f1-score: 0.9762 - iou_score: 0.9542 - val_loss: 0.2759 - val_precision: 0.9353 - val_recall: 0.9395 - val_f1-score: 0.9371 - val_iou_score: 0.8849
# Epoch 489/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0854 - precision: 0.9754 - recall: 0.9773 - f1-score: 0.9763 - iou_score: 0.9544 - val_loss: 0.2774 - val_precision: 0.9363 - val_recall: 0.9386 - val_f1-score: 0.9371 - val_iou_score: 0.8848
# Epoch 490/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0851 - precision: 0.9754 - recall: 0.9773 - f1-score: 0.9764 - iou_score: 0.9545 - val_loss: 0.2774 - val_precision: 0.9360 - val_recall: 0.9387 - val_f1-score: 0.9370 - val_iou_score: 0.8848
# Epoch 491/1000
# 155/155 [==============================] - 97s 621ms/step - loss: 0.0851 - precision: 0.9755 - recall: 0.9774 - f1-score: 0.9764 - iou_score: 0.9546 - val_loss: 0.2797 - val_precision: 0.9355 - val_recall: 0.9393 - val_f1-score: 0.9370 - val_iou_score: 0.8847
# Epoch 492/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0850 - precision: 0.9755 - recall: 0.9774 - f1-score: 0.9764 - iou_score: 0.9546 - val_loss: 0.2803 - val_precision: 0.9359 - val_recall: 0.9371 - val_f1-score: 0.9362 - val_iou_score: 0.8835
# Epoch 493/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0846 - precision: 0.9756 - recall: 0.9776 - f1-score: 0.9766 - iou_score: 0.9548 - val_loss: 0.2808 - val_precision: 0.9353 - val_recall: 0.9367 - val_f1-score: 0.9356 - val_iou_score: 0.8823
# Epoch 494/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0846 - precision: 0.9756 - recall: 0.9775 - f1-score: 0.9765 - iou_score: 0.9548 - val_loss: 0.2808 - val_precision: 0.9332 - val_recall: 0.9399 - val_f1-score: 0.9361 - val_iou_score: 0.8834
# Epoch 495/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0846 - precision: 0.9756 - recall: 0.9776 - f1-score: 0.9766 - iou_score: 0.9549 - val_loss: 0.2841 - val_precision: 0.9338 - val_recall: 0.9354 - val_f1-score: 0.9343 - val_iou_score: 0.8806
# Epoch 496/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0845 - precision: 0.9756 - recall: 0.9775 - f1-score: 0.9766 - iou_score: 0.9548 - val_loss: 0.2790 - val_precision: 0.9352 - val_recall: 0.9398 - val_f1-score: 0.9371 - val_iou_score: 0.8849
# Epoch 497/1000
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0843 - precision: 0.9757 - recall: 0.9776 - f1-score: 0.9767 - iou_score: 0.9550 - val_loss: 0.2812 - val_precision: 0.9389 - val_recall: 0.9365 - val_f1-score: 0.9373 - val_iou_score: 0.8854
# Epoch 498/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0844 - precision: 0.9756 - recall: 0.9776 - f1-score: 0.9766 - iou_score: 0.9549 - val_loss: 0.2785 - val_precision: 0.9383 - val_recall: 0.9365 - val_f1-score: 0.9371 - val_iou_score: 0.8849
# Epoch 499/1000
# 155/155 [==============================] - 96s 616ms/step - loss: 0.0842 - precision: 0.9757 - recall: 0.9776 - f1-score: 0.9767 - iou_score: 0.9551 - val_loss: 0.2815 - val_precision: 0.9362 - val_recall: 0.9372 - val_f1-score: 0.9364 - val_iou_score: 0.8838
# Epoch 500/1000
# 155/155 [==============================] - ETA: 0s - loss: 0.0839 - precision: 0.9758 - recall: 0.9777 - f1-score: 0.9768 - iou_score: 0.9552
# Epoch 00500: saving model to mobilenetV2_edge/ckpt_path/500.h5
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0839 - precision: 0.9758 - recall: 0.9777 - f1-score: 0.9768 - iou_score: 0.9552 - val_loss: 0.2745 - val_precision: 0.9357 - val_recall: 0.9405 - val_f1-score: 0.9378 - val_iou_score: 0.8861
# Epoch 501/1000
# 155/155 [==============================] - 97s 619ms/step - loss: 0.0839 - precision: 0.9758 - recall: 0.9777 - f1-score: 0.9767 - iou_score: 0.9552 - val_loss: 0.2775 - val_precision: 0.9350 - val_recall: 0.9406 - val_f1-score: 0.9374 - val_iou_score: 0.8855
# Epoch 502/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0841 - precision: 0.9757 - recall: 0.9777 - f1-score: 0.9767 - iou_score: 0.9550 - val_loss: 0.2836 - val_precision: 0.9356 - val_recall: 0.9379 - val_f1-score: 0.9365 - val_iou_score: 0.8837
# Epoch 503/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0839 - precision: 0.9758 - recall: 0.9777 - f1-score: 0.9767 - iou_score: 0.9552 - val_loss: 0.2874 - val_precision: 0.9334 - val_recall: 0.9386 - val_f1-score: 0.9356 - val_iou_score: 0.8823
# Epoch 504/1000
# 155/155 [==============================] - 94s 602ms/step - loss: 0.0836 - precision: 0.9759 - recall: 0.9778 - f1-score: 0.9768 - iou_score: 0.9554 - val_loss: 0.2831 - val_precision: 0.9340 - val_recall: 0.9416 - val_f1-score: 0.9374 - val_iou_score: 0.8855
# Epoch 505/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0836 - precision: 0.9759 - recall: 0.9778 - f1-score: 0.9768 - iou_score: 0.9554 - val_loss: 0.2837 - val_precision: 0.9330 - val_recall: 0.9406 - val_f1-score: 0.9365 - val_iou_score: 0.8838
# Epoch 506/1000
# 155/155 [==============================] - 95s 607ms/step - loss: 0.0835 - precision: 0.9759 - recall: 0.9778 - f1-score: 0.9769 - iou_score: 0.9554 - val_loss: 0.2819 - val_precision: 0.9337 - val_recall: 0.9401 - val_f1-score: 0.9366 - val_iou_score: 0.8839
# Epoch 507/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0833 - precision: 0.9760 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9555 - val_loss: 0.2785 - val_precision: 0.9352 - val_recall: 0.9391 - val_f1-score: 0.9368 - val_iou_score: 0.8841
# Epoch 508/1000
# 155/155 [==============================] - 94s 604ms/step - loss: 0.0832 - precision: 0.9760 - recall: 0.9780 - f1-score: 0.9770 - iou_score: 0.9556 - val_loss: 0.2810 - val_precision: 0.9360 - val_recall: 0.9378 - val_f1-score: 0.9366 - val_iou_score: 0.8838
# Epoch 509/1000
# 155/155 [==============================] - 93s 596ms/step - loss: 0.0833 - precision: 0.9760 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9556 - val_loss: 0.2818 - val_precision: 0.9359 - val_recall: 0.9369 - val_f1-score: 0.9361 - val_iou_score: 0.8830
# Epoch 510/1000
# 155/155 [==============================] - 94s 607ms/step - loss: 0.0835 - precision: 0.9759 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9554 - val_loss: 0.2851 - val_precision: 0.9309 - val_recall: 0.9395 - val_f1-score: 0.9346 - val_iou_score: 0.8806
# Epoch 511/1000
# 155/155 [==============================] - 94s 604ms/step - loss: 0.0835 - precision: 0.9759 - recall: 0.9778 - f1-score: 0.9769 - iou_score: 0.9554 - val_loss: 0.2887 - val_precision: 0.9347 - val_recall: 0.9350 - val_f1-score: 0.9345 - val_iou_score: 0.8808
# Epoch 512/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0835 - precision: 0.9759 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9554 - val_loss: 0.2802 - val_precision: 0.9365 - val_recall: 0.9362 - val_f1-score: 0.9360 - val_iou_score: 0.8831
# Epoch 513/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0834 - precision: 0.9760 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9555 - val_loss: 0.2829 - val_precision: 0.9330 - val_recall: 0.9401 - val_f1-score: 0.9362 - val_iou_score: 0.8836
# Epoch 514/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0834 - precision: 0.9759 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9555 - val_loss: 0.2792 - val_precision: 0.9334 - val_recall: 0.9408 - val_f1-score: 0.9366 - val_iou_score: 0.8841
# Epoch 515/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0830 - precision: 0.9760 - recall: 0.9780 - f1-score: 0.9770 - iou_score: 0.9557 - val_loss: 0.2834 - val_precision: 0.9330 - val_recall: 0.9396 - val_f1-score: 0.9360 - val_iou_score: 0.8834
# Epoch 516/1000
# 155/155 [==============================] - 94s 602ms/step - loss: 0.0836 - precision: 0.9758 - recall: 0.9778 - f1-score: 0.9768 - iou_score: 0.9553 - val_loss: 0.2873 - val_precision: 0.9336 - val_recall: 0.9395 - val_f1-score: 0.9362 - val_iou_score: 0.8834
# Epoch 517/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0835 - precision: 0.9759 - recall: 0.9778 - f1-score: 0.9769 - iou_score: 0.9554 - val_loss: 0.2810 - val_precision: 0.9339 - val_recall: 0.9411 - val_f1-score: 0.9371 - val_iou_score: 0.8850
# Epoch 518/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0831 - precision: 0.9760 - recall: 0.9779 - f1-score: 0.9770 - iou_score: 0.9556 - val_loss: 0.2892 - val_precision: 0.9339 - val_recall: 0.9365 - val_f1-score: 0.9348 - val_iou_score: 0.8810
# Epoch 519/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0832 - precision: 0.9760 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9555 - val_loss: 0.2806 - val_precision: 0.9343 - val_recall: 0.9394 - val_f1-score: 0.9365 - val_iou_score: 0.8840
# Epoch 520/1000
# 155/155 [==============================] - 94s 604ms/step - loss: 0.0833 - precision: 0.9760 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9555 - val_loss: 0.2838 - val_precision: 0.9339 - val_recall: 0.9367 - val_f1-score: 0.9348 - val_iou_score: 0.8815
# Epoch 521/1000
# 155/155 [==============================] - 94s 607ms/step - loss: 0.0826 - precision: 0.9762 - recall: 0.9781 - f1-score: 0.9771 - iou_score: 0.9559 - val_loss: 0.2877 - val_precision: 0.9361 - val_recall: 0.9357 - val_f1-score: 0.9355 - val_iou_score: 0.8825
# Epoch 522/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0833 - precision: 0.9759 - recall: 0.9779 - f1-score: 0.9769 - iou_score: 0.9555 - val_loss: 0.2848 - val_precision: 0.9346 - val_recall: 0.9352 - val_f1-score: 0.9344 - val_iou_score: 0.8804
# Epoch 523/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0825 - precision: 0.9762 - recall: 0.9781 - f1-score: 0.9772 - iou_score: 0.9560 - val_loss: 0.2840 - val_precision: 0.9337 - val_recall: 0.9392 - val_f1-score: 0.9362 - val_iou_score: 0.8833
# Epoch 524/1000
# 155/155 [==============================] - 96s 619ms/step - loss: 0.0828 - precision: 0.9761 - recall: 0.9780 - f1-score: 0.9771 - iou_score: 0.9558 - val_loss: 0.2854 - val_precision: 0.9348 - val_recall: 0.9376 - val_f1-score: 0.9357 - val_iou_score: 0.8826
# Epoch 525/1000
# 155/155 [==============================] - ETA: 0s - loss: 0.0821 - precision: 0.9763 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9562
# Epoch 00525: saving model to mobilenetV2_edge/ckpt_path/525.h5
# 155/155 [==============================] - 97s 622ms/step - loss: 0.0821 - precision: 0.9763 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9562 - val_loss: 0.2847 - val_precision: 0.9356 - val_recall: 0.9370 - val_f1-score: 0.9360 - val_iou_score: 0.8832
# Epoch 526/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0829 - precision: 0.9761 - recall: 0.9780 - f1-score: 0.9770 - iou_score: 0.9557 - val_loss: 0.2842 - val_precision: 0.9373 - val_recall: 0.9361 - val_f1-score: 0.9364 - val_iou_score: 0.8840
# Epoch 527/1000
# 155/155 [==============================] - 96s 615ms/step - loss: 0.0829 - precision: 0.9761 - recall: 0.9780 - f1-score: 0.9770 - iou_score: 0.9557 - val_loss: 0.2813 - val_precision: 0.9376 - val_recall: 0.9367 - val_f1-score: 0.9368 - val_iou_score: 0.8843
# Epoch 528/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0822 - precision: 0.9763 - recall: 0.9782 - f1-score: 0.9773 - iou_score: 0.9561 - val_loss: 0.2796 - val_precision: 0.9381 - val_recall: 0.9354 - val_f1-score: 0.9364 - val_iou_score: 0.8839
# Epoch 529/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0827 - precision: 0.9762 - recall: 0.9781 - f1-score: 0.9771 - iou_score: 0.9559 - val_loss: 0.2823 - val_precision: 0.9366 - val_recall: 0.9365 - val_f1-score: 0.9361 - val_iou_score: 0.8835
# Epoch 530/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0827 - precision: 0.9761 - recall: 0.9781 - f1-score: 0.9771 - iou_score: 0.9558 - val_loss: 0.2856 - val_precision: 0.9352 - val_recall: 0.9371 - val_f1-score: 0.9357 - val_iou_score: 0.8825
# Epoch 531/1000
# 155/155 [==============================] - 96s 616ms/step - loss: 0.0825 - precision: 0.9762 - recall: 0.9782 - f1-score: 0.9772 - iou_score: 0.9559 - val_loss: 0.2842 - val_precision: 0.9360 - val_recall: 0.9359 - val_f1-score: 0.9356 - val_iou_score: 0.8825
# Epoch 532/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0821 - precision: 0.9763 - recall: 0.9782 - f1-score: 0.9773 - iou_score: 0.9562 - val_loss: 0.2889 - val_precision: 0.9336 - val_recall: 0.9406 - val_f1-score: 0.9367 - val_iou_score: 0.8844
# Epoch 533/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0821 - precision: 0.9763 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9562 - val_loss: 0.2845 - val_precision: 0.9364 - val_recall: 0.9355 - val_f1-score: 0.9356 - val_iou_score: 0.8827
# Epoch 534/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0819 - precision: 0.9764 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9563 - val_loss: 0.2839 - val_precision: 0.9362 - val_recall: 0.9358 - val_f1-score: 0.9357 - val_iou_score: 0.8826
# Epoch 535/1000
# 155/155 [==============================] - 96s 613ms/step - loss: 0.0823 - precision: 0.9763 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9561 - val_loss: 0.2853 - val_precision: 0.9388 - val_recall: 0.9354 - val_f1-score: 0.9367 - val_iou_score: 0.8844
# Epoch 536/1000
# 155/155 [==============================] - 96s 620ms/step - loss: 0.0821 - precision: 0.9764 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9562 - val_loss: 0.2858 - val_precision: 0.9351 - val_recall: 0.9369 - val_f1-score: 0.9356 - val_iou_score: 0.8822
# Epoch 537/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0820 - precision: 0.9763 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9562 - val_loss: 0.2849 - val_precision: 0.9360 - val_recall: 0.9362 - val_f1-score: 0.9358 - val_iou_score: 0.8826
# Epoch 538/1000
# 155/155 [==============================] - 96s 616ms/step - loss: 0.0821 - precision: 0.9763 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9562 - val_loss: 0.2882 - val_precision: 0.9395 - val_recall: 0.9330 - val_f1-score: 0.9358 - val_iou_score: 0.8827
# Epoch 539/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0820 - precision: 0.9764 - recall: 0.9782 - f1-score: 0.9773 - iou_score: 0.9562 - val_loss: 0.2867 - val_precision: 0.9343 - val_recall: 0.9378 - val_f1-score: 0.9357 - val_iou_score: 0.8827
# Epoch 540/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0819 - precision: 0.9764 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9563 - val_loss: 0.2900 - val_precision: 0.9339 - val_recall: 0.9369 - val_f1-score: 0.9349 - val_iou_score: 0.8814
# Epoch 541/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0819 - precision: 0.9764 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9563 - val_loss: 0.2855 - val_precision: 0.9395 - val_recall: 0.9347 - val_f1-score: 0.9368 - val_iou_score: 0.8845
# Epoch 542/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0820 - precision: 0.9763 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9562 - val_loss: 0.2823 - val_precision: 0.9377 - val_recall: 0.9361 - val_f1-score: 0.9366 - val_iou_score: 0.8841
# Epoch 543/1000
# 155/155 [==============================] - 96s 613ms/step - loss: 0.0812 - precision: 0.9766 - recall: 0.9785 - f1-score: 0.9776 - iou_score: 0.9567 - val_loss: 0.2903 - val_precision: 0.9331 - val_recall: 0.9356 - val_f1-score: 0.9339 - val_iou_score: 0.8798
# Epoch 544/1000
# 155/155 [==============================] - 97s 622ms/step - loss: 0.0819 - precision: 0.9764 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9563 - val_loss: 0.2825 - val_precision: 0.9382 - val_recall: 0.9338 - val_f1-score: 0.9356 - val_iou_score: 0.8828
# Epoch 545/1000
# 155/155 [==============================] - 97s 621ms/step - loss: 0.0817 - precision: 0.9764 - recall: 0.9784 - f1-score: 0.9774 - iou_score: 0.9564 - val_loss: 0.2821 - val_precision: 0.9361 - val_recall: 0.9368 - val_f1-score: 0.9361 - val_iou_score: 0.8832
# Epoch 546/1000
# 155/155 [==============================] - 96s 619ms/step - loss: 0.0814 - precision: 0.9765 - recall: 0.9785 - f1-score: 0.9775 - iou_score: 0.9565 - val_loss: 0.2891 - val_precision: 0.9330 - val_recall: 0.9356 - val_f1-score: 0.9339 - val_iou_score: 0.8801
# Epoch 547/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0816 - precision: 0.9765 - recall: 0.9784 - f1-score: 0.9774 - iou_score: 0.9565 - val_loss: 0.2821 - val_precision: 0.9350 - val_recall: 0.9394 - val_f1-score: 0.9369 - val_iou_score: 0.8845
# Epoch 548/1000
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0819 - precision: 0.9764 - recall: 0.9783 - f1-score: 0.9773 - iou_score: 0.9563 - val_loss: 0.2883 - val_precision: 0.9324 - val_recall: 0.9401 - val_f1-score: 0.9358 - val_iou_score: 0.8829
# Epoch 549/1000
# 155/155 [==============================] - 96s 613ms/step - loss: 0.0818 - precision: 0.9764 - recall: 0.9784 - f1-score: 0.9774 - iou_score: 0.9564 - val_loss: 0.2839 - val_precision: 0.9353 - val_recall: 0.9386 - val_f1-score: 0.9365 - val_iou_score: 0.8842
# Epoch 550/1000
# 155/155 [==============================] - ETA: 0s - loss: 0.0814 - precision: 0.9765 - recall: 0.9784 - f1-score: 0.9775 - iou_score: 0.9565
# Epoch 00550: saving model to mobilenetV2_edge/ckpt_path/550.h5
# 155/155 [==============================] - 97s 620ms/step - loss: 0.0814 - precision: 0.9765 - recall: 0.9784 - f1-score: 0.9775 - iou_score: 0.9565 - val_loss: 0.2857 - val_precision: 0.9334 - val_recall: 0.9385 - val_f1-score: 0.9355 - val_iou_score: 0.8823
# Epoch 551/1000
# 155/155 [==============================] - 96s 613ms/step - loss: 0.0810 - precision: 0.9767 - recall: 0.9786 - f1-score: 0.9776 - iou_score: 0.9568 - val_loss: 0.2853 - val_precision: 0.9360 - val_recall: 0.9342 - val_f1-score: 0.9346 - val_iou_score: 0.8815
# Epoch 552/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0810 - precision: 0.9767 - recall: 0.9786 - f1-score: 0.9776 - iou_score: 0.9568 - val_loss: 0.2857 - val_precision: 0.9329 - val_recall: 0.9368 - val_f1-score: 0.9343 - val_iou_score: 0.8810
# Epoch 553/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0814 - precision: 0.9765 - recall: 0.9785 - f1-score: 0.9775 - iou_score: 0.9566 - val_loss: 0.2845 - val_precision: 0.9369 - val_recall: 0.9357 - val_f1-score: 0.9360 - val_iou_score: 0.8832
# Epoch 554/1000
# 155/155 [==============================] - 95s 607ms/step - loss: 0.0823 - precision: 0.9762 - recall: 0.9782 - f1-score: 0.9772 - iou_score: 0.9561 - val_loss: 0.2905 - val_precision: 0.9351 - val_recall: 0.9367 - val_f1-score: 0.9354 - val_iou_score: 0.8823
# Epoch 555/1000
# 155/155 [==============================] - 97s 622ms/step - loss: 0.0812 - precision: 0.9765 - recall: 0.9785 - f1-score: 0.9775 - iou_score: 0.9566 - val_loss: 0.2903 - val_precision: 0.9345 - val_recall: 0.9385 - val_f1-score: 0.9360 - val_iou_score: 0.8833
# Epoch 556/1000
# 155/155 [==============================] - 95s 607ms/step - loss: 0.0810 - precision: 0.9766 - recall: 0.9786 - f1-score: 0.9776 - iou_score: 0.9567 - val_loss: 0.2871 - val_precision: 0.9373 - val_recall: 0.9377 - val_f1-score: 0.9372 - val_iou_score: 0.8850
# Epoch 557/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0812 - precision: 0.9766 - recall: 0.9785 - f1-score: 0.9776 - iou_score: 0.9567 - val_loss: 0.2865 - val_precision: 0.9355 - val_recall: 0.9376 - val_f1-score: 0.9362 - val_iou_score: 0.8835
# Epoch 558/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0816 - precision: 0.9765 - recall: 0.9784 - f1-score: 0.9774 - iou_score: 0.9564 - val_loss: 0.2845 - val_precision: 0.9367 - val_recall: 0.9377 - val_f1-score: 0.9369 - val_iou_score: 0.8848
# Epoch 559/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0816 - precision: 0.9764 - recall: 0.9784 - f1-score: 0.9774 - iou_score: 0.9564 - val_loss: 0.2887 - val_precision: 0.9379 - val_recall: 0.9327 - val_f1-score: 0.9349 - val_iou_score: 0.8817
# Epoch 560/1000
# 155/155 [==============================] - 94s 607ms/step - loss: 0.0815 - precision: 0.9765 - recall: 0.9785 - f1-score: 0.9774 - iou_score: 0.9565 - val_loss: 0.2843 - val_precision: 0.9383 - val_recall: 0.9373 - val_f1-score: 0.9374 - val_iou_score: 0.8856
# Epoch 561/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0809 - precision: 0.9767 - recall: 0.9786 - f1-score: 0.9776 - iou_score: 0.9568 - val_loss: 0.2838 - val_precision: 0.9353 - val_recall: 0.9374 - val_f1-score: 0.9360 - val_iou_score: 0.8832
# Epoch 562/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0809 - precision: 0.9766 - recall: 0.9786 - f1-score: 0.9776 - iou_score: 0.9568 - val_loss: 0.2862 - val_precision: 0.9368 - val_recall: 0.9364 - val_f1-score: 0.9363 - val_iou_score: 0.8838
# Epoch 563/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0812 - precision: 0.9766 - recall: 0.9785 - f1-score: 0.9775 - iou_score: 0.9566 - val_loss: 0.2850 - val_precision: 0.9372 - val_recall: 0.9378 - val_f1-score: 0.9372 - val_iou_score: 0.8851
# Epoch 564/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0807 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9569 - val_loss: 0.2832 - val_precision: 0.9373 - val_recall: 0.9379 - val_f1-score: 0.9373 - val_iou_score: 0.8852
# Epoch 565/1000
# 155/155 [==============================] - 94s 603ms/step - loss: 0.0812 - precision: 0.9766 - recall: 0.9785 - f1-score: 0.9775 - iou_score: 0.9566 - val_loss: 0.2852 - val_precision: 0.9358 - val_recall: 0.9393 - val_f1-score: 0.9372 - val_iou_score: 0.8851
# Epoch 566/1000
# 155/155 [==============================] - 96s 616ms/step - loss: 0.0807 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9569 - val_loss: 0.2863 - val_precision: 0.9375 - val_recall: 0.9351 - val_f1-score: 0.9359 - val_iou_score: 0.8832
# Epoch 567/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0807 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9569 - val_loss: 0.2875 - val_precision: 0.9354 - val_recall: 0.9370 - val_f1-score: 0.9358 - val_iou_score: 0.8828
# Epoch 568/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0808 - precision: 0.9767 - recall: 0.9786 - f1-score: 0.9777 - iou_score: 0.9569 - val_loss: 0.2864 - val_precision: 0.9370 - val_recall: 0.9363 - val_f1-score: 0.9362 - val_iou_score: 0.8835
# Epoch 569/1000
# 155/155 [==============================] - 96s 616ms/step - loss: 0.0802 - precision: 0.9769 - recall: 0.9788 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2878 - val_precision: 0.9380 - val_recall: 0.9339 - val_f1-score: 0.9356 - val_iou_score: 0.8825
# Epoch 570/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0808 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9569 - val_loss: 0.2879 - val_precision: 0.9377 - val_recall: 0.9359 - val_f1-score: 0.9364 - val_iou_score: 0.8838
# Epoch 571/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0813 - precision: 0.9765 - recall: 0.9785 - f1-score: 0.9775 - iou_score: 0.9566 - val_loss: 0.2864 - val_precision: 0.9379 - val_recall: 0.9361 - val_f1-score: 0.9366 - val_iou_score: 0.8841
# Epoch 572/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0805 - precision: 0.9768 - recall: 0.9787 - f1-score: 0.9778 - iou_score: 0.9571 - val_loss: 0.2866 - val_precision: 0.9364 - val_recall: 0.9362 - val_f1-score: 0.9359 - val_iou_score: 0.8831
# Epoch 573/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0804 - precision: 0.9768 - recall: 0.9788 - f1-score: 0.9778 - iou_score: 0.9571 - val_loss: 0.2902 - val_precision: 0.9334 - val_recall: 0.9384 - val_f1-score: 0.9355 - val_iou_score: 0.8825
# Epoch 574/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0813 - precision: 0.9766 - recall: 0.9785 - f1-score: 0.9775 - iou_score: 0.9566 - val_loss: 0.2919 - val_precision: 0.9365 - val_recall: 0.9336 - val_f1-score: 0.9347 - val_iou_score: 0.8810
# Epoch 575/1000
# 155/155 [==============================] - ETA: 0s - loss: 0.0809 - precision: 0.9766 - recall: 0.9786 - f1-score: 0.9776 - iou_score: 0.9568
# Epoch 00575: saving model to mobilenetV2_edge/ckpt_path/575.h5
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0809 - precision: 0.9766 - recall: 0.9786 - f1-score: 0.9776 - iou_score: 0.9568 - val_loss: 0.2884 - val_precision: 0.9387 - val_recall: 0.9339 - val_f1-score: 0.9359 - val_iou_score: 0.8830
# Epoch 576/1000
# 155/155 [==============================] - 94s 604ms/step - loss: 0.0811 - precision: 0.9766 - recall: 0.9785 - f1-score: 0.9776 - iou_score: 0.9567 - val_loss: 0.2831 - val_precision: 0.9361 - val_recall: 0.9381 - val_f1-score: 0.9367 - val_iou_score: 0.8844
# Epoch 577/1000
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0802 - precision: 0.9769 - recall: 0.9788 - f1-score: 0.9778 - iou_score: 0.9572 - val_loss: 0.2923 - val_precision: 0.9351 - val_recall: 0.9369 - val_f1-score: 0.9356 - val_iou_score: 0.8825
# Epoch 578/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0807 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9569 - val_loss: 0.2844 - val_precision: 0.9383 - val_recall: 0.9356 - val_f1-score: 0.9366 - val_iou_score: 0.8843
# Epoch 579/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0810 - precision: 0.9766 - recall: 0.9786 - f1-score: 0.9776 - iou_score: 0.9568 - val_loss: 0.2906 - val_precision: 0.9344 - val_recall: 0.9361 - val_f1-score: 0.9349 - val_iou_score: 0.8813
# Epoch 580/1000
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0808 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9569 - val_loss: 0.2918 - val_precision: 0.9370 - val_recall: 0.9352 - val_f1-score: 0.9357 - val_iou_score: 0.8826
# Epoch 581/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0801 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2887 - val_precision: 0.9378 - val_recall: 0.9339 - val_f1-score: 0.9355 - val_iou_score: 0.8822
# Epoch 582/1000
# 155/155 [==============================] - 95s 607ms/step - loss: 0.0813 - precision: 0.9765 - recall: 0.9785 - f1-score: 0.9775 - iou_score: 0.9566 - val_loss: 0.2843 - val_precision: 0.9368 - val_recall: 0.9374 - val_f1-score: 0.9368 - val_iou_score: 0.8844
# Epoch 583/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0803 - precision: 0.9768 - recall: 0.9788 - f1-score: 0.9778 - iou_score: 0.9571 - val_loss: 0.2855 - val_precision: 0.9376 - val_recall: 0.9367 - val_f1-score: 0.9368 - val_iou_score: 0.8845
# Epoch 584/1000
# 155/155 [==============================] - 97s 621ms/step - loss: 0.0806 - precision: 0.9768 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9570 - val_loss: 0.2869 - val_precision: 0.9388 - val_recall: 0.9345 - val_f1-score: 0.9362 - val_iou_score: 0.8836
# Epoch 585/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0803 - precision: 0.9768 - recall: 0.9788 - f1-score: 0.9778 - iou_score: 0.9571 - val_loss: 0.2871 - val_precision: 0.9368 - val_recall: 0.9354 - val_f1-score: 0.9356 - val_iou_score: 0.8826
# Epoch 586/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0801 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2825 - val_precision: 0.9369 - val_recall: 0.9368 - val_f1-score: 0.9366 - val_iou_score: 0.8842
# Epoch 587/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0805 - precision: 0.9768 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9570 - val_loss: 0.2866 - val_precision: 0.9383 - val_recall: 0.9371 - val_f1-score: 0.9374 - val_iou_score: 0.8855
# Epoch 588/1000
# 155/155 [==============================] - 96s 617ms/step - loss: 0.0805 - precision: 0.9768 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9570 - val_loss: 0.2895 - val_precision: 0.9360 - val_recall: 0.9387 - val_f1-score: 0.9370 - val_iou_score: 0.8848
# Epoch 589/1000
# 155/155 [==============================] - 96s 618ms/step - loss: 0.0806 - precision: 0.9768 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9570 - val_loss: 0.2874 - val_precision: 0.9346 - val_recall: 0.9384 - val_f1-score: 0.9360 - val_iou_score: 0.8831
# Epoch 590/1000
# 155/155 [==============================] - 96s 618ms/step - loss: 0.0806 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9570 - val_loss: 0.2866 - val_precision: 0.9364 - val_recall: 0.9378 - val_f1-score: 0.9368 - val_iou_score: 0.8844
# Epoch 591/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0803 - precision: 0.9768 - recall: 0.9789 - f1-score: 0.9778 - iou_score: 0.9572 - val_loss: 0.2953 - val_precision: 0.9332 - val_recall: 0.9372 - val_f1-score: 0.9349 - val_iou_score: 0.8810
# Epoch 592/1000
# 155/155 [==============================] - 96s 618ms/step - loss: 0.0803 - precision: 0.9768 - recall: 0.9788 - f1-score: 0.9778 - iou_score: 0.9571 - val_loss: 0.2879 - val_precision: 0.9372 - val_recall: 0.9345 - val_f1-score: 0.9355 - val_iou_score: 0.8827
# Epoch 593/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0801 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2899 - val_precision: 0.9372 - val_recall: 0.9350 - val_f1-score: 0.9358 - val_iou_score: 0.8828
# Epoch 594/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0803 - precision: 0.9768 - recall: 0.9788 - f1-score: 0.9778 - iou_score: 0.9572 - val_loss: 0.2862 - val_precision: 0.9386 - val_recall: 0.9340 - val_f1-score: 0.9360 - val_iou_score: 0.8832
# Epoch 595/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0801 - precision: 0.9769 - recall: 0.9788 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2898 - val_precision: 0.9383 - val_recall: 0.9308 - val_f1-score: 0.9340 - val_iou_score: 0.8799
# Epoch 596/1000
# 155/155 [==============================] - 94s 602ms/step - loss: 0.0801 - precision: 0.9769 - recall: 0.9788 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2855 - val_precision: 0.9370 - val_recall: 0.9369 - val_f1-score: 0.9367 - val_iou_score: 0.8844
# Epoch 597/1000
# 155/155 [==============================] - 96s 615ms/step - loss: 0.0799 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2890 - val_precision: 0.9375 - val_recall: 0.9364 - val_f1-score: 0.9366 - val_iou_score: 0.8842
# Epoch 598/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0798 - precision: 0.9770 - recall: 0.9789 - f1-score: 0.9780 - iou_score: 0.9574 - val_loss: 0.2888 - val_precision: 0.9363 - val_recall: 0.9359 - val_f1-score: 0.9357 - val_iou_score: 0.8828
# Epoch 599/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0802 - precision: 0.9768 - recall: 0.9789 - f1-score: 0.9778 - iou_score: 0.9572 - val_loss: 0.2893 - val_precision: 0.9356 - val_recall: 0.9373 - val_f1-score: 0.9361 - val_iou_score: 0.8832
# Epoch 600/1000
# 155/155 [==============================] - ETA: 0s - loss: 0.0800 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9573
# Epoch 00600: saving model to mobilenetV2_edge/ckpt_path/600.h5
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0800 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2899 - val_precision: 0.9346 - val_recall: 0.9377 - val_f1-score: 0.9358 - val_iou_score: 0.8825
# Epoch 601/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0801 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2860 - val_precision: 0.9381 - val_recall: 0.9365 - val_f1-score: 0.9371 - val_iou_score: 0.8848
# Epoch 602/1000
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0804 - precision: 0.9768 - recall: 0.9788 - f1-score: 0.9778 - iou_score: 0.9571 - val_loss: 0.2865 - val_precision: 0.9364 - val_recall: 0.9371 - val_f1-score: 0.9364 - val_iou_score: 0.8835
# Epoch 603/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0802 - precision: 0.9768 - recall: 0.9788 - f1-score: 0.9778 - iou_score: 0.9572 - val_loss: 0.2886 - val_precision: 0.9338 - val_recall: 0.9369 - val_f1-score: 0.9350 - val_iou_score: 0.8817
# Epoch 604/1000
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0796 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9575 - val_loss: 0.2923 - val_precision: 0.9341 - val_recall: 0.9369 - val_f1-score: 0.9352 - val_iou_score: 0.8817
# Epoch 605/1000
# 155/155 [==============================] - 94s 607ms/step - loss: 0.0799 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9573 - val_loss: 0.2871 - val_precision: 0.9352 - val_recall: 0.9388 - val_f1-score: 0.9366 - val_iou_score: 0.8843
# Epoch 606/1000
# 155/155 [==============================] - 93s 600ms/step - loss: 0.0797 - precision: 0.9769 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9575 - val_loss: 0.2905 - val_precision: 0.9384 - val_recall: 0.9356 - val_f1-score: 0.9367 - val_iou_score: 0.8842
# Epoch 607/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0806 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9570 - val_loss: 0.2893 - val_precision: 0.9361 - val_recall: 0.9368 - val_f1-score: 0.9361 - val_iou_score: 0.8833
# Epoch 608/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0797 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9575 - val_loss: 0.2889 - val_precision: 0.9353 - val_recall: 0.9365 - val_f1-score: 0.9357 - val_iou_score: 0.8825
# Epoch 609/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0803 - precision: 0.9769 - recall: 0.9787 - f1-score: 0.9778 - iou_score: 0.9572 - val_loss: 0.2871 - val_precision: 0.9370 - val_recall: 0.9360 - val_f1-score: 0.9362 - val_iou_score: 0.8835
# Epoch 610/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0797 - precision: 0.9770 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9574 - val_loss: 0.2868 - val_precision: 0.9379 - val_recall: 0.9346 - val_f1-score: 0.9359 - val_iou_score: 0.8832
# Epoch 611/1000
# 155/155 [==============================] - 94s 602ms/step - loss: 0.0796 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9575 - val_loss: 0.2886 - val_precision: 0.9382 - val_recall: 0.9353 - val_f1-score: 0.9364 - val_iou_score: 0.8837
# Epoch 612/1000
# 155/155 [==============================] - 97s 621ms/step - loss: 0.0796 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9575 - val_loss: 0.2859 - val_precision: 0.9390 - val_recall: 0.9350 - val_f1-score: 0.9368 - val_iou_score: 0.8844
# Epoch 613/1000
# 155/155 [==============================] - 96s 617ms/step - loss: 0.0798 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9575 - val_loss: 0.2882 - val_precision: 0.9382 - val_recall: 0.9353 - val_f1-score: 0.9363 - val_iou_score: 0.8835
# Epoch 614/1000
# 155/155 [==============================] - 96s 615ms/step - loss: 0.0799 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9574 - val_loss: 0.2939 - val_precision: 0.9349 - val_recall: 0.9374 - val_f1-score: 0.9358 - val_iou_score: 0.8829
# Epoch 615/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0792 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2907 - val_precision: 0.9379 - val_recall: 0.9364 - val_f1-score: 0.9368 - val_iou_score: 0.8844
# Epoch 616/1000
# 155/155 [==============================] - 96s 616ms/step - loss: 0.0792 - precision: 0.9772 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9578 - val_loss: 0.2866 - val_precision: 0.9337 - val_recall: 0.9394 - val_f1-score: 0.9361 - val_iou_score: 0.8833
# Epoch 617/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0795 - precision: 0.9770 - recall: 0.9791 - f1-score: 0.9780 - iou_score: 0.9576 - val_loss: 0.2897 - val_precision: 0.9368 - val_recall: 0.9346 - val_f1-score: 0.9354 - val_iou_score: 0.8822
# Epoch 618/1000
# 155/155 [==============================] - 95s 607ms/step - loss: 0.0795 - precision: 0.9771 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9576 - val_loss: 0.2911 - val_precision: 0.9363 - val_recall: 0.9343 - val_f1-score: 0.9349 - val_iou_score: 0.8813
# Epoch 619/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0797 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9575 - val_loss: 0.2931 - val_precision: 0.9363 - val_recall: 0.9352 - val_f1-score: 0.9354 - val_iou_score: 0.8821
# Epoch 620/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0795 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9576 - val_loss: 0.2912 - val_precision: 0.9360 - val_recall: 0.9378 - val_f1-score: 0.9365 - val_iou_score: 0.8841
# Epoch 621/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0799 - precision: 0.9769 - recall: 0.9789 - f1-score: 0.9779 - iou_score: 0.9574 - val_loss: 0.2896 - val_precision: 0.9373 - val_recall: 0.9359 - val_f1-score: 0.9363 - val_iou_score: 0.8836
# Epoch 622/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0792 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2903 - val_precision: 0.9349 - val_recall: 0.9353 - val_f1-score: 0.9346 - val_iou_score: 0.8808
# Epoch 623/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0791 - precision: 0.9772 - recall: 0.9791 - f1-score: 0.9782 - iou_score: 0.9578 - val_loss: 0.2906 - val_precision: 0.9371 - val_recall: 0.9384 - val_f1-score: 0.9374 - val_iou_score: 0.8852
# Epoch 624/1000
# 155/155 [==============================] - 94s 607ms/step - loss: 0.0794 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2904 - val_precision: 0.9379 - val_recall: 0.9345 - val_f1-score: 0.9358 - val_iou_score: 0.8826
# Epoch 625/1000
# 155/155 [==============================] - ETA: 0s - loss: 0.0798 - precision: 0.9769 - recall: 0.9790 - f1-score: 0.9779 - iou_score: 0.9574
# Epoch 00625: saving model to mobilenetV2_edge/ckpt_path/625.h5
# 155/155 [==============================] - 95s 609ms/step - loss: 0.0798 - precision: 0.9769 - recall: 0.9790 - f1-score: 0.9779 - iou_score: 0.9574 - val_loss: 0.2902 - val_precision: 0.9379 - val_recall: 0.9357 - val_f1-score: 0.9365 - val_iou_score: 0.8838
# Epoch 626/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0795 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9576 - val_loss: 0.2916 - val_precision: 0.9349 - val_recall: 0.9362 - val_f1-score: 0.9352 - val_iou_score: 0.8818
# Epoch 627/1000
# 155/155 [==============================] - 96s 614ms/step - loss: 0.0795 - precision: 0.9770 - recall: 0.9790 - f1-score: 0.9780 - iou_score: 0.9576 - val_loss: 0.2900 - val_precision: 0.9374 - val_recall: 0.9320 - val_f1-score: 0.9340 - val_iou_score: 0.8800
# Epoch 628/1000
# 155/155 [==============================] - 96s 613ms/step - loss: 0.0794 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9576 - val_loss: 0.2889 - val_precision: 0.9377 - val_recall: 0.9357 - val_f1-score: 0.9365 - val_iou_score: 0.8838
# Epoch 629/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0792 - precision: 0.9772 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2929 - val_precision: 0.9348 - val_recall: 0.9350 - val_f1-score: 0.9345 - val_iou_score: 0.8805
# Epoch 630/1000
# 155/155 [==============================] - 94s 602ms/step - loss: 0.0790 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2901 - val_precision: 0.9393 - val_recall: 0.9340 - val_f1-score: 0.9363 - val_iou_score: 0.8836
# Epoch 631/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0789 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2916 - val_precision: 0.9381 - val_recall: 0.9347 - val_f1-score: 0.9361 - val_iou_score: 0.8834
# Epoch 632/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0789 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2855 - val_precision: 0.9372 - val_recall: 0.9357 - val_f1-score: 0.9361 - val_iou_score: 0.8833
# Epoch 633/1000
# 155/155 [==============================] - 96s 615ms/step - loss: 0.0790 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2860 - val_precision: 0.9369 - val_recall: 0.9360 - val_f1-score: 0.9361 - val_iou_score: 0.8836
# Epoch 634/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0789 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2895 - val_precision: 0.9345 - val_recall: 0.9373 - val_f1-score: 0.9357 - val_iou_score: 0.8826
# Epoch 635/1000
# 155/155 [==============================] - 97s 623ms/step - loss: 0.0791 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9578 - val_loss: 0.2909 - val_precision: 0.9361 - val_recall: 0.9370 - val_f1-score: 0.9361 - val_iou_score: 0.8834
# Epoch 636/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0791 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9578 - val_loss: 0.2900 - val_precision: 0.9365 - val_recall: 0.9354 - val_f1-score: 0.9355 - val_iou_score: 0.8824
# Epoch 637/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0789 - precision: 0.9773 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2923 - val_precision: 0.9321 - val_recall: 0.9401 - val_f1-score: 0.9357 - val_iou_score: 0.8825
# Epoch 638/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0793 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2927 - val_precision: 0.9325 - val_recall: 0.9371 - val_f1-score: 0.9345 - val_iou_score: 0.8811
# Epoch 639/1000
# 155/155 [==============================] - 95s 613ms/step - loss: 0.0792 - precision: 0.9772 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2903 - val_precision: 0.9361 - val_recall: 0.9374 - val_f1-score: 0.9364 - val_iou_score: 0.8836
# Epoch 640/1000
# 155/155 [==============================] - 96s 616ms/step - loss: 0.0793 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2899 - val_precision: 0.9359 - val_recall: 0.9388 - val_f1-score: 0.9370 - val_iou_score: 0.8847
# Epoch 641/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0793 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2942 - val_precision: 0.9351 - val_recall: 0.9364 - val_f1-score: 0.9354 - val_iou_score: 0.8822
# Epoch 642/1000
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0792 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2906 - val_precision: 0.9332 - val_recall: 0.9381 - val_f1-score: 0.9352 - val_iou_score: 0.8819
# Epoch 643/1000
# 155/155 [==============================] - 96s 617ms/step - loss: 0.0791 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9578 - val_loss: 0.2918 - val_precision: 0.9384 - val_recall: 0.9352 - val_f1-score: 0.9365 - val_iou_score: 0.8840
# Epoch 644/1000
# 155/155 [==============================] - 95s 610ms/step - loss: 0.0789 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2907 - val_precision: 0.9355 - val_recall: 0.9352 - val_f1-score: 0.9351 - val_iou_score: 0.8817
# Epoch 645/1000
# 155/155 [==============================] - 96s 615ms/step - loss: 0.0791 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9578 - val_loss: 0.2916 - val_precision: 0.9340 - val_recall: 0.9372 - val_f1-score: 0.9352 - val_iou_score: 0.8818
# Epoch 646/1000
# 155/155 [==============================] - 96s 617ms/step - loss: 0.0827 - precision: 0.9763 - recall: 0.9782 - f1-score: 0.9773 - iou_score: 0.9561 - val_loss: 0.2882 - val_precision: 0.9349 - val_recall: 0.9377 - val_f1-score: 0.9361 - val_iou_score: 0.8830
# Epoch 647/1000
# 155/155 [==============================] - 96s 616ms/step - loss: 0.0808 - precision: 0.9767 - recall: 0.9787 - f1-score: 0.9777 - iou_score: 0.9569 - val_loss: 0.2874 - val_precision: 0.9362 - val_recall: 0.9357 - val_f1-score: 0.9357 - val_iou_score: 0.8823
# Epoch 648/1000
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0789 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2901 - val_precision: 0.9365 - val_recall: 0.9359 - val_f1-score: 0.9359 - val_iou_score: 0.8829
# Epoch 649/1000
# 155/155 [==============================] - 95s 608ms/step - loss: 0.0788 - precision: 0.9773 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9580 - val_loss: 0.2866 - val_precision: 0.9361 - val_recall: 0.9358 - val_f1-score: 0.9356 - val_iou_score: 0.8825
# Epoch 650/1000
# 155/155 [==============================] - ETA: 0s - loss: 0.0786 - precision: 0.9773 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9581
# Epoch 00650: saving model to mobilenetV2_edge/ckpt_path/650.h5
# 155/155 [==============================] - 95s 612ms/step - loss: 0.0786 - precision: 0.9773 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9581 - val_loss: 0.2902 - val_precision: 0.9355 - val_recall: 0.9331 - val_f1-score: 0.9339 - val_iou_score: 0.8802
# Epoch 651/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0787 - precision: 0.9773 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9580 - val_loss: 0.2848 - val_precision: 0.9358 - val_recall: 0.9365 - val_f1-score: 0.9358 - val_iou_score: 0.8827
# Epoch 652/1000
# 155/155 [==============================] - 95s 611ms/step - loss: 0.0784 - precision: 0.9773 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9581 - val_loss: 0.2917 - val_precision: 0.9375 - val_recall: 0.9344 - val_f1-score: 0.9356 - val_iou_score: 0.8826
# Epoch 653/1000
# 155/155 [==============================] - 96s 617ms/step - loss: 0.0783 - precision: 0.9774 - recall: 0.9794 - f1-score: 0.9784 - iou_score: 0.9582 - val_loss: 0.2819 - val_precision: 0.9391 - val_recall: 0.9357 - val_f1-score: 0.9371 - val_iou_score: 0.8849
# Epoch 654/1000
# 155/155 [==============================] - 94s 601ms/step - loss: 0.0784 - precision: 0.9774 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9581 - val_loss: 0.2876 - val_precision: 0.9394 - val_recall: 0.9349 - val_f1-score: 0.9369 - val_iou_score: 0.8845
# Epoch 655/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0789 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2886 - val_precision: 0.9373 - val_recall: 0.9333 - val_f1-score: 0.9347 - val_iou_score: 0.8810
# Epoch 656/1000
# 155/155 [==============================] - 94s 604ms/step - loss: 0.0785 - precision: 0.9774 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9581 - val_loss: 0.2870 - val_precision: 0.9357 - val_recall: 0.9381 - val_f1-score: 0.9365 - val_iou_score: 0.8839
# Epoch 657/1000
# 155/155 [==============================] - 94s 601ms/step - loss: 0.0792 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2898 - val_precision: 0.9370 - val_recall: 0.9380 - val_f1-score: 0.9371 - val_iou_score: 0.8851
# Epoch 658/1000
# 155/155 [==============================] - 93s 599ms/step - loss: 0.0786 - precision: 0.9773 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9580 - val_loss: 0.2916 - val_precision: 0.9358 - val_recall: 0.9366 - val_f1-score: 0.9358 - val_iou_score: 0.8826
# Epoch 659/1000
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0787 - precision: 0.9773 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9580 - val_loss: 0.2954 - val_precision: 0.9380 - val_recall: 0.9331 - val_f1-score: 0.9352 - val_iou_score: 0.8818
# Epoch 660/1000
# 155/155 [==============================] - 94s 605ms/step - loss: 0.0786 - precision: 0.9773 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9580 - val_loss: 0.2875 - val_precision: 0.9361 - val_recall: 0.9379 - val_f1-score: 0.9367 - val_iou_score: 0.8843
# Epoch 661/1000
# 155/155 [==============================] - 94s 606ms/step - loss: 0.0782 - precision: 0.9775 - recall: 0.9794 - f1-score: 0.9784 - iou_score: 0.9583 - val_loss: 0.2887 - val_precision: 0.9351 - val_recall: 0.9392 - val_f1-score: 0.9368 - val_iou_score: 0.8844
# Epoch 662/1000
# 155/155 [==============================] - 93s 598ms/step - loss: 0.0785 - precision: 0.9773 - recall: 0.9793 - f1-score: 0.9783 - iou_score: 0.9581 - val_loss: 0.2902 - val_precision: 0.9391 - val_recall: 0.9322 - val_f1-score: 0.9352 - val_iou_score: 0.8820
# Epoch 663/1000
# 155/155 [==============================] - 93s 600ms/step - loss: 0.0788 - precision: 0.9773 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9580 - val_loss: 0.2856 - val_precision: 0.9381 - val_recall: 0.9360 - val_f1-score: 0.9368 - val_iou_score: 0.8845
# Epoch 664/1000
# 155/155 [==============================] - 95s 607ms/step - loss: 0.0793 - precision: 0.9771 - recall: 0.9791 - f1-score: 0.9781 - iou_score: 0.9577 - val_loss: 0.2886 - val_precision: 0.9381 - val_recall: 0.9372 - val_f1-score: 0.9373 - val_iou_score: 0.8852
# Epoch 665/1000
# 155/155 [==============================] - 94s 601ms/step - loss: 0.0788 - precision: 0.9773 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2897 - val_precision: 0.9364 - val_recall: 0.9366 - val_f1-score: 0.9361 - val_iou_score: 0.8835
# Epoch 666/1000
# 155/155 [==============================] - 95s 607ms/step - loss: 0.0788 - precision: 0.9772 - recall: 0.9792 - f1-score: 0.9782 - iou_score: 0.9579 - val_loss: 0.2880 - val_precision: 0.9383 - val_recall: 0.9350 - val_f1-score: 0.9363 - val_iou_score: 0.8836
# Epoch 667/1000
# 155/155 [==============================] - 94s 603ms/step - loss: 0.0787 - precision: 0.9773 - recall: 0.9792 - f1-score: 0.9783 - iou_score: 0.9580 - val_loss: 0.2920 - val_precision: 0.9340 - val_recall: 0.9388 - val_f1-score: 0.9359 - val_iou_score: 0.8830
# Epoch 668/1000
# 155/155 [==============================] - 94s 604ms/step - loss: 0.0784 - precision: 0.9773 - recall: 0.9794 - f1-score: 0.9784 - iou_score: 0.9582 - val_loss: 0.2961 - val_precision: 0.9365 - val_recall: 0.9321 - val_f1-score: 0.9337 - val_iou_score: 0.8794
# Epoch 669/1000
# 155/155 [==============================] - 94s 602ms/step - loss: 0.0782 - precision: 0.9774 - recall: 0.9794 - f1-score: 0.9784 - iou_score: 0.9582 - val_loss: 0.2951 - val_precision: 0.9359 - val_recall: 0.9355 - val_f1-score: 0.9352 - val_iou_score: 0.8821
# Epoch 670/1000
#  44/155 [=======>......................] - ETA: 1:03 - loss: 0.0791 - precision: 0.9770 - recall: 0.9793 - f1-score: 0.9781 - iou_score: 0.9578
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-8ae7a7224d57> in <module>
# ----> 1 history = model.fit(
#       2     dataset["train"],
#       3     validation_data=dataset["val"],
#       4     epochs=1000,
#       5     initial_epoch = 475,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
# model.save('/content/drive/MyDrive/LaneSeg/Deeplabv3p_xception_fullsize_Lane_Seg_0036+16.h5')

# %%
# from segmentation_models.losses import cce_jaccard_loss, dice_loss, JaccardLoss
# from segmentation_models.metrics import iou_score, f1_score, precision, recall
# ls = dice_loss + cce_jaccard_loss
# metrics = [precision, recall, f1_score, iou_score] 

# from tensorflow.keras.models import load_model
# model = load_model('mobilenetv2_bs4/ckpt_path/Deeplabv3p_mobilenetv2_200.h5',
#                    custom_objects={'dice_loss_plus_categorical_crossentropy_plus_jaccard_loss':ls,
#                                    'precision':precision, 'recall':recall, 'f1-score':f1_score, 'iou_score':iou_score})

# %%
# !tensorboard --logdir logs --host 0.0.0.0
