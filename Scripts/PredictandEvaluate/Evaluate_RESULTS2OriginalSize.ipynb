# %%
# !pip install tqdm pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 76 kB 2.8 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 11.7 MB 746 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 503 kB 16.2 MB/s eta 0:00:01
# ...
#   WARNING: The script tqdm is installed in '/home/tensorflow/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !python pred11.py "IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4__1X1_DSC_custom_bs8" 340 False

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

CS_Dv3p_xception_OS16_bs12_CS = pd.read_csv("../../RESULTS/CS_Dv3p_xception_OS16_bs12/TestResult_OS16.csv")
CS_Dv3p_xception_OS8_bs12_CS = pd.read_csv("../../RESULTS/CS_Dv3p_xception_OS16_bs12/TestResult_OS8.csv")
CS_mobilenetV2_bs4_CS = pd.read_csv("../../RESULTS/CS_Dv3p_mobilenetV2_alpha1.0_bs4/TestResult.csv")

CS_mobilenetV2_edge_175epoch_CS = pd.read_csv("../../RESULTS/CS_Dv3p_mobilenetV2_alpha0.3_bs16/TestResult_175_CS.csv")
CS_mobilenetV2_edge_475epoch_CS = pd.read_csv("../../RESULTS/CS_Dv3p_mobilenetV2_alpha0.3_bs16/TestResult_475_CS.csv")
CS_mobilenetV2_edge_475epoch_IDD = pd.read_csv("../../RESULTS/CS_Dv3p_mobilenetV2_alpha0.3_bs16/TestResult_475_IDD.csv")

CS_mobilenetV2_edge_650epoch_IDD = pd.read_csv("../../RESULTS/CS_Dv3p_mobilenetV2_alpha0.3_bs16/TestResult_650_IDD.csv")
CS_mobilenetV2_edge_650epoch_BDD= pd.read_csv("../../RESULTS/CS_Dv3p_mobilenetV2_alpha0.3_bs16/TestResult_650_BDD.csv")
CS_mobilenetV2_edge_650epoch_CS = pd.read_csv("../../RESULTS/CS_Dv3p_mobilenetV2_alpha0.3_bs16/TestResult_650_CS.csv")

IDD_mobilenetV2_edge_350epoch_IDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_350_IDD.csv")
IDD_mobilenetV2_edge_350epoch_BDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_350_BDD.csv")
IDD_mobilenetV2_edge_350epoch_CS = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_350_CS.csv")

IDD_mobilenetV2_edge_725epoch_IDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_725_IDD.csv")
IDD_mobilenetV2_edge_725epoch_BDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_725_BDD.csv")
IDD_mobilenetV2_edge_725epoch_CS = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_725_CS.csv")

IDD_mobilenetV2_edge_75epoch_IDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_75_IDD.csv")
IDD_mobilenetV2_edge_75epoch_BDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_75_BDD.csv")
IDD_mobilenetV2_edge_75epoch_CS = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha1.0_bs16/TestResults/TestResult_75_CS.csv")

IDD_Unet_mobilenetV2_alpha1_125epoch_IDD = pd.read_csv("../../RESULTS/IDD_Unet_mobilenetV2_alpha1.0_bs8/TestResult_125_IDD.csv")
IDD_Unet_mobilenetV2_alpha1_125epoch_BDD = pd.read_csv("../../RESULTS/IDD_Unet_mobilenetV2_alpha1.0_bs8/TestResult_125_BDD.csv")
IDD_Unet_mobilenetV2_alpha1_125epoch_CS = pd.read_csv("../../RESULTS/IDD_Unet_mobilenetV2_alpha1.0_bs8/TestResult_125_CS.csv")

IDD_PSPnet_mobilenetV2_alpha1_125epoch_IDD = pd.read_csv("../../RESULTS/IDD_PSPnet_mobilenetV2_alpha1.0_bs8/TestResult_125_IDD.csv")
IDD_PSPnet_mobilenetV2_alpha1_125epoch_BDD = pd.read_csv("../../RESULTS/IDD_PSPnet_mobilenetV2_alpha1.0_bs8/TestResult_125_BDD.csv")
IDD_PSPnet_mobilenetV2_alpha1_125epoch_CS = pd.read_csv("../../RESULTS/IDD_PSPnet_mobilenetV2_alpha1.0_bs8/TestResult_125_CS.csv")

IDD_Linknet_mobilenetV2_alpha1_100epoch_IDD = pd.read_csv("../../RESULTS/IDD_Linknet_mobilenetV2_alpha1.0_bs8/TestResult_100_IDD.csv")
IDD_Linknet_mobilenetV2_alpha1_100epoch_BDD = pd.read_csv("../../RESULTS/IDD_Linknet_mobilenetV2_alpha1.0_bs8/TestResult_100_BDD.csv")
IDD_Linknet_mobilenetV2_alpha1_100epoch_CS = pd.read_csv("../../RESULTS/IDD_Linknet_mobilenetV2_alpha1.0_bs8/TestResult_100_CS.csv")

IDD_Unet_mobilenetV2_alpha0_35_150epoch_IDD = pd.read_csv("../../RESULTS/IDD_Unet_mobilenetV2_alpha0.35_custom_bs8/TestResult_150_IDD.csv")
IDD_Unet_mobilenetV2_alpha0_35_150epoch_BDD = pd.read_csv("../../RESULTS/IDD_Unet_mobilenetV2_alpha0.35_custom_bs8/TestResult_150_BDD.csv")
IDD_Unet_mobilenetV2_alpha0_35_150epoch_CS = pd.read_csv("../../RESULTS/IDD_Unet_mobilenetV2_alpha0.35_custom_bs8/TestResult_150_CS.csv")

IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_IDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby2_custom_bs8/TestResult_168_IDD.csv")
IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_BDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby2_custom_bs8/TestResult_168_BDD.csv")
IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_CS = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby2_custom_bs8/TestResult_168_CS.csv")

IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_IDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4_custom_bs8/TestResult_111_IDD.csv")
IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_BDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4_custom_bs8/TestResult_111_BDD.csv")
IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_CS = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4_custom_bs8/TestResult_111_CS.csv")

IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_IDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4__1X1_DSC_custom_bs8/TestResult_340_IDD.csv")
IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_BDD = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4__1X1_DSC_custom_bs8/TestResult_340_BDD.csv")
IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_CS = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4__1X1_DSC_custom_bs8/TestResult_340_CS.csv")

IDD_Unet_efficientnetB0_alpha1_172epoch_IDD = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB0_alpha1.0_bs8/TestResult_172_IDD.csv")
IDD_Unet_efficientnetB0_alpha1_172epoch_BDD = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB0_alpha1.0_bs8/TestResult_172_BDD.csv")
IDD_Unet_efficientnetB0_alpha1_172epoch_CS = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB0_alpha1.0_bs8/TestResult_172_CS.csv")

IDD_Unet_efficientnetB1_alpha1_169epoch_IDD = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB1_alpha1.0_bs8/TestResult_169_IDD.csv")
IDD_Unet_efficientnetB1_alpha1_169epoch_BDD = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB1_alpha1.0_bs8/TestResult_169_BDD.csv")
IDD_Unet_efficientnetB1_alpha1_169epoch_CS = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB1_alpha1.0_bs8/TestResult_169_CS.csv")

IDD_Unet_efficientnetB6_alpha1_102epoch_IDD = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB6_alpha1.0_bs8/TestResult_102_IDD.csv")
IDD_Unet_efficientnetB6_alpha1_102epoch_BDD = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB6_alpha1.0_bs8/TestResult_102_BDD.csv")
IDD_Unet_efficientnetB6_alpha1_102epoch_CS = pd.read_csv("../../RESULTS/IDD_Unet_efficientnetB6_alpha1.0_bs8/TestResult_102_CS.csv")

d = pd.DataFrame({                            
    "CS_Dv3p_xception_OS16_bs12_CS":CS_Dv3p_xception_OS16_bs12_CS.mean().values,
    "CS_Dv3p_xception_OS8_bs12_CS":CS_Dv3p_xception_OS8_bs12_CS.mean().values,
    "CS_mobilenetV2_bs4_CS":CS_mobilenetV2_bs4_CS.mean().values,    
    
    "CS_mobilenetV2_edge_175epoch_CS":CS_mobilenetV2_edge_175epoch_CS.mean().values,
    "CS_mobilenetV2_edge_475epoch_CS":CS_mobilenetV2_edge_475epoch_CS.mean().values,              
    "CS_mobilenetV2_edge_475epoch_IDD":CS_mobilenetV2_edge_475epoch_IDD.mean().values,
    
    "CS_mobilenetV2_edge_650epoch_IDD":CS_mobilenetV2_edge_650epoch_IDD.mean().values,
    "CS_mobilenetV2_edge_650epoch_BDD":CS_mobilenetV2_edge_650epoch_BDD.mean().values,              
    "CS_mobilenetV2_edge_650epoch_CS":CS_mobilenetV2_edge_650epoch_CS.mean().values,
        
    "IDD_mobilenetV2_edge_350epoch_IDD":IDD_mobilenetV2_edge_350epoch_IDD.mean().values,
    "IDD_mobilenetV2_edge_350epoch_BDD":IDD_mobilenetV2_edge_350epoch_BDD.mean().values,
    "IDD_mobilenetV2_edge_350epoch_CS":IDD_mobilenetV2_edge_350epoch_CS.mean().values,
    
    "IDD_mobilenetV2_edge_725epoch_IDD":IDD_mobilenetV2_edge_725epoch_IDD.mean().values,
    "IDD_mobilenetV2_edge_725epoch_BDD":IDD_mobilenetV2_edge_725epoch_BDD.mean().values,
    "IDD_mobilenetV2_edge_725epoch_CS":IDD_mobilenetV2_edge_725epoch_CS.mean().values,
    
    "IDD_mobilenetV2_edge_75epoch_IDD":IDD_mobilenetV2_edge_75epoch_IDD.mean().values,
    "IDD_mobilenetV2_edge_75epoch_BDD":IDD_mobilenetV2_edge_75epoch_BDD.mean().values,
    "IDD_mobilenetV2_edge_75epoch_CS":IDD_mobilenetV2_edge_75epoch_CS.mean().values,
    
    "IDD_Unet_mobilenetV2_alpha1_125epoch_IDD":IDD_Unet_mobilenetV2_alpha1_125epoch_IDD.mean().values,
    "IDD_Unet_mobilenetV2_alpha1_125epoch_BDD":IDD_Unet_mobilenetV2_alpha1_125epoch_BDD.mean().values,
    "IDD_Unet_mobilenetV2_alpha1_125epoch_CS":IDD_Unet_mobilenetV2_alpha1_125epoch_CS.mean().values,
    
    "IDD_PSPnet_mobilenetV2_alpha1_125epoch_IDD":IDD_PSPnet_mobilenetV2_alpha1_125epoch_IDD.mean().values,
    "IDD_PSPnet_mobilenetV2_alpha1_125epoch_BDD":IDD_PSPnet_mobilenetV2_alpha1_125epoch_BDD.mean().values,
    "IDD_PSPnet_mobilenetV2_alpha1_125epoch_CS":IDD_PSPnet_mobilenetV2_alpha1_125epoch_CS.mean().values,
    
    "IDD_Linknet_mobilenetV2_alpha1_100epoch_IDD":IDD_Linknet_mobilenetV2_alpha1_100epoch_IDD.mean().values,
    "IDD_Linknet_mobilenetV2_alpha1_100epoch_BDD":IDD_Linknet_mobilenetV2_alpha1_100epoch_BDD.mean().values,
    "IDD_Linknet_mobilenetV2_alpha1_100epoch_CS":IDD_Linknet_mobilenetV2_alpha1_100epoch_CS.mean().values,
    
    "IDD_Unet_mobilenetV2_alpha0_35_150epoch_IDD":IDD_Unet_mobilenetV2_alpha0_35_150epoch_IDD.mean().values,
    "IDD_Unet_mobilenetV2_alpha0_35_150epoch_BDD":IDD_Unet_mobilenetV2_alpha0_35_150epoch_BDD.mean().values,
    "IDD_Unet_mobilenetV2_alpha0_35_150epoch_CS":IDD_Unet_mobilenetV2_alpha0_35_150epoch_CS.mean().values,
    
    "IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_IDD":IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_IDD.mean().values,
    "IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_BDD":IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_BDD.mean().values,
    "IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_CS":IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_CS.mean().values,
    
    "IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_IDD":IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_IDD.mean().values,
    "IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_BDD":IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_BDD.mean().values,
    "IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_CS":IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_CS.mean().values,
    
    "IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_IDD":IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_IDD.mean().values,
    "IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_BDD":IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_BDD.mean().values,
    "IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_CS":IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_CS.mean().values,
    
    "IDD_Unet_efficientnetB0_alpha1_172epoch_IDD":IDD_Unet_efficientnetB0_alpha1_172epoch_IDD.mean().values,
    "IDD_Unet_efficientnetB0_alpha1_172epoch_BDD":IDD_Unet_efficientnetB0_alpha1_172epoch_BDD.mean().values,
    "IDD_Unet_efficientnetB0_alpha1_172epoch_CS":IDD_Unet_efficientnetB0_alpha1_172epoch_CS.mean().values,
    
    "IDD_Unet_efficientnetB1_alpha1_169epoch_IDD":IDD_Unet_efficientnetB1_alpha1_169epoch_IDD.mean().values,
    "IDD_Unet_efficientnetB1_alpha1_169epoch_BDD":IDD_Unet_efficientnetB1_alpha1_169epoch_BDD.mean().values,
    "IDD_Unet_efficientnetB1_alpha1_169epoch_CS":IDD_Unet_efficientnetB1_alpha1_169epoch_CS.mean().values,
    
    "IDD_Unet_efficientnetB6_alpha1_102epoch_IDD":IDD_Unet_efficientnetB6_alpha1_102epoch_IDD.mean().values,
    "IDD_Unet_efficientnetB6_alpha1_102epoch_BDD":IDD_Unet_efficientnetB6_alpha1_102epoch_BDD.mean().values,
    "IDD_Unet_efficientnetB6_alpha1_102epoch_CS":IDD_Unet_efficientnetB6_alpha1_102epoch_CS.mean().values,
    
}, index=["mIoU", "Precision", "Recall", "F1-score (Dice-score)","F2-score"])
d = d.T

# IDD_Unet_efficientnetB0_alpha1.0_bs8 172 IDD_Unet_efficientnetB0_alpha1_172epoch_IDD
# IDD_Unet_efficientnetB1_alpha1.0_bs8 169 IDD_Unet_efficientnetB1_alpha1_169epoch_IDD
# IDD_Unet_efficientnetB6_alpha1.0_bs8 102 IDD_Unet_efficientnetB6_alpha1_102epoch_IDD

d["Classes"]= [5]*3+[3]*45
d["Model"]= ["DeeplabV3p"]*18 +["Unet"]*3+["PSPnet"]*3 +["Linknet"]*3 + ["Unet"]*3 + ["Dv3p"]*9 + ["Unet"]*9
d["Backbone"]=["Xception OS16"]*2+["MobilenetV2 alpha1.0"]+["MobilenetV2 alpha0.3"]*6+["MobilenetV2 alpha1.0"]*18 +\
    ["MobilenetV2 alpha0.35"]*12 + ["efficientnetB0"]*3+["efficientnetB1"]*3+["efficientnetB6"]*3
d["Trained Dataset"]=["CS"]*9+["IDD"]*39
d["Test Dataset"]=["CS"]*3+["CS","CS","IDD"]+["IDD","BDD","CS"]*14
d["Trained Epochs"] = [60,60,84,175,475,475]+[650]*3 + [350]*3 +[725]*3+ [75]*3 + [125]*6 + [100]*3+ [150]*3 + [168]*3+\
    [111]*3 + [340]*3 +[172]*3+[169]*3 + [102]*3
d["Batch Size"] = [12,12,4]+[8]*6+[16]*9 + [8]*9 + [8]*12 +[4]*6+[2]*3
d["optimizer"]=["adam"]*9+["adam+nadam(275 onwards)"]*3+["adam,nadam(275 onwards) + with_Reduce_LR(350 onwards)"]*3+["adam"]*33
d["loss"]=["dice_loss + categorical_crossentropy + jaccard_loss"]*48

d["Images Count"] = [
    len(CS_Dv3p_xception_OS16_bs12_CS),
    len(CS_Dv3p_xception_OS8_bs12_CS),
    len(CS_mobilenetV2_bs4_CS),    
    len(CS_mobilenetV2_edge_175epoch_CS),
    len(CS_mobilenetV2_edge_475epoch_CS),len(CS_mobilenetV2_edge_475epoch_IDD),
                     
    len(CS_mobilenetV2_edge_650epoch_IDD),len(CS_mobilenetV2_edge_650epoch_BDD),len(CS_mobilenetV2_edge_650epoch_CS),
    len(IDD_mobilenetV2_edge_350epoch_IDD),len(IDD_mobilenetV2_edge_350epoch_BDD),len(IDD_mobilenetV2_edge_350epoch_CS),
    len(IDD_mobilenetV2_edge_725epoch_IDD),len(IDD_mobilenetV2_edge_725epoch_BDD),len(IDD_mobilenetV2_edge_725epoch_CS),                     
    len(IDD_mobilenetV2_edge_75epoch_IDD),len(IDD_mobilenetV2_edge_75epoch_BDD),len(IDD_mobilenetV2_edge_75epoch_CS),
    len(IDD_Unet_mobilenetV2_alpha1_125epoch_IDD),len(IDD_Unet_mobilenetV2_alpha1_125epoch_BDD),len(IDD_Unet_mobilenetV2_alpha1_125epoch_CS),
    len(IDD_PSPnet_mobilenetV2_alpha1_125epoch_IDD),len(IDD_PSPnet_mobilenetV2_alpha1_125epoch_BDD),len(IDD_PSPnet_mobilenetV2_alpha1_125epoch_CS),
    len(IDD_Linknet_mobilenetV2_alpha1_100epoch_IDD),len(IDD_Linknet_mobilenetV2_alpha1_100epoch_BDD),len(IDD_Linknet_mobilenetV2_alpha1_100epoch_CS),    
    len(IDD_Unet_mobilenetV2_alpha0_35_150epoch_IDD),len(IDD_Unet_mobilenetV2_alpha0_35_150epoch_BDD),len(IDD_Unet_mobilenetV2_alpha0_35_150epoch_CS),
    len(IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_IDD),len(IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_BDD),len(IDD_Dv3p_mobilenetV2_upsampleby2_custom_alpha0_35_168epoch_CS),
    len(IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_IDD),len(IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_BDD),len(IDD_Dv3p_mobilenetV2_upsampleby4_custom_alpha0_35_111epoch_CS),
    len(IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_IDD),len(IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_BDD),len(IDD_Dv3p_mobilenetV2_upsampleby4_1X1_DSC_custom_alpha0_35_340epoch_CS),
    len(IDD_Unet_efficientnetB0_alpha1_172epoch_IDD),len(IDD_Unet_efficientnetB0_alpha1_172epoch_BDD),len(IDD_Unet_efficientnetB0_alpha1_172epoch_CS),
    len(IDD_Unet_efficientnetB1_alpha1_169epoch_IDD),len(IDD_Unet_efficientnetB1_alpha1_169epoch_BDD),len(IDD_Unet_efficientnetB1_alpha1_169epoch_CS),
    len(IDD_Unet_efficientnetB6_alpha1_102epoch_IDD),len(IDD_Unet_efficientnetB6_alpha1_102epoch_BDD),len(IDD_Unet_efficientnetB6_alpha1_102epoch_CS),    
]
final_d = d[['Classes', 'Model', 'Backbone','Trained Dataset', 'Test Dataset',
       'Trained Epochs', 'Batch Size', 'optimizer', 'loss','Images Count','mIoU', 'Precision', 'Recall', 'F1-score (Dice-score)', 'F2-score']]
final_d.to_csv("../../RESULTS/Analysis_resized2ORG.csv")
final_d[['mIoU', 'Precision', 'Recall', 'F1-score (Dice-score)', 'F2-score']]#.sort_values(by="mIoU")
# Out:
#                                                         mIoU  Precision  \
# CS_Dv3p_xception_OS16_bs12_CS                       0.705746   0.815081
# CS_Dv3p_xception_OS8_bs12_CS                        0.695628   0.795993
# CS_mobilenetV2_bs4_CS                               0.743022   0.852509
# CS_mobilenetV2_edge_175epoch_CS                     0.854087   0.925751
# CS_mobilenetV2_edge_475epoch_CS                     0.865492   0.923830
# CS_mobilenetV2_edge_475epoch_IDD                    0.648186   0.777859
# CS_mobilenetV2_edge_650epoch_IDD                    0.693916   0.839117
# CS_mobilenetV2_edge_650epoch_BDD                    0.561843   0.679019
# CS_mobilenetV2_edge_650epoch_CS                     0.870145   0.928871
# IDD_mobilenetV2_edge_350epoch_IDD                   0.833040   0.900465
# IDD_mobilenetV2_edge_350epoch_BDD                   0.683485   0.782480
# IDD_mobilenetV2_edge_350epoch_CS                    0.684523   0.806061
# ...

# %%
import pandas as pd
t = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4__1X1_DSC_custom_bs8/TestResult_340_CS.csv")
t.mean()
# Out:
# mIoU                    0.659209
# Precision               0.762818
# Recall                  0.817660
# F1-score(Dice-score)    0.770095
# F2-score                0.789873
# dtype: float64

# %%
t = pd.read_csv("../../RESULTS/IDD_Dv3p_mobilenetV2_alpha0.35_upsampleby4__1X1_DSC_custom_bs8/TestResult_340_CS_resized2ORG.csv")
t.mean()
# Out:
# mIoU                    0.658749
# Precision               0.762434
# Recall                  0.817456
# F1-score(Dice-score)    0.769735
# F2-score                0.789576
# dtype: float64
